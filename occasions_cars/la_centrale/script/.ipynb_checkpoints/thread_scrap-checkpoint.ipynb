# %% [markdown]
# Lien du site :
# https://www.lacentrale.fr/auto-occasion-annonce-69113195868.html

# %% [markdown]
# # Scrappe la centrale

# %% [markdown]
# ### Import

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import pandas as pd
import urllib
import re
import requests
import csv
import time

from selenium.webdriver.common.service import Service
from selenium.webdriver.common.service import Service
from fake_useragent import UserAgent
from urllib3.exceptions import NewConnectionError
import logging
from datetime import datetime, timedelta
from selenium.common.exceptions import ElementClickInterceptedException

import pandas as pd 
import numpy as np 

import random
from selenium.webdriver.common.action_chains import ActionChains
from itertools import combinations

# %% [markdown]
# ### Scrappe

# %% [markdown]
# Fake Action

# %%
def action_aleatoire(driver):
    actions_possibles = ["scroll_full", "scroll_half", "move_to_element"]
    action_choisie = random.choice(actions_possibles)

    # Enregistrer la position actuelle de la page
    current_scroll_position = driver.execute_script("return window.pageYOffset;")

    if action_choisie == "scroll_full":
        # Action aléatoire : Faites défiler la page vers le bas
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    elif action_choisie == "scroll_half":
        # Action aléatoire : Faites défiler la moitié de la page vers le bas
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight / 2);")
    elif action_choisie == "move_to_element":
        # Action aléatoire : Bougez la souris vers un élément aléatoire (par exemple, div de class PriceInformation_classifiedPrice__b-Jae)
        wait = WebDriverWait(driver, 10)
        element_to_move = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'PriceInformation_classifiedPrice__b-Jae')))
        driver.execute_script("arguments[0].scrollIntoView();", element_to_move)

    # Revenir à la position enregistrée
    driver.execute_script(f"window.scrollTo(0, {current_scroll_position});")

# %%
def find_element_with_retry(driver, by, value, max_retries=3):
    retries = 0
    while retries < max_retries:
        try:
            element = driver.find_element(by, value)
            return element
        except NoSuchElementException:
            retries += 1
            time.sleep(2)  # Add a small delay before retrying
    raise NoSuchElementException(f"Element not found after {max_retries} retries")

# %% [markdown]
# Scrape

# %% [markdown]
# import time
# import random
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
# from fake_useragent import UserAgent
# from selenium.common.exceptions import WebDriverException
# # Configurations du navigateur
# ua = UserAgent()
# user_agent = ua.random
# options = webdriver.FirefoxOptions()
# options.add_argument('--headless')
# options.add_argument(f'user-agent={user_agent}')
#
# # Initialisation du navigateur
# driver = webdriver.Firefox(options=options)
# base_url = "https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page="
# xpath_expression = "//a[contains(@class, 'Vehiculecard_Vehiculecard_vehiculeCard Containers_Containers_containers Containers_Containers_borderRadius Containers_Containers_darkShadowWide')]"
# data_final = []
# # Numéro de la première page à visiter
# current_page = 0
#
# # Boucle pour parcourir les pages
# while True:
#     # Construire l'URL de la page actuelle
#
#
#     url = base_url + str(current_page)
#     time.sleep(random.uniform(2, 6))
#
#     # Charger la page web
#     try:
#         driver.set_page_load_timeout(120)
#         driver.get(url)
#     except TimeoutException:
#         print(f"TimeoutException: Unable to load {link}")
#     try:
#         # Insérer ici le code pour extraire les liens ou effectuer d'autres opérations sur la page
#         links = driver.find_elements(By.XPATH, xpath_expression)
#         all_links = []
#         # Ajouter les liens à la liste
#         all_links.extend(link.get_attribute("href") for link in links)
#         print(all_links)
#         # Parcourir chaque lien pour effectuer des opérations
#         for link in all_links:
#             try:
#                 # Afficher le lien trouvé
#                 print("Lien trouvé :", link)
#                 data = []
#                 # Accéder à la page du lien
#                 driver.get(link)
#                 time.sleep(random.uniform(2, 5))
#
#                 # Insérer ici le code pour effectuer des opérations sur la page du lien
#
#                 try:
#                     nom_xpath = "//div[contains(@class, 'Text_Text_text SummaryInformation_title__5CYhW Text_Text_headline3')]"
#
#                     nom = driver.find_element(By.XPATH, nom_xpath).text
#                     print("Nom du véhicule:", nom)
#
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     nom = " "
#                     print("aucun nom trouvé")
#                 data.append(nom)
#                 try:
#                     carac_xpath = "//div[contains(@class, 'Text_Text_text SummaryInformation_subtitle__M7MAb Text_Text_body2')]"
#                     carac = driver.find_element(By.XPATH, carac_xpath).text
#                     #print("Carac:", carac)
#
#                     # Diviser le texte en éléments
#                     elements = carac.split()
#                     action_aleatoire(driver)
#                     # Variables pour stocker les informations
#                     cylindree_moteur = ""
#                     type_moteur = ""
#                     puissance = ""
#                     finition = ""
#
#                     # Utiliser un indicateur pour savoir quel type d'information on traite actuellement
#                     current_type = None
#
#                     # Parcourir les éléments et attribuer aux variables appropriées
#                     for element in elements:
#                         # Vérifier s'il s'agit de la cylindrée du moteur (exprimée en centimètres cubes)
#                         if element.replace(".", "").isdigit() and not cylindree_moteur:
#                             cylindree_moteur = element
#                         # Vérifier s'il s'agit du type de moteur (contient des lettres)
#                         elif any(char.isalpha() for char in element) and not type_moteur:
#                             type_moteur = element
#                         # Vérifier s'il s'agit de la puissance (contient des chiffres)
#                         elif element.isdigit() and not puissance:
#                             puissance = element
#                         # Si ce n'est ni la cylindrée, ni le type, ni la puissance, c'est probablement la finition
#                         elif not finition:
#                             finition += element + " "
#
#                     cylindree_moteur = cylindree_moteur.strip()
#                     type_moteur = type_moteur.strip()
#                     puissance = puissance.strip()
#                     finition = finition.strip()
#                     # Afficher les résultats
#                     #print("Cylindrée du moteur:", cylindree_moteur.strip())
#                     #print("Type de moteur:", type_moteur.strip())
#                     #print("Puissance:", puissance.strip())
#                     #print("Finition:", finition.strip())
#                     data.append((cylindree_moteur,type_moteur,puissance,finition))
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     carac = " "
#                     print("Carac non trouvé")
#                 try:
#                     prix_xpath = "//span[contains(@class, 'PriceInformation_classifiedPrice__b-Jae')]"
#
#                     prix = driver.find_element(By.XPATH, prix_xpath).text
#                    # print("prix:", prix)
#                     time.sleep(random.uniform(2, 4))
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     prix = " "
#                     print("aucun nom trouvé")
#                 data.append(prix)
#                 try:
#                     duree_publi_xpath = "//div[contains(@class, 'Text_Text_text Text_Text_body2')]"
#
#                     duree_publi = driver.find_element(By.XPATH, duree_publi_xpath).text
#                    # print("publié depuis:",  duree_publi)
#                     time.sleep(random.uniform(2, 5))
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     durée_publi = " "
#                     print("no durée publi renseigné")
#                 data.append(duree_publi)
#                 try:
#                     volume_coffre_xpath = "//div[contains(@class, 'Gauge_Gauge_gaugeWrapper')]//button[contains(@class, 'Gauge_Gauge_value Button_Button_button Button_Button_shaded Button_Button_small Button_Button_square')]//span[contains(@class, 'Text_Text_text Text_Text_label2')]"
#                     volume_coffre_element = WebDriverWait(driver, 15).until(
#                             EC.presence_of_element_located((By.XPATH, volume_coffre_xpath))
#                     )
#
#                     volume_coffre = volume_coffre_element.get_attribute('textContent')
#                     # print("volume_coffre", volume_coffre)
#                     time.sleep(random.uniform(2, 3))
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     volume_coffre = " "
#                     print("no volume_coffrerenseigné")
#                 except TimeoutException:
#                     # Gérer la TimeoutException ici
#                     print("Élément non trouvé après 15 secondes. Continuer avec le reste du code.")
#                     volume_coffre = " "
#                 data.append(volume_coffre)
#                 try:
#                     spans_xpath = "//span[contains(@class, 'Text_Text_text Icon-button_IconButton_label Text_Text_label2')]"
#                     action_aleatoire(driver)
#                     spans = driver.find_elements(By.XPATH, spans_xpath)
#                     time.sleep(random.uniform(2, 4))
#     # Nombre de spans
#                     num_spans = len(spans)
#                     point_forts_values = []
#     # Créer des variables dynamiquement
#                     for index, span in enumerate(spans, start=1):
#         # Utilisation de JavaScript pour extraire le texte
#                         span_text = driver.execute_script("return arguments[0].textContent;", span)
#                         variable_name = f"point_fort{index}"
#                         locals()[variable_name] = span_text.strip()
#                          #print(f"{variable_name}:", locals()[variable_name])
#                         point_forts_values.append(locals()[variable_name])
#
#
#                 except NoSuchElementException:
#     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     for index in range(1, num_spans + 1):
#                         variable_name = f"point_fort{index}"
#                         locals()[variable_name] = " "
#                         print(f"{variable_name}: not found")
#                         point_forts_values.append(locals()[variable_name])
#
#                     # Ajouter le tuple de valeurs des points forts à la liste data
#                 data.append(tuple(point_forts_values))
#                 h3_values = []
#                 try:
#                     h3_xpath = "//h3[contains(@class, 'Text_Text_text Text_Text_subtitle1')]"
#
#                     h3_elements = driver.find_elements(By.XPATH, h3_xpath)
#                     time.sleep(random.uniform(2, 3))
#
#                     for h3_element in h3_elements:
#                         try:
#                             ul_element = h3_element.find_element(By.XPATH, "following-sibling::ul")
#
#                             li_elements = ul_element.find_elements(By.XPATH, "li")
#                             li_values = []
#                             for index, li_element in enumerate(li_elements, start=0):
#                                 time.sleep(random.uniform(2, 5))
#
#                                 try:
#                                     # Essayer de trouver le texte du span directement
#                                     first_span_xpath = ".//span[contains(@class, 'Text_Text_text Text_Text_subtitle2')]"
#                                     first_span_element = find_element_with_retry(li_element, By.XPATH, first_span_xpath)
#                                     variable_name = first_span_element.get_attribute('textContent')
#
#                                     span_xpath = ".//span[@class='Item_content__Xyd3d']"
#                                     span_element = find_element_with_retry(li_element, By.XPATH, span_xpath)
#                                     variable_value = span_element.get_attribute('textContent')
#
#                                 except NoSuchElementException:
#                                     # Si le premier essai échoue, essayer de trouver le texte du span à l'intérieur
#                                     span_xpath = ".//span[@class='Item_content__Xyd3d']//span"
#                                     span_element = find_element_with_retry(li_element, By.XPATH, span_xpath)
#                                     variable_value = span_element.get_attribute('textContent')
#                                 li_values.append((variable_name, variable_value))
#                                 # Maintenant, vous avez la valeur du texte du span, que ce soit directement ou à l'intérieur
#                                 #print(f"Nom de la variable : {variable_name}, Valeur de la variable : {variable_value}")
#                             h3_values.append(tuple(li_values))
#
#                         except NoSuchElementException:
#                             pass
#
#                 except NoSuchElementException:
#                     print("H3 non trouvé")
#                 data.append(tuple(h3_values))
#                 ########################EN COURS######################
#                 button_class_name = "Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline"
#
#                 try:
#                     # Find the button using its class name
#                     button = driver.find_element(By.CLASS_NAME, button_class_name)
#
#                     # Click the button
#                     button.click()
#
#                     print("Button clicked successfully")
#
#                 except NoSuchElementException:
#                     print(f"Button with class name '{button_class_name}' not found")
#                 except Exception as e:
#                     print(f"An error occurred: {e}")
#
#                 ####Scrappe equipement####
#                 xpath_button_options = "//div[contains(@class, 'EquipmentOptionsInformation_linkMoreEquipments__rd-QS')]//button[contains(@class, 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline')]"
#                 try:
#                     # Attendre que le bouton soit cliquable
#                     button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, xpath_button_options)))
#
#                     # Utiliser ActionChains pour survoler et cliquer sur le bouton
#                     action = ActionChains(driver)
#                     action.move_to_element(button).click().perform()
#
#                     print("Button clicked successfully")
#
#                 except NoSuchElementException:
#                     print(f"Button with XPath '{xpath_button_options}' not found")
#                 except Exception as e:
#                     print(f"An error occurred: {e}")
#
#                 ####Scrappe equipement####
#                 # Dictionnaire pour stocker les résultats
#                 results = {}
#
#
#
#                 # XPath pour sélectionner les uls
#                 ul_xpaths = "//ul[contains(@class, 'EquipmentOptionsInformation_column__rQp-a')]"
#
#                 # Parcourir les uls
#                 uls = driver.find_elements(By.XPATH, ul_xpaths)
#                 action_aleatoire(driver)
#                 # Parcourir chaque ul
#                 for ul_index, ul_element in enumerate(uls, start=1):
#                     try:
#                         # Trouver tous les li dans l'ul actuel
#                         li_elements = ul_element.find_elements(By.XPATH, "./li")
#
#                         # Parcourir chaque li
#                         time.sleep(random.uniform(2, 3))
#                         for li_index, li_element in enumerate(li_elements, start=1):
#                             # Obtenir tous les éléments h3 et div à l'intérieur du li
#                             h3_elements = li_element.find_elements(By.XPATH, "./h3")
#                             div_elements = li_element.find_elements(By.XPATH, "./div")
#
#                             # Concaténer les textcontents de tous les h3 et div
#                             li_textcontent = " ".join(element.get_attribute('textContent') for element in h3_elements + div_elements)
#
#                             # Ajouter le résultat au dictionnaire
#                             results[f"ul{ul_index}_li{li_index}"] = f",{li_textcontent}"
#
#                     except NoSuchElementException:
#                         print("UL non trouvé")
#
#                 # Afficher les résultats
#                 #for key, value in results.items():
#                     #print(f"{key}: {value}")
#                 data.append(tuple(results.values()))
#                 data_final.append(data)
#                 time.sleep(random.uniform(2, 3))
#                 #print(data_final)
#                 print("+1")
#                 csv_file_path = "data.csv"
#                 csv_columns = [
#                     "Nom du véhicule",
#                     "Caractéristiques",
#                     "Prix",
#                     "Durée de publication",
#                     "Volume du coffre",
#                     "Points forts",
#                     "Équipements"
#                 ]
#
#
#                 with open('data.csv', 'a', newline='', encoding='utf-8') as csvfile:
#                     csv_writer = csv.writer(csvfile)
#                     csv_writer.writerow(data)
#
#
#
#             except StaleElementReferenceException:
#                 # Si l'élément de lien est obsolète, afficher un message
#                 print("StaleElementReferenceException pour le lien :", link.get_attribute("href"))
#
#             except StaleElementReferenceException:
#                 # Si l'élément de lien est obsolète, afficher un message
#                 print("StaleElementReferenceException pour le lien :", link)
#                 pass
#             except TimeoutException as e:
#                 print(f"TimeoutException: {e}")
#                 pass
#                 # Handle the timeout exception
#             except WebDriverException as e:
#                 print(f"WebDriverException: {e}")
#                 pass
#
#     except NoSuchElementException:
#         # Si l'élément n'est pas trouvé, cela signifie probablement que la page n'existe pas
#         print("Fin de la boucle : La page", current_page, "n'existe pas.")
#         pass
#     # Passer à la page suivante
#
#     current_page += 1
#
# # Fermer le navigateur à la fin
# driver.quit()

# %% [markdown]
# ### TEST  POOL

# %%
import time
import random
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from fake_useragent import UserAgent
from selenium.common.exceptions import WebDriverException
from concurrent.futures import ThreadPoolExecutor
from selenium.common.exceptions import TimeoutException


def initialize_driver():
    ua = UserAgent()
    user_agent = ua.random
    options = webdriver.FirefoxOptions()
    options.add_argument('--headless')
    options.add_argument(f'user-agent={user_agent}')
    return webdriver.Firefox(options=options)
base_url = "https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page="
xpath_expression = "//a[contains(@class, 'Vehiculecard_Vehiculecard_vehiculeCard Containers_Containers_containers Containers_Containers_borderRadius Containers_Containers_darkShadowWide')]"
data_final = []
def scrape_page(base_url, start_page, step, driver, links):
    current_page = start_page
   
   
    
    # Boucle pour parcourir les pages
    while current_page < start_page + step:
        # Construire l'URL de la page actuelle


        url = base_url + str(current_page)
        time.sleep(random.uniform(2, 6))

        # Charger la page web
        try:
            driver.set_page_load_timeout(120)
            driver.get(url)
        except TimeoutException:
            print(f"TimeoutException: Unable to load {link}")
        try:
            # Insérer ici le code pour extraire les liens ou effectuer d'autres opérations sur la page
            all_links = driver.find_elements(By.XPATH, xpath_expression)
            links = []
            # Ajouter les liens à la liste
            links.extend(link.get_attribute("href") for link in all_links)
            print(links)
            # Parcourir chaque lien pour effectuer des opérations
            for link in links:
                try:
                    # Afficher le lien trouvé
                    print("Lien trouvé :", link)
                    data = []
                    # Accéder à la page du lien
                    driver.get(link)
                    time.sleep(random.uniform(2, 5))

                    # Insérer ici le code pour effectuer des opérations sur la page du lien

                    try:
                        time.sleep(random.uniform(2, 5))
                        nom_xpath = "//div[contains(@class, 'Text_Text_text SummaryInformation_title__5CYhW Text_Text_headline3')]"

                        nom = driver.find_element(By.XPATH, nom_xpath).text
                        print("Nom du véhicule:", nom)

                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        nom = " "
                        print("aucun nom trouvé")
                    data.append(nom)
                    try:
                        time.sleep(random.uniform(2, 5))
                        carac_xpath = "//div[contains(@class, 'Text_Text_text SummaryInformation_subtitle__M7MAb Text_Text_body2')]"
                        carac = driver.find_element(By.XPATH, carac_xpath).text
                        #print("Carac:", carac)

                        # Diviser le texte en éléments
                        elements = carac.split()
                        action_aleatoire(driver)
                        # Variables pour stocker les informations
                        cylindree_moteur = ""
                        type_moteur = ""
                        puissance = ""
                        finition = ""

                        # Utiliser un indicateur pour savoir quel type d'information on traite actuellement
                        current_type = None

                        # Parcourir les éléments et attribuer aux variables appropriées
                        for element in elements:
                            # Vérifier s'il s'agit de la cylindrée du moteur (exprimée en centimètres cubes)
                            if element.replace(".", "").isdigit() and not cylindree_moteur:
                                cylindree_moteur = element
                            # Vérifier s'il s'agit du type de moteur (contient des lettres)
                            elif any(char.isalpha() for char in element) and not type_moteur:
                                type_moteur = element
                            # Vérifier s'il s'agit de la puissance (contient des chiffres)
                            elif element.isdigit() and not puissance:
                                puissance = element
                            # Si ce n'est ni la cylindrée, ni le type, ni la puissance, c'est probablement la finition
                            elif not finition:
                                finition += element + " "

                        cylindree_moteur = cylindree_moteur.strip()
                        type_moteur = type_moteur.strip()
                        puissance = puissance.strip()
                        finition = finition.strip()
                        # Afficher les résultats
                        #print("Cylindrée du moteur:", cylindree_moteur.strip())
                        #print("Type de moteur:", type_moteur.strip())
                        #print("Puissance:", puissance.strip())
                        #print("Finition:", finition.strip())
                        data.append((cylindree_moteur,type_moteur,puissance,finition))
                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        carac = " "
                        print("Carac non trouvé")
                    try:
                        prix_xpath = "//span[contains(@class, 'PriceInformation_classifiedPrice__b-Jae')]"

                        prix = driver.find_element(By.XPATH, prix_xpath).text
                       # print("prix:", prix)
                        time.sleep(random.uniform(2, 4))
                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        prix = " "
                        print("aucun nom trouvé")
                    data.append(prix)
                    try:
                        duree_publi_xpath = "//div[contains(@class, 'Text_Text_text Text_Text_body2')]"

                        duree_publi = driver.find_element(By.XPATH, duree_publi_xpath).text
                       # print("publié depuis:",  duree_publi)
                        time.sleep(random.uniform(2, 5))
                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        durée_publi = " "
                        print("no durée publi renseigné")
                    data.append(duree_publi)
                    try:
                        volume_coffre_xpath = "//div[contains(@class, 'Gauge_Gauge_gaugeWrapper')]//button[contains(@class, 'Gauge_Gauge_value Button_Button_button Button_Button_shaded Button_Button_small Button_Button_square')]//span[contains(@class, 'Text_Text_text Text_Text_label2')]"
                        volume_coffre_element = WebDriverWait(driver, 15).until(
                                EC.presence_of_element_located((By.XPATH, volume_coffre_xpath))
                        )

                        volume_coffre = volume_coffre_element.get_attribute('textContent')
                        # print("volume_coffre", volume_coffre)
                        time.sleep(random.uniform(2, 3))
                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        volume_coffre = " "
                        print("no volume_coffrerenseigné")
                    except TimeoutException:
                        # Gérer la TimeoutException ici
                        print("Élément non trouvé après 15 secondes. Continuer avec le reste du code.")
                        volume_coffre = " "
                    data.append(volume_coffre)
                    try:
                        spans_xpath = "//span[contains(@class, 'Text_Text_text Icon-button_IconButton_label Text_Text_label2')]"
                        action_aleatoire(driver)
                        spans = driver.find_elements(By.XPATH, spans_xpath)
                        time.sleep(random.uniform(2, 4))
        # Nombre de spans
                        num_spans = len(spans)
                        point_forts_values = []
        # Créer des variables dynamiquement
                        for index, span in enumerate(spans, start=1):
            # Utilisation de JavaScript pour extraire le texte
                            span_text = driver.execute_script("return arguments[0].textContent;", span)
                            variable_name = f"point_fort{index}"
                            locals()[variable_name] = span_text.strip()
                             #print(f"{variable_name}:", locals()[variable_name])
                            point_forts_values.append(locals()[variable_name])


                    except NoSuchElementException:
        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        for index in range(1, num_spans + 1):
                            variable_name = f"point_fort{index}"
                            locals()[variable_name] = " "
                            print(f"{variable_name}: not found")
                            point_forts_values.append(locals()[variable_name])

                        # Ajouter le tuple de valeurs des points forts à la liste data
                    data.append(tuple(point_forts_values))
                    h3_values = []
                    try:
                        h3_xpath = "//h3[contains(@class, 'Text_Text_text Text_Text_subtitle1')]"

                        h3_elements = driver.find_elements(By.XPATH, h3_xpath)
                        time.sleep(random.uniform(2, 3))

                        for h3_element in h3_elements:
                            try:
                                ul_element = h3_element.find_element(By.XPATH, "following-sibling::ul")

                                li_elements = ul_element.find_elements(By.XPATH, "li")
                                li_values = []
                                time.sleep(random.uniform(2, 3))
                                for index, li_element in enumerate(li_elements, start=0):
                                    
                                    try:
                                        # Essayer de trouver le texte du span directement
                                        first_span_xpath = ".//span[contains(@class, 'Text_Text_text Text_Text_subtitle2')]"
                                        first_span_element = find_element_with_retry(li_element, By.XPATH, first_span_xpath)
                                        variable_name = first_span_element.get_attribute('textContent')

                                        span_xpath = ".//span[@class='Item_content__Xyd3d']"
                                        span_element = find_element_with_retry(li_element, By.XPATH, span_xpath)
                                        variable_value = span_element.get_attribute('textContent')

                                    except NoSuchElementException:
                                        # Si le premier essai échoue, essayer de trouver le texte du span à l'intérieur
                                        span_xpath = ".//span[@class='Item_content__Xyd3d']//span"
                                        span_element = find_element_with_retry(li_element, By.XPATH, span_xpath)
                                        variable_value = span_element.get_attribute('textContent')
                                    li_values.append((variable_name, variable_value))
                                    # Maintenant, vous avez la valeur du texte du span, que ce soit directement ou à l'intérieur
                                    #print(f"Nom de la variable : {variable_name}, Valeur de la variable : {variable_value}")
                                h3_values.append(tuple(li_values))

                            except NoSuchElementException:
                                pass

                    except NoSuchElementException:
                        print("H3 non trouvé")
                    data.append(tuple(h3_values))
                    ########################EN COURS######################  
                    button_class_name = "Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline"

                    try:
                        # Find the button using its class name
                        button = driver.find_element(By.CLASS_NAME, button_class_name)

                        # Click the button
                        button.click()

                        print("Button clicked successfully")

                    except NoSuchElementException:
                        print(f"Button with class name '{button_class_name}' not found")
                    except Exception as e:
                        print(f"An error occurred: {e}")

                    ####Scrappe equipement####
                    xpath_button_options = "//div[contains(@class, 'EquipmentOptionsInformation_linkMoreEquipments__rd-QS')]//button[contains(@class, 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline')]"
                    try:
                        # Attendre que le bouton soit cliquable
                        button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, xpath_button_options)))

                        # Utiliser ActionChains pour survoler et cliquer sur le bouton
                        action = ActionChains(driver)
                        action.move_to_element(button).click().perform()

                        print("Button clicked successfully")

                    except NoSuchElementException:
                        print(f"Button with XPath '{xpath_button_options}' not found")
                    except Exception as e:
                        print(f"An error occurred: {e}")

                    ####Scrappe equipement####
                    # Dictionnaire pour stocker les résultats
                    results = {}



                    # XPath pour sélectionner les uls
                    ul_xpaths = "//ul[contains(@class, 'EquipmentOptionsInformation_column__rQp-a')]"

                    # Parcourir les uls
                    uls = driver.find_elements(By.XPATH, ul_xpaths)
                    action_aleatoire(driver)
                    time.sleep(random.uniform(2, 5))
                    # Parcourir chaque ul
                    for ul_index, ul_element in enumerate(uls, start=1):
                        try:
                            # Trouver tous les li dans l'ul actuel
                            li_elements = ul_element.find_elements(By.XPATH, "./li")

                            # Parcourir chaque li
                            
                            for li_index, li_element in enumerate(li_elements, start=1):
                                # Obtenir tous les éléments h3 et div à l'intérieur du li
                                h3_elements = li_element.find_elements(By.XPATH, "./h3")
                                div_elements = li_element.find_elements(By.XPATH, "./div")

                                # Concaténer les textcontents de tous les h3 et div
                                li_textcontent = " ".join(element.get_attribute('textContent') for element in h3_elements + div_elements)

                                # Ajouter le résultat au dictionnaire
                                results[f"ul{ul_index}_li{li_index}"] = f",{li_textcontent}"

                        except NoSuchElementException:
                            print("UL non trouvé")

                    # Afficher les résultats
                    #for key, value in results.items():
                        #print(f"{key}: {value}")
                    data.append(tuple(results.values()))
                    data_final.append(data)
                    time.sleep(random.uniform(2, 3))
                    #print(data_final)
                    print("+1")
                    csv_file_path = "data.csv"
                    csv_columns = [
                        "Nom du véhicule",
                        "Caractéristiques",
                        "Prix",
                        "Durée de publication",
                        "Volume du coffre",
                        "Points forts",
                        "Équipements"
                    ]


                    with open('thread2.csv', 'a', newline='', encoding='utf-8') as csvfile:
                        csv_writer = csv.writer(csvfile)
                        csv_writer.writerow(data)       



                except StaleElementReferenceException:
                    # Si l'élément de lien est obsolète, afficher un message
                    print("StaleElementReferenceException pour le lien :", link.get_attribute("href"))

                except StaleElementReferenceException:
                    # Si l'élément de lien est obsolète, afficher un message
                    print("StaleElementReferenceException pour le lien :", link)
                    pass
                except TimeoutException as e:
                    print(f"TimeoutException: {e}")
                    pass
                    # Handle the timeout exception
                except WebDriverException as e:
                    print(f"WebDriverException: {e}")
                    pass
        except StaleElementReferenceException:
            # If the element is stale, refind the links and continue
            print("StaleElementReferenceException. Refinding links.")
            links = driver.find_elements(By.XPATH, xpath_expression)
            continue
        except NoSuchElementException:
            # Si l'élément n'est pas trouvé, cela signifie probablement que la page n'existe pas
            print("Fin de la boucle : La page", current_page, "n'existe pas.")
            pass
        # Passer à la page suivante
        current_page += 1
        

    # Fermer le navigateur à la fin
    driver.quit()

# Number of threads
num_threads = 7

# Create a list to store WebDriver instances
drivers = [initialize_driver() for _ in range(num_threads)]

# Define the range of pages you want to scrape
start_page = 0
end_page = 500
# Calculate the step size to distribute pages evenly
step = (end_page - start_page) // num_threads
# Create a list to store thread links
thread_links = [[] for _ in range(num_threads)]
# Use ThreadPoolExecutor to run tasks concurrently
with ThreadPoolExecutor(max_workers=num_threads) as executor:
    # Submit tasks to the pool for the specified range of pages
    futures = [executor.submit(scrape_page, base_url, page, step, driver, thread_links[i]) for i, (page, driver) in enumerate(zip(range(start_page, end_page, step), drivers))]

    # Wait for all tasks to complete
    for future in futures:
        future.result()

# Close the WebDriver instances
for driver in drivers:
    driver.quit()
# Out:
# ['https://www.lacentrale.fr/auto-occasion-annonce-69112997227.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113156609.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112927612.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102820976.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113140547.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111740720.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102663197.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112896563.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113216716.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113102010.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102708815.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102778657.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102808713.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112395876.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112916225.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112071360.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112997227.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113022243.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112063396.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102751926.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113142182.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113022046.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112960764.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113174767.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113174856.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112060093.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112630381.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113006342.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111694896.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112963434.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112766440.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102736411.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112742571.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113022243.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69112785721.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102793479.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112114255.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112386860.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102803835.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102747883.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102773919.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113107012.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112944284.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112975226.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113174772.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102809055.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113181488.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113158583.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113075579.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113185492.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112785721.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113062554.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102813595.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113072854.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102813657.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102816006.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113115585.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113121127.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113014538.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102407120.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113083696.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102523632.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113037517.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112577170.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112806954.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102787897.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112700533.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113062554.html
# StaleElementReferenceException. Refinding links.
# ['https://www.lacentrale.fr/auto-occasion-annonce-69112703568.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113012624.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113145505.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113108249.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112812669.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112821375.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112795081.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113156658.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113096583.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112622053.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112977381.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113010485.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112861838.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113225327.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113110264.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113129523.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112703568.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113170610.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112910156.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113142099.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102818067.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112956067.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112921037.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113142149.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102731141.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113224390.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112823524.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112992049.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112082761.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113050558.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112743501.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112834758.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112970163.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113170610.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113206884.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113095724.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112785056.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113124035.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113144384.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112663112.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112416801.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112725920.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113158679.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113186573.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113142173.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102744839.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111934068.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113147816.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102809573.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113003203.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113206884.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113220575.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102805749.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113087955.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113220704.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102670818.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113157052.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102792962.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102708846.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113221117.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113142179.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102682356.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112950512.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102773380.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102765888.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113056156.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113200883.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113220575.html
# Nom du véhicule: FORD FOCUS 4
# Nom du véhicule: CITROEN C5 AIRCROSS
# Nom du véhicule: PEUGEOT 108
# Nom du véhicule: SKODA SUPERB III COMBI phase 2
# Nom du véhicule: CITROEN C3 AIRCROSS
# Nom du véhicule: BMW X1 F48
# Nom du véhicule: AUDI A5 SPORTBACK
# Nom du véhicule: VOLKSWAGEN GOLF 7 SW
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112063396.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Nom du véhicule: RENAULT MEGANE IV ESTATE
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113012624.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102793479.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112910156.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102813595.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113095724.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102805749.html
# Nom du véhicule: VOLVO XC90 II phase 2
# Nom du véhicule: CITROEN C4 PICASSO II
# Nom du véhicule: RENAULT KADJAR phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113156609.html
# Nom du véhicule: CHEVROLET CORVETTE C7 STINGRAY TARGA
# Nom du véhicule: DACIA SPRING
# Nom du véhicule: BMW X6 F16
# Nom du véhicule: AUDI Q5 II phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102751926.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113142099.html
# aucun nom trouvé
# An error occurred: Message:
#
# Carac non trouvé
# aucun nom trouvé
# no durée publi renseigné
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112114255.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113072854.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113145505.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112785056.html
# aucun nom trouvé
# aucun nom trouvé
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113087955.html
# aucun nom trouvé
# Carac non trouvé
# aucun nom trouvé
# no durée publi renseigné
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112927612.html
# aucun nom trouvé
# Carac non trouvé
# aucun nom trouvé
# no durée publi renseigné
# aucun nom trouvé
# Carac non trouvé
# aucun nom trouvé
# no durée publi renseigné
# aucun nom trouvé
# Carac non trouvé
# aucun nom trouvé
# no durée publi renseigné
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Carac non trouvé
# aucun nom trouvé
# no durée publi renseigné
# aucun nom trouvé
# Carac non trouvé
# aucun nom trouvé
# no durée publi renseigné
# Carac non trouvé
# aucun nom trouvé
# no durée publi renseigné
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# TimeoutException: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113142182.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# aucun nom trouvé
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# TimeoutException: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102818067.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Carac non trouvé
# aucun nom trouvé
# no durée publi renseigné
# TimeoutException: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102813657.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# TimeoutException: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112386860.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# TimeoutException: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113220704.html
# Nom du véhicule: ALFA ROMEO 147
# Nom du véhicule: JAGUAR F-PACE phase 2
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Nom du véhicule: PEUGEOT 308 III
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113124035.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113108249.html
# Nom du véhicule: PEUGEOT 3008 II phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102820976.html
# Nom du véhicule: FORD FOCUS IV
# Nom du véhicule: AUDI TT II ROADSTER phase 2
# TimeoutException: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113022046.html
# Nom du véhicule: LEXUS NX
# Nom du véhicule: PEUGEOT 208 II
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102816006.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112956067.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102803835.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102670818.html
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT 208 II
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: CITROEN C4 SPACETOURER
# An error occurred: Message:
#
# Nom du véhicule: MERCEDES GLE
# Nom du véhicule: PORSCHE 911 TYPE 992 CABRIOLET
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112812669.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113144384.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113140547.html
# Nom du véhicule: CITROEN C3 III phase 2
# Nom du véhicule: MINI III CABRIOLET
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112960764.html
# Nom du véhicule: RENAULT MEGANE IV RS
# Nom du véhicule: VOLKSWAGEN TIGUAN II
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113115585.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112921037.html
# Nom du véhicule: AUDI Q2 phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102747883.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113157052.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: PEUGEOT 3008 II
# Nom du véhicule: TRIUMPH TR 4
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Nom du véhicule: NISSAN LEAF II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112821375.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112663112.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111740720.html
# Nom du véhicule: PEUGEOT 5008 II phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113174767.html
# Nom du véhicule: TOYOTA RAV 4 II phase 2
# Nom du véhicule: PEUGEOT 3008 II phase 2
# Nom du véhicule: VOLKSWAGEN GOLF VII SW phase 2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113121127.html
# An error occurred: Message:
#
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: RENAULT MEGANE IV
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113142149.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102773919.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102792962.html
# Nom du véhicule: FORD PUMA 2
# An error occurred: Message:
#
# Nom du véhicule: MERCEDES CLASSE E V COUPE
# An error occurred: Message:
#
# An error occurred: Message:
#
# Nom du véhicule: SEAT LEON III
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112795081.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102663197.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112416801.html
# Nom du véhicule: AUDI S7 SPORTBACK
# Nom du véhicule: AUDI A3 (3E GENERATION) SPORTBACK
# Nom du véhicule: NISSAN QASHQAI II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113174856.html
# Nom du véhicule: VOLKSWAGEN GOLF VIII
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113014538.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: VOLKSWAGEN T-ROC
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113107012.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102708846.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT 3008 II
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112725920.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102731141.html
# Nom du véhicule: PEUGEOT BOXER II phase 2
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112896563.html
# +1
# Nom du véhicule: PORSCHE 718 BOXSTER
# Nom du véhicule: MINI MINI III 5P
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113156658.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112060093.html
# Nom du véhicule: PEUGEOT 2008 phase 2
# Nom du véhicule: RENAULT TALISMAN ESTATE
# Nom du véhicule: AUDI A4 V AVANT phase 3
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102407120.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: OPEL CORSA VI
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112944284.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT 308 III
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113158679.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113221117.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113224390.html
# Nom du véhicule: AUDI A3 IV SPORTBACK
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113216716.html
# Nom du véhicule: VOLKSWAGEN T-ROC
# An error occurred: Message:
#
# Nom du véhicule: PORSCHE 911 TYPE 991
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112630381.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113096583.html
# Nom du véhicule: FIAT DUCATO
# Nom du véhicule: PEUGEOT 3008 II
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: AUDI A4 V AVANT phase 3
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113083696.html
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: OPEL CORSA 6
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112975226.html
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: OPEL GRANDLAND X
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112823524.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113186573.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113142179.html
# An error occurred: Message:
#
# Nom du véhicule: BMW SERIE 3 G20 phase 2
# Nom du véhicule: DODGE RAM
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113102010.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113006342.html
# Nom du véhicule: CITROEN C3 AIRCROSS
# Nom du véhicule: RENAULT CAPTUR II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112622053.html
# Nom du véhicule: VOLKSWAGEN TOURAN III
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: BMW SERIE 1 F20 5 PORTES phase 2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102523632.html
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113174772.html
# Nom du véhicule: OPEL ZAFIRA III phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: LAND ROVER RANGE ROVER EVOQUE phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112992049.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113142173.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102708815.html
# Nom du véhicule: LAND ROVER RANGE ROVER IV
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102682356.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111694896.html
# Nom du véhicule: CITROEN C4 (3E GENERATION)
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT 5008 II
# Nom du véhicule: BMW SERIE 6 E64 CABRIOLET
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112977381.html
# Nom du véhicule: AUDI A4 V
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: BMW X4 F26
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113037517.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102809055.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: FIAT 500 II phase 2
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: BENTLEY FLYING SPUR 3 phase 3
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112082761.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102744839.html
# Nom du véhicule: PEUGEOT 508 II SW
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102778657.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112950512.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112963434.html
# Nom du véhicule: CHEVROLET CORVETTE C8 STINGRAY CONVERTIBLE
# Nom du véhicule: BMW X2 F39
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113010485.html
# Nom du véhicule: PORSCHE MACAN phase 2
# Nom du véhicule: VOLKSWAGEN TIGUAN 2
# Nom du véhicule: PEUGEOT 308 II SW phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112577170.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113181488.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: RENAULT KANGOO II EXPRESS phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: SUBARU IMPREZA II phase 3
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113050558.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Nom du véhicule: MERCEDES CLASSE E IV
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102808713.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111934068.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102773380.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112766440.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112861838.html
# Nom du véhicule: PEUGEOT E-2008 II
# Nom du véhicule: VOLKSWAGEN T-ROC
# Nom du véhicule: AUDI Q2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Nom du véhicule: DS 7 CROSSBACK
# Nom du véhicule: PORSCHE 911 TYPE 991 TARGA phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113158583.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112806954.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: PEUGEOT PARTNER III FOURGON
# Nom du véhicule: JEEP AVENGER
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112743501.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Nom du véhicule: TESLA MODEL S phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102736411.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102765888.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112395876.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113147816.html
# Nom du véhicule: PEUGEOT RCZ
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113225327.html
# Nom du véhicule: RENAULT CAPTUR II
# Nom du véhicule: VOLKSWAGEN TIGUAN
# Nom du véhicule: VOLKSWAGEN TIGUAN II
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Nom du véhicule: LAND ROVER RANGE ROVER EVOQUE phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113075579.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102787897.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Nom du véhicule: VOLKSWAGEN AMAROK phase 3
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Nom du véhicule: CITROEN C3 AIRCROSS
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112834758.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112742571.html
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT 2008 II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113056156.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112916225.html
# Nom du véhicule: PORSCHE MACAN
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102809573.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113110264.html
# Nom du véhicule: RENAULT CLIO IV phase 2
# Nom du véhicule: PEUGEOT 5008 II
# Nom du véhicule: FIAT SCUDO III
# Nom du véhicule: MERCEDES GLE
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# An error occurred: Message:
#
# An error occurred: Message:
#
# ...
# An error occurred: Message:
#
# Nom du véhicule: RENAULT MASTER III phase 2
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112862927.html
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113142455.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113123989.html
# Nom du véhicule: IVECO DAILY 5
# An error occurred: Message:
# An error occurred: Message:
#
#
# Nom du véhicule: MERCEDES GLE II
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113099787.html
# Nom du véhicule: KIA E-NIRO phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113158979.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102763909.html
# Nom du véhicule: FERRARI 488 GTB
# Nom du véhicule: LAND ROVER RANGE ROVER SPORT II phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: MERCEDES-AMG GT
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112173602.html
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112385389.html
# Nom du véhicule: OPEL GRANDLAND X
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Nom du véhicule: DS 3 CROSSBACK
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112684467.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102821292.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112157751.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113193246.html
# Nom du véhicule: BMW X1 F48 phase 2
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112385347.html
# Nom du véhicule: VOLKSWAGEN TIGUAN II
# Nom du véhicule: CITROEN C3 AIRCROSS
# Nom du véhicule: PEUGEOT E-2008 II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113199428.html
# Nom du véhicule: PEUGEOT 3008 II phase 2
# Nom du véhicule: CITROEN C3 III phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112913994.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102708876.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: PEUGEOT 308 II phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: CITROEN JUMPER II phase 2
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112294594.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113093617.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# Nom du véhicule: CITROEN C3 AIRCROSS phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112618824.html
# An error occurred: Message:
#
# Nom du véhicule: OPEL CORSA 5
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113169448.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113155509.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102812237.html
# Nom du véhicule: HYUNDAI I20 II COUPE
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Nom du véhicule: PEUGEOT 2008 II
# Nom du véhicule: CHEVROLET CAMARO VI
# Nom du véhicule: CITROEN C5 AIRCROSS
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112956948.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113138648.html
# Nom du véhicule: MERCEDES GLB
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT 2008 phase 2
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112866503.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112534909.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112759004.html
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT 2008 II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113226576.html
# Nom du véhicule: MERCEDES GLA II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112924548.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113062469.html
# Nom du véhicule: VOLKSWAGEN GOLF VIII
# Nom du véhicule: BMW SERIE 6 F06 GRAN COUPE
# Nom du véhicule: CITROEN C3 AIRCROSS
# Nom du véhicule: VOLKSWAGEN ID.5
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102725615.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112864238.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: PORSCHE 911 TYPE 992 CABRIOLET
# Nom du véhicule: PEUGEOT 208 II
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112775382.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113224392.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102615716.html
# Nom du véhicule: VOLKSWAGEN T-ROC CABRIOLET
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111722313.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112284278.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113032215.html
# Nom du véhicule: CITROEN C5 AIRCROSS phase 2
# Nom du véhicule: MINI COUNTRYMAN phase 2
# Nom du véhicule: AUDI A3 IV SPORTBACK
# Nom du véhicule: RENAULT SCENIC 3
# Nom du véhicule: VOLKSWAGEN T-ROC phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113195011.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102804027.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: AUDI A4 V AVANT
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: PORSCHE MACAN
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112824125.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111988199.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113174759.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112845624.html
# Nom du véhicule: AUDI Q2 phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113180202.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111976885.html
# Nom du véhicule: RENAULT TRAFIC III
# Nom du véhicule: CITROEN BERLINGO II MULTISPACE
# Nom du véhicule: PEUGEOT 3008 II
# Nom du véhicule: RENAULT KANGOO III EXPRESS
# Nom du véhicule: AUDI A6 (5E GENERATION) AVANT
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112385354.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112870239.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: PEUGEOT 3008 II phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Nom du véhicule: OPEL GRANDLAND X
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112897762.html
# An error occurred: Message:
#
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113230698.html
# Nom du véhicule: CITROEN C4 SPACETOURER
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113062546.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102821104.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112610617.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113013558.html
# Nom du véhicule: VOLKSWAGEN T-ROC phase 2
# Nom du véhicule: FIAT 500 X phase 2
# Nom du véhicule: JEEP RENEGADE phase 2
# Nom du véhicule: PEUGEOT 207 phase 2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Nom du véhicule: PEUGEOT 3008 II
