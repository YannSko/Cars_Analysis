# %% [markdown]
# Lien du site :
# https://www.lacentrale.fr/auto-occasion-annonce-69113195868.html

# %% [markdown]
# # Scrappe la centrale

# %% [markdown]
# ### Import

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import pandas as pd
import urllib
import re
import requests
import csv
import time

from selenium.webdriver.common.service import Service
from selenium.webdriver.common.service import Service
from fake_useragent import UserAgent
from urllib3.exceptions import NewConnectionError
import logging
from datetime import datetime, timedelta
from selenium.common.exceptions import ElementClickInterceptedException

import pandas as pd 
import numpy as np 

import random
from selenium.webdriver.common.action_chains import ActionChains
from itertools import combinations

# %% [markdown]
# ### Scrappe

# %% [markdown]
# Fake Action

# %%
def action_aleatoire(driver):
    actions_possibles = ["scroll_full", "scroll_half", "move_to_element"]
    action_choisie = random.choice(actions_possibles)

    # Enregistrer la position actuelle de la page
    current_scroll_position = driver.execute_script("return window.pageYOffset;")

    if action_choisie == "scroll_full":
        # Action aléatoire : Faites défiler la page vers le bas
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    elif action_choisie == "scroll_half":
        # Action aléatoire : Faites défiler la moitié de la page vers le bas
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight / 2);")
    elif action_choisie == "move_to_element":
        # Action aléatoire : Bougez la souris vers un élément aléatoire (par exemple, div de class PriceInformation_classifiedPrice__b-Jae)
        wait = WebDriverWait(driver, 10)
        element_to_move = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'PriceInformation_classifiedPrice__b-Jae')))
        driver.execute_script("arguments[0].scrollIntoView();", element_to_move)

    # Revenir à la position enregistrée
    driver.execute_script(f"window.scrollTo(0, {current_scroll_position});")

# %%
def find_element_with_retry(driver, by, value, max_retries=3):
    retries = 0
    while retries < max_retries:
        try:
            element = driver.find_element(by, value)
            return element
        except NoSuchElementException:
            retries += 1
            time.sleep(2)  # Add a small delay before retrying
    raise NoSuchElementException(f"Element not found after {max_retries} retries")

# %% [markdown]
# Scrape

# %% [markdown]
# import time
# import random
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
# from fake_useragent import UserAgent
# from selenium.common.exceptions import WebDriverException
# # Configurations du navigateur
# ua = UserAgent()
# user_agent = ua.random
# options = webdriver.FirefoxOptions()
# options.add_argument('--headless')
# options.add_argument(f'user-agent={user_agent}')
#
# # Initialisation du navigateur
# driver = webdriver.Firefox(options=options)
# base_url = "https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page="
# xpath_expression = "//a[contains(@class, 'Vehiculecard_Vehiculecard_vehiculeCard Containers_Containers_containers Containers_Containers_borderRadius Containers_Containers_darkShadowWide')]"
# data_final = []
# # Numéro de la première page à visiter
# current_page = 0
#
# # Boucle pour parcourir les pages
# while True:
#     # Construire l'URL de la page actuelle
#
#
#     url = base_url + str(current_page)
#     time.sleep(random.uniform(2, 6))
#
#     # Charger la page web
#     try:
#         driver.set_page_load_timeout(120)
#         driver.get(url)
#     except TimeoutException:
#         print(f"TimeoutException: Unable to load {link}")
#     try:
#         # Insérer ici le code pour extraire les liens ou effectuer d'autres opérations sur la page
#         links = driver.find_elements(By.XPATH, xpath_expression)
#         all_links = []
#         # Ajouter les liens à la liste
#         all_links.extend(link.get_attribute("href") for link in links)
#         print(all_links)
#         # Parcourir chaque lien pour effectuer des opérations
#         for link in all_links:
#             try:
#                 # Afficher le lien trouvé
#                 print("Lien trouvé :", link)
#                 data = []
#                 # Accéder à la page du lien
#                 driver.get(link)
#                 time.sleep(random.uniform(2, 5))
#
#                 # Insérer ici le code pour effectuer des opérations sur la page du lien
#
#                 try:
#                     nom_xpath = "//div[contains(@class, 'Text_Text_text SummaryInformation_title__5CYhW Text_Text_headline3')]"
#
#                     nom = driver.find_element(By.XPATH, nom_xpath).text
#                     print("Nom du véhicule:", nom)
#
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     nom = " "
#                     print("aucun nom trouvé")
#                 data.append(nom)
#                 try:
#                     carac_xpath = "//div[contains(@class, 'Text_Text_text SummaryInformation_subtitle__M7MAb Text_Text_body2')]"
#                     carac = driver.find_element(By.XPATH, carac_xpath).text
#                     #print("Carac:", carac)
#
#                     # Diviser le texte en éléments
#                     elements = carac.split()
#                     action_aleatoire(driver)
#                     # Variables pour stocker les informations
#                     cylindree_moteur = ""
#                     type_moteur = ""
#                     puissance = ""
#                     finition = ""
#
#                     # Utiliser un indicateur pour savoir quel type d'information on traite actuellement
#                     current_type = None
#
#                     # Parcourir les éléments et attribuer aux variables appropriées
#                     for element in elements:
#                         # Vérifier s'il s'agit de la cylindrée du moteur (exprimée en centimètres cubes)
#                         if element.replace(".", "").isdigit() and not cylindree_moteur:
#                             cylindree_moteur = element
#                         # Vérifier s'il s'agit du type de moteur (contient des lettres)
#                         elif any(char.isalpha() for char in element) and not type_moteur:
#                             type_moteur = element
#                         # Vérifier s'il s'agit de la puissance (contient des chiffres)
#                         elif element.isdigit() and not puissance:
#                             puissance = element
#                         # Si ce n'est ni la cylindrée, ni le type, ni la puissance, c'est probablement la finition
#                         elif not finition:
#                             finition += element + " "
#
#                     cylindree_moteur = cylindree_moteur.strip()
#                     type_moteur = type_moteur.strip()
#                     puissance = puissance.strip()
#                     finition = finition.strip()
#                     # Afficher les résultats
#                     #print("Cylindrée du moteur:", cylindree_moteur.strip())
#                     #print("Type de moteur:", type_moteur.strip())
#                     #print("Puissance:", puissance.strip())
#                     #print("Finition:", finition.strip())
#                     data.append((cylindree_moteur,type_moteur,puissance,finition))
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     carac = " "
#                     print("Carac non trouvé")
#                 try:
#                     prix_xpath = "//span[contains(@class, 'PriceInformation_classifiedPrice__b-Jae')]"
#
#                     prix = driver.find_element(By.XPATH, prix_xpath).text
#                    # print("prix:", prix)
#                     time.sleep(random.uniform(2, 4))
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     prix = " "
#                     print("aucun nom trouvé")
#                 data.append(prix)
#                 try:
#                     duree_publi_xpath = "//div[contains(@class, 'Text_Text_text Text_Text_body2')]"
#
#                     duree_publi = driver.find_element(By.XPATH, duree_publi_xpath).text
#                    # print("publié depuis:",  duree_publi)
#                     time.sleep(random.uniform(2, 5))
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     durée_publi = " "
#                     print("no durée publi renseigné")
#                 data.append(duree_publi)
#                 try:
#                     volume_coffre_xpath = "//div[contains(@class, 'Gauge_Gauge_gaugeWrapper')]//button[contains(@class, 'Gauge_Gauge_value Button_Button_button Button_Button_shaded Button_Button_small Button_Button_square')]//span[contains(@class, 'Text_Text_text Text_Text_label2')]"
#                     volume_coffre_element = WebDriverWait(driver, 15).until(
#                             EC.presence_of_element_located((By.XPATH, volume_coffre_xpath))
#                     )
#
#                     volume_coffre = volume_coffre_element.get_attribute('textContent')
#                     # print("volume_coffre", volume_coffre)
#                     time.sleep(random.uniform(2, 3))
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     volume_coffre = " "
#                     print("no volume_coffrerenseigné")
#                 except TimeoutException:
#                     # Gérer la TimeoutException ici
#                     print("Élément non trouvé après 15 secondes. Continuer avec le reste du code.")
#                     volume_coffre = " "
#                 data.append(volume_coffre)
#                 try:
#                     spans_xpath = "//span[contains(@class, 'Text_Text_text Icon-button_IconButton_label Text_Text_label2')]"
#                     action_aleatoire(driver)
#                     spans = driver.find_elements(By.XPATH, spans_xpath)
#                     time.sleep(random.uniform(2, 4))
#     # Nombre de spans
#                     num_spans = len(spans)
#                     point_forts_values = []
#     # Créer des variables dynamiquement
#                     for index, span in enumerate(spans, start=1):
#         # Utilisation de JavaScript pour extraire le texte
#                         span_text = driver.execute_script("return arguments[0].textContent;", span)
#                         variable_name = f"point_fort{index}"
#                         locals()[variable_name] = span_text.strip()
#                          #print(f"{variable_name}:", locals()[variable_name])
#                         point_forts_values.append(locals()[variable_name])
#
#
#                 except NoSuchElementException:
#     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     for index in range(1, num_spans + 1):
#                         variable_name = f"point_fort{index}"
#                         locals()[variable_name] = " "
#                         print(f"{variable_name}: not found")
#                         point_forts_values.append(locals()[variable_name])
#
#                     # Ajouter le tuple de valeurs des points forts à la liste data
#                 data.append(tuple(point_forts_values))
#                 h3_values = []
#                 try:
#                     h3_xpath = "//h3[contains(@class, 'Text_Text_text Text_Text_subtitle1')]"
#
#                     h3_elements = driver.find_elements(By.XPATH, h3_xpath)
#                     time.sleep(random.uniform(2, 3))
#
#                     for h3_element in h3_elements:
#                         try:
#                             ul_element = h3_element.find_element(By.XPATH, "following-sibling::ul")
#
#                             li_elements = ul_element.find_elements(By.XPATH, "li")
#                             li_values = []
#                             for index, li_element in enumerate(li_elements, start=0):
#                                 time.sleep(random.uniform(2, 5))
#
#                                 try:
#                                     # Essayer de trouver le texte du span directement
#                                     first_span_xpath = ".//span[contains(@class, 'Text_Text_text Text_Text_subtitle2')]"
#                                     first_span_element = find_element_with_retry(li_element, By.XPATH, first_span_xpath)
#                                     variable_name = first_span_element.get_attribute('textContent')
#
#                                     span_xpath = ".//span[@class='Item_content__Xyd3d']"
#                                     span_element = find_element_with_retry(li_element, By.XPATH, span_xpath)
#                                     variable_value = span_element.get_attribute('textContent')
#
#                                 except NoSuchElementException:
#                                     # Si le premier essai échoue, essayer de trouver le texte du span à l'intérieur
#                                     span_xpath = ".//span[@class='Item_content__Xyd3d']//span"
#                                     span_element = find_element_with_retry(li_element, By.XPATH, span_xpath)
#                                     variable_value = span_element.get_attribute('textContent')
#                                 li_values.append((variable_name, variable_value))
#                                 # Maintenant, vous avez la valeur du texte du span, que ce soit directement ou à l'intérieur
#                                 #print(f"Nom de la variable : {variable_name}, Valeur de la variable : {variable_value}")
#                             h3_values.append(tuple(li_values))
#
#                         except NoSuchElementException:
#                             pass
#
#                 except NoSuchElementException:
#                     print("H3 non trouvé")
#                 data.append(tuple(h3_values))
#                 ########################EN COURS######################
#                 button_class_name = "Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline"
#
#                 try:
#                     # Find the button using its class name
#                     button = driver.find_element(By.CLASS_NAME, button_class_name)
#
#                     # Click the button
#                     button.click()
#
#                     print("Button clicked successfully")
#
#                 except NoSuchElementException:
#                     print(f"Button with class name '{button_class_name}' not found")
#                 except Exception as e:
#                     print(f"An error occurred: {e}")
#
#                 ####Scrappe equipement####
#                 xpath_button_options = "//div[contains(@class, 'EquipmentOptionsInformation_linkMoreEquipments__rd-QS')]//button[contains(@class, 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline')]"
#                 try:
#                     # Attendre que le bouton soit cliquable
#                     button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, xpath_button_options)))
#
#                     # Utiliser ActionChains pour survoler et cliquer sur le bouton
#                     action = ActionChains(driver)
#                     action.move_to_element(button).click().perform()
#
#                     print("Button clicked successfully")
#
#                 except NoSuchElementException:
#                     print(f"Button with XPath '{xpath_button_options}' not found")
#                 except Exception as e:
#                     print(f"An error occurred: {e}")
#
#                 ####Scrappe equipement####
#                 # Dictionnaire pour stocker les résultats
#                 results = {}
#
#
#
#                 # XPath pour sélectionner les uls
#                 ul_xpaths = "//ul[contains(@class, 'EquipmentOptionsInformation_column__rQp-a')]"
#
#                 # Parcourir les uls
#                 uls = driver.find_elements(By.XPATH, ul_xpaths)
#                 action_aleatoire(driver)
#                 # Parcourir chaque ul
#                 for ul_index, ul_element in enumerate(uls, start=1):
#                     try:
#                         # Trouver tous les li dans l'ul actuel
#                         li_elements = ul_element.find_elements(By.XPATH, "./li")
#
#                         # Parcourir chaque li
#                         time.sleep(random.uniform(2, 3))
#                         for li_index, li_element in enumerate(li_elements, start=1):
#                             # Obtenir tous les éléments h3 et div à l'intérieur du li
#                             h3_elements = li_element.find_elements(By.XPATH, "./h3")
#                             div_elements = li_element.find_elements(By.XPATH, "./div")
#
#                             # Concaténer les textcontents de tous les h3 et div
#                             li_textcontent = " ".join(element.get_attribute('textContent') for element in h3_elements + div_elements)
#
#                             # Ajouter le résultat au dictionnaire
#                             results[f"ul{ul_index}_li{li_index}"] = f",{li_textcontent}"
#
#                     except NoSuchElementException:
#                         print("UL non trouvé")
#
#                 # Afficher les résultats
#                 #for key, value in results.items():
#                     #print(f"{key}: {value}")
#                 data.append(tuple(results.values()))
#                 data_final.append(data)
#                 time.sleep(random.uniform(2, 3))
#                 #print(data_final)
#                 print("+1")
#                 csv_file_path = "data.csv"
#                 csv_columns = [
#                     "Nom du véhicule",
#                     "Caractéristiques",
#                     "Prix",
#                     "Durée de publication",
#                     "Volume du coffre",
#                     "Points forts",
#                     "Équipements"
#                 ]
#
#
#                 with open('data.csv', 'a', newline='', encoding='utf-8') as csvfile:
#                     csv_writer = csv.writer(csvfile)
#                     csv_writer.writerow(data)
#
#
#
#             except StaleElementReferenceException:
#                 # Si l'élément de lien est obsolète, afficher un message
#                 print("StaleElementReferenceException pour le lien :", link.get_attribute("href"))
#
#             except StaleElementReferenceException:
#                 # Si l'élément de lien est obsolète, afficher un message
#                 print("StaleElementReferenceException pour le lien :", link)
#                 pass
#             except TimeoutException as e:
#                 print(f"TimeoutException: {e}")
#                 pass
#                 # Handle the timeout exception
#             except WebDriverException as e:
#                 print(f"WebDriverException: {e}")
#                 pass
#
#     except NoSuchElementException:
#         # Si l'élément n'est pas trouvé, cela signifie probablement que la page n'existe pas
#         print("Fin de la boucle : La page", current_page, "n'existe pas.")
#         pass
#     # Passer à la page suivante
#
#     current_page += 1
#
# # Fermer le navigateur à la fin
# driver.quit()

# %% [markdown]
# ### TEST  POOL

# %%
import time
import random
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from fake_useragent import UserAgent
from selenium.common.exceptions import WebDriverException
from concurrent.futures import ThreadPoolExecutor
from selenium.common.exceptions import TimeoutException


def initialize_driver():
    ua = UserAgent()
    user_agent = ua.random
    options = webdriver.FirefoxOptions()
    options.add_argument('--headless')
    options.add_argument(f'user-agent={user_agent}')
    return webdriver.Firefox(options=options)
base_url = "https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page="
xpath_expression = "//a[contains(@class, 'Vehiculecard_Vehiculecard_vehiculeCard Containers_Containers_containers Containers_Containers_borderRadius Containers_Containers_darkShadowWide')]"
data_final = []
def scrape_page(base_url, start_page, step, driver, links):
    current_page = start_page
   
   
    
    # Boucle pour parcourir les pages
    while current_page < start_page + step:
        # Construire l'URL de la page actuelle


        url = base_url + str(current_page)
        time.sleep(random.uniform(2, 6))

        # Charger la page web
        try:
            driver.set_page_load_timeout(120)
            driver.get(url)
        except TimeoutException:
            print(f"TimeoutException: Unable to load {link}")
        try:
            # Insérer ici le code pour extraire les liens ou effectuer d'autres opérations sur la page
            all_links = driver.find_elements(By.XPATH, xpath_expression)
            links = []
            # Ajouter les liens à la liste
            links.extend(link.get_attribute("href") for link in all_links)
            print(links)
            # Parcourir chaque lien pour effectuer des opérations
            for link in links:
                try:
                    # Afficher le lien trouvé
                    print("Lien trouvé :", link)
                    data = []
                    # Accéder à la page du lien
                    driver.get(link)
                    time.sleep(random.uniform(2, 5))

                    # Insérer ici le code pour effectuer des opérations sur la page du lien

                    try:
                        time.sleep(random.uniform(2, 5))
                        nom_xpath = "//div[contains(@class, 'Text_Text_text SummaryInformation_title__5CYhW Text_Text_headline3')]"

                        nom = driver.find_element(By.XPATH, nom_xpath).text
                        print("Nom du véhicule:", nom)

                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        nom = " "
                        print("aucun nom trouvé")
                    data.append(nom)
                    try:
                        time.sleep(random.uniform(2, 5))
                        carac_xpath = "//div[contains(@class, 'Text_Text_text SummaryInformation_subtitle__M7MAb Text_Text_body2')]"
                        carac = driver.find_element(By.XPATH, carac_xpath).text
                        #print("Carac:", carac)

                        # Diviser le texte en éléments
                        elements = carac.split()
                        action_aleatoire(driver)
                        # Variables pour stocker les informations
                        cylindree_moteur = ""
                        type_moteur = ""
                        puissance = ""
                        finition = ""

                        # Utiliser un indicateur pour savoir quel type d'information on traite actuellement
                        current_type = None

                        # Parcourir les éléments et attribuer aux variables appropriées
                        for element in elements:
                            # Vérifier s'il s'agit de la cylindrée du moteur (exprimée en centimètres cubes)
                            if element.replace(".", "").isdigit() and not cylindree_moteur:
                                cylindree_moteur = element
                            # Vérifier s'il s'agit du type de moteur (contient des lettres)
                            elif any(char.isalpha() for char in element) and not type_moteur:
                                type_moteur = element
                            # Vérifier s'il s'agit de la puissance (contient des chiffres)
                            elif element.isdigit() and not puissance:
                                puissance = element
                            # Si ce n'est ni la cylindrée, ni le type, ni la puissance, c'est probablement la finition
                            elif not finition:
                                finition += element + " "

                        cylindree_moteur = cylindree_moteur.strip()
                        type_moteur = type_moteur.strip()
                        puissance = puissance.strip()
                        finition = finition.strip()
                        # Afficher les résultats
                        #print("Cylindrée du moteur:", cylindree_moteur.strip())
                        #print("Type de moteur:", type_moteur.strip())
                        #print("Puissance:", puissance.strip())
                        #print("Finition:", finition.strip())
                        data.append((cylindree_moteur,type_moteur,puissance,finition))
                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        carac = " "
                        print("Carac non trouvé")
                    try:
                        prix_xpath = "//span[contains(@class, 'PriceInformation_classifiedPrice__b-Jae')]"

                        prix = driver.find_element(By.XPATH, prix_xpath).text
                       # print("prix:", prix)
                        time.sleep(random.uniform(2, 4))
                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        prix = " "
                        print("aucun nom trouvé")
                    data.append(prix)
                    try:
                        duree_publi_xpath = "//div[contains(@class, 'Text_Text_text Text_Text_body2')]"

                        duree_publi = driver.find_element(By.XPATH, duree_publi_xpath).text
                       # print("publié depuis:",  duree_publi)
                        time.sleep(random.uniform(2, 5))
                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        durée_publi = " "
                        print("no durée publi renseigné")
                    data.append(duree_publi)
                    try:
                        volume_coffre_xpath = "//div[contains(@class, 'Gauge_Gauge_gaugeWrapper')]//button[contains(@class, 'Gauge_Gauge_value Button_Button_button Button_Button_shaded Button_Button_small Button_Button_square')]//span[contains(@class, 'Text_Text_text Text_Text_label2')]"
                        volume_coffre_element = WebDriverWait(driver, 15).until(
                                EC.presence_of_element_located((By.XPATH, volume_coffre_xpath))
                        )

                        volume_coffre = volume_coffre_element.get_attribute('textContent')
                        # print("volume_coffre", volume_coffre)
                        time.sleep(random.uniform(2, 3))
                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        volume_coffre = " "
                        print("no volume_coffrerenseigné")
                    except TimeoutException:
                        # Gérer la TimeoutException ici
                        print("Élément non trouvé après 15 secondes. Continuer avec le reste du code.")
                        volume_coffre = " "
                    data.append(volume_coffre)
                    try:
                        spans_xpath = "//span[contains(@class, 'Text_Text_text Icon-button_IconButton_label Text_Text_label2')]"
                        action_aleatoire(driver)
                        spans = driver.find_elements(By.XPATH, spans_xpath)
                        time.sleep(random.uniform(2, 4))
        # Nombre de spans
                        num_spans = len(spans)
                        point_forts_values = []
        # Créer des variables dynamiquement
                        for index, span in enumerate(spans, start=1):
            # Utilisation de JavaScript pour extraire le texte
                            span_text = driver.execute_script("return arguments[0].textContent;", span)
                            variable_name = f"point_fort{index}"
                            locals()[variable_name] = span_text.strip()
                             #print(f"{variable_name}:", locals()[variable_name])
                            point_forts_values.append(locals()[variable_name])


                    except NoSuchElementException:
        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        for index in range(1, num_spans + 1):
                            variable_name = f"point_fort{index}"
                            locals()[variable_name] = " "
                            print(f"{variable_name}: not found")
                            point_forts_values.append(locals()[variable_name])

                        # Ajouter le tuple de valeurs des points forts à la liste data
                    data.append(tuple(point_forts_values))
                    h3_values = []
                    try:
                        h3_xpath = "//h3[contains(@class, 'Text_Text_text Text_Text_subtitle1')]"

                        h3_elements = driver.find_elements(By.XPATH, h3_xpath)
                        time.sleep(random.uniform(2, 3))

                        for h3_element in h3_elements:
                            try:
                                ul_element = h3_element.find_element(By.XPATH, "following-sibling::ul")

                                li_elements = ul_element.find_elements(By.XPATH, "li")
                                li_values = []
                                time.sleep(random.uniform(2, 3))
                                for index, li_element in enumerate(li_elements, start=0):
                                    
                                    try:
                                        # Essayer de trouver le texte du span directement
                                        first_span_xpath = ".//span[contains(@class, 'Text_Text_text Text_Text_subtitle2')]"
                                        first_span_element = find_element_with_retry(li_element, By.XPATH, first_span_xpath)
                                        variable_name = first_span_element.get_attribute('textContent')

                                        span_xpath = ".//span[@class='Item_content__Xyd3d']"
                                        span_element = find_element_with_retry(li_element, By.XPATH, span_xpath)
                                        variable_value = span_element.get_attribute('textContent')

                                    except NoSuchElementException:
                                        # Si le premier essai échoue, essayer de trouver le texte du span à l'intérieur
                                        span_xpath = ".//span[@class='Item_content__Xyd3d']//span"
                                        span_element = find_element_with_retry(li_element, By.XPATH, span_xpath)
                                        variable_value = span_element.get_attribute('textContent')
                                    li_values.append((variable_name, variable_value))
                                    # Maintenant, vous avez la valeur du texte du span, que ce soit directement ou à l'intérieur
                                    #print(f"Nom de la variable : {variable_name}, Valeur de la variable : {variable_value}")
                                h3_values.append(tuple(li_values))

                            except NoSuchElementException:
                                pass

                    except NoSuchElementException:
                        print("H3 non trouvé")
                    data.append(tuple(h3_values))
                    ########################EN COURS######################  
                    button_class_name = "Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline"

                    try:
                        # Find the button using its class name
                        button = driver.find_element(By.CLASS_NAME, button_class_name)

                        # Click the button
                        button.click()

                        print("Button clicked successfully")

                    except NoSuchElementException:
                        print(f"Button with class name '{button_class_name}' not found")
                    except Exception as e:
                        print(f"An error occurred: {e}")

                    ####Scrappe equipement####
                    xpath_button_options = "//div[contains(@class, 'EquipmentOptionsInformation_linkMoreEquipments__rd-QS')]//button[contains(@class, 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline')]"
                    try:
                        # Attendre que le bouton soit cliquable
                        button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, xpath_button_options)))

                        # Utiliser ActionChains pour survoler et cliquer sur le bouton
                        action = ActionChains(driver)
                        action.move_to_element(button).click().perform()

                        print("Button clicked successfully")

                    except NoSuchElementException:
                        print(f"Button with XPath '{xpath_button_options}' not found")
                    except Exception as e:
                        print(f"An error occurred: {e}")

                    ####Scrappe equipement####
                    # Dictionnaire pour stocker les résultats
                    results = {}



                    # XPath pour sélectionner les uls
                    ul_xpaths = "//ul[contains(@class, 'EquipmentOptionsInformation_column__rQp-a')]"

                    # Parcourir les uls
                    uls = driver.find_elements(By.XPATH, ul_xpaths)
                    action_aleatoire(driver)
                    time.sleep(random.uniform(2, 5))
                    # Parcourir chaque ul
                    for ul_index, ul_element in enumerate(uls, start=1):
                        try:
                            # Trouver tous les li dans l'ul actuel
                            li_elements = ul_element.find_elements(By.XPATH, "./li")

                            # Parcourir chaque li
                            
                            for li_index, li_element in enumerate(li_elements, start=1):
                                # Obtenir tous les éléments h3 et div à l'intérieur du li
                                h3_elements = li_element.find_elements(By.XPATH, "./h3")
                                div_elements = li_element.find_elements(By.XPATH, "./div")

                                # Concaténer les textcontents de tous les h3 et div
                                li_textcontent = " ".join(element.get_attribute('textContent') for element in h3_elements + div_elements)

                                # Ajouter le résultat au dictionnaire
                                results[f"ul{ul_index}_li{li_index}"] = f",{li_textcontent}"

                        except NoSuchElementException:
                            print("UL non trouvé")

                    # Afficher les résultats
                    #for key, value in results.items():
                        #print(f"{key}: {value}")
                    data.append(tuple(results.values()))
                    data_final.append(data)
                    time.sleep(random.uniform(2, 3))
                    #print(data_final)
                    print("+1")
                    csv_file_path = "data.csv"
                    csv_columns = [
                        "Nom du véhicule",
                        "Caractéristiques",
                        "Prix",
                        "Durée de publication",
                        "Volume du coffre",
                        "Points forts",
                        "Équipements"
                    ]


                    with open('thread2.csv', 'a', newline='', encoding='utf-8') as csvfile:
                        csv_writer = csv.writer(csvfile)
                        csv_writer.writerow(data)       



                except StaleElementReferenceException:
                    # Si l'élément de lien est obsolète, afficher un message
                    print("StaleElementReferenceException pour le lien :", link.get_attribute("href"))

                except StaleElementReferenceException:
                    # Si l'élément de lien est obsolète, afficher un message
                    print("StaleElementReferenceException pour le lien :", link)
                    pass
                except TimeoutException as e:
                    print(f"TimeoutException: {e}")
                    pass
                    # Handle the timeout exception
                except WebDriverException as e:
                    print(f"WebDriverException: {e}")
                    pass
        except StaleElementReferenceException:
            # If the element is stale, refind the links and continue
            print("StaleElementReferenceException. Refinding links.")
            links = driver.find_elements(By.XPATH, xpath_expression)
            continue
        except NoSuchElementException:
            # Si l'élément n'est pas trouvé, cela signifie probablement que la page n'existe pas
            print("Fin de la boucle : La page", current_page, "n'existe pas.")
            pass
        # Passer à la page suivante
        current_page += 1
        

    # Fermer le navigateur à la fin
    driver.quit()

# Number of threads
num_threads = 4

# Create a list to store WebDriver instances
drivers = [initialize_driver() for _ in range(num_threads)]

# Define the range of pages you want to scrape
start_page = 0
end_page = 500
# Calculate the step size to distribute pages evenly
step = (end_page - start_page) // num_threads
# Create a list to store thread links
thread_links = [[] for _ in range(num_threads)]
# Use ThreadPoolExecutor to run tasks concurrently
with ThreadPoolExecutor(max_workers=num_threads) as executor:
    # Submit tasks to the pool for the specified range of pages
    futures = [executor.submit(scrape_page, base_url, page, step, driver, thread_links[i]) for i, (page, driver) in enumerate(zip(range(start_page, end_page, step), drivers))]

    # Wait for all tasks to complete
    for future in futures:
        future.result()

# Close the WebDriver instances
for driver in drivers:
    driver.quit()
# Out:
# ['https://www.lacentrale.fr/auto-occasion-annonce-69112840545.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102818441.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112814782.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112180824.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102787014.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102778876.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112895533.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113056939.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102816608.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113195000.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113169982.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112914157.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102713969.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102821104.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112402782.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112738270.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112840545.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113019827.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113134323.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112922405.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113104510.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113035112.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113179659.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112949567.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112947079.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113171171.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112872790.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113063905.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112562457.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113083670.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112971413.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112622320.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112866288.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113019827.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69112670269.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113126798.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113170615.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113189043.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112873216.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112925166.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112961470.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112982939.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113088053.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102813141.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113187505.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112964249.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113175678.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102665188.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112330505.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102783958.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112670269.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69112805053.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112681498.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102810341.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113051333.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112909477.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112707076.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112406894.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102750284.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112021132.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112753836.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113072490.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102820525.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102752575.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113187504.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112988569.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112919979.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112805053.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69112785721.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112846580.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102768895.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113100605.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113166271.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113169674.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113009185.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112890148.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102796880.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112872702.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113069822.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102775646.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112385680.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112871714.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113199448.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113220114.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112785721.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-87102728211.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113089078.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102799373.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112635330.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113170468.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102758115.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112972194.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112322039.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102783853.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113219682.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102812299.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113229769.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113131862.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112902500.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112811171.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102809687.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102728211.html
# Nom du véhicule: NISSAN X-TRAIL III
# Nom du véhicule: PEUGEOT 2008 II
# Nom du véhicule: VOLKSWAGEN TAIGO
# Nom du véhicule: BMW SERIE 3 F31 TOURING phase 2
# Nom du véhicule: PEUGEOT 108
# Nom du véhicule: RENAULT CLIO 5
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113134323.html
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102818441.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113126798.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112846580.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112681498.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113089078.html
# Nom du véhicule: JEEP RENEGADE phase 2
# Nom du véhicule: MERCEDES CLA phase 2
# Nom du véhicule: RENAULT TALISMAN
# Nom du véhicule: BMW SERIE 1 F20 5 PORTES phase 2
# Nom du véhicule: RENAULT TRAFIC III
# Nom du véhicule: RENAULT CLIO V
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112922405.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112814782.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102768895.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113170615.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102810341.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102799373.html
# Nom du véhicule: TOYOTA C-HR phase 2
# Nom du véhicule: OPEL CORSA VI
# Nom du véhicule: AUDI TT II phase 2
# Nom du véhicule: DS 3 CROSSBACK
# Nom du véhicule: VOLKSWAGEN GOLF VII phase 2
# Nom du véhicule: AUDI A1 II SPORTBACK
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113100605.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113189043.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113051333.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113104510.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112635330.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112180824.html
# Nom du véhicule: CITROEN C3 III phase 2
# Nom du véhicule: RENAULT MEGANE IV
# Nom du véhicule: JAGUAR E-PACE
# Nom du véhicule: RENAULT KANGOO II EXPRESS phase 2
# Nom du véhicule: DACIA SANDERO II phase 2
# Nom du véhicule: PEUGEOT 3008 II phase 2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113166271.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112909477.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113035112.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113170468.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112873216.html
# Nom du véhicule: PEUGEOT 308 II SW phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102787014.html
# Nom du véhicule: CITROEN C3 III phase 2
# Nom du véhicule: NISSAN QASHQAI III
# Nom du véhicule: NISSAN JUKE II
# Nom du véhicule: PEUGEOT 308 II phase 2
# Nom du véhicule: MAZDA MX5 III
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113169674.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112707076.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113179659.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112925166.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102758115.html
# Nom du véhicule: MERCEDES CLA SHOOTING BRAKE phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102778876.html
# Nom du véhicule: PEUGEOT 208 II
# Nom du véhicule: VOLKSWAGEN TIGUAN II
# Nom du véhicule: FORD EDGE
# Nom du véhicule: BMW SERIE 3 G80 M3
# Nom du véhicule: MAZDA MX5 IV ST
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113009185.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112949567.html
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT 308 II phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112406894.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112961470.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112972194.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112895533.html
# Nom du véhicule: BMW X1 F48 phase 2
# Nom du véhicule: JEEP RENEGADE phase 2
# Nom du véhicule: NISSAN X-TRAIL III phase 2
# Nom du véhicule: FORD ECOSPORT
# Nom du véhicule: FERRARI 488 SPIDER
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112890148.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102750284.html
# An error occurred: Message:
#
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Nom du véhicule: AUDI TT III RS ROADSTER phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112947079.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112322039.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112982939.html
# Nom du véhicule: PEUGEOT 3008 II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113056939.html
# Nom du véhicule: MINI III 3P
# Nom du véhicule: RENAULT ZOE phase 2
# Nom du véhicule: CITROEN C4 PICASSO II phase 2
# Nom du véhicule: PEUGEOT 3008 II
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102796880.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112021132.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Nom du véhicule: PORSCHE 911 TYPE 997 phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102783853.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102816608.html
# Nom du véhicule: PORSCHE CAYENNE II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113088053.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113171171.html
# Nom du véhicule: PEUGEOT RCZ
# Nom du véhicule: DACIA SANDERO 3 STEPWAY
# Nom du véhicule: CITROEN C3 III phase 2
# Nom du véhicule: MINI III CLUBMAN phase 2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# An error occurred: Message:
#
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112872702.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112753836.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113195000.html
# +1+1
#
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113219682.html
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112872790.html
# Nom du véhicule: FERRARI SF90 STRADALE
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102813141.html
# Nom du véhicule: PEUGEOT E-208 II
# Nom du véhicule: BMW X3 F25 phase 2
# Nom du véhicule: OPEL MOKKA II
# Nom du véhicule: INFINITI Q30
# Nom du véhicule: SUZUKI ACROSS
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113069822.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113072490.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113169982.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113063905.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102812299.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113187505.html
# Nom du véhicule: CHEVROLET CORVETTE C2 CABRIOLET
# Nom du véhicule: MINI COUNTRYMAN II
# Nom du véhicule: VOLVO XC40
# Nom du véhicule: SKODA KODIAQ
# Nom du véhicule: PEUGEOT 308 II SW phase 2
# Nom du véhicule: PEUGEOT E-2008 II
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102775646.html
# An error occurred: Message:
#
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112562457.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102820525.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112914157.html
# Nom du véhicule: FORD F150
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113229769.html
# Nom du véhicule: MERCEDES CLA II SHOOTING BRAKE
# Nom du véhicule: SMART FORFOUR 2
# Nom du véhicule: MERCEDES CLASSE M II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112964249.html
# Nom du véhicule: AUDI A1 II SPORTBACK
# Nom du véhicule: AUDI A5 SPORTBACK II
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112385680.html
# An error occurred: Message:
#
# +1
# +1
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102713969.html
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113083670.html
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102752575.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113131862.html
# An error occurred: Message:
#
# Nom du véhicule: OPEL CROSSLAND X
# Nom du véhicule: PORSCHE 911 TYPE 991 TARGA
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113175678.html
# Nom du véhicule: VOLKSWAGEN GOLF VII
# Nom du véhicule: RENAULT CLIO V
# Nom du véhicule: LAND ROVER DISCOVERY SPORT
# Nom du véhicule: CITROEN C3 III phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112871714.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112971413.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113187504.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102821104.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112902500.html
# An error occurred: Message:
#
# Nom du véhicule: RENAULT CLIO V
# Nom du véhicule: TOYOTA RAV 4 V
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102665188.html
# Nom du véhicule: PEUGEOT 207 phase 2
# Nom du véhicule: CITROEN C3 III phase 2
# Nom du véhicule: BMW X2 F39
# Nom du véhicule: PEUGEOT 208 phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112622320.html
# An error occurred: Message:
#
# An error occurred: Message:
# An error occurred: Message:
#
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113199448.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112402782.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112811171.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112988569.html
# Nom du véhicule: PEUGEOT 508 II SW
# Nom du véhicule: SEAT ARONA phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112330505.html
# Nom du véhicule: PEUGEOT 208 II
# Nom du véhicule: OPEL GRANDLAND X
# Nom du véhicule: BMW X3 G01
# Nom du véhicule: PEUGEOT 3008 II
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112866288.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113220114.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102809687.html
# Nom du véhicule: MINI III CLUBMAN phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112738270.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112919979.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102783958.html
# Nom du véhicule: RENAULT MEGANE IV phase 2
# Nom du véhicule: MERCEDES CLASSE A II phase 2
# Nom du véhicule: PEUGEOT 2008 II
# Nom du véhicule: MERCEDES CLASSE C IV SW AMG
# Nom du véhicule: AUDI RS7 II SPORTBACK
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113002672.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112713513.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113010551.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112765252.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113163899.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113128338.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112783090.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113087289.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112878670.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112804453.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113019827.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113134323.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112922405.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113104510.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113035112.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113179659.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113002672.html
# +1
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113169674.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113009185.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112890148.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102796880.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112872702.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113069822.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102775646.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112385680.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112871714.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113199448.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113220114.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102737862.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113089730.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112702302.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112876687.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102794837.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113169674.html
# +1
# Nom du véhicule: SKODA OCTAVIA 3 COMBI
# +1
# +1
# ['https://www.lacentrale.fr/auto-occasion-annonce-87102728211.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113089078.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102799373.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112635330.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113170468.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102758115.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112972194.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112322039.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102783853.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113219682.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102812299.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113229769.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113181662.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113131862.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112902500.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112811171.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102728211.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113218624.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102756719.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112957886.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112715750.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112840545.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102818441.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112814782.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112180824.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102787014.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102778876.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112895533.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113056939.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102816608.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113195000.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113169982.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102713969.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113218624.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69112988569.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113187504.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112919979.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112341016.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102810663.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113216906.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112851743.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112739551.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102734042.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102812338.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112799447.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113077268.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113202723.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112897913.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102789253.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113164430.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112988569.html
# Nom du véhicule: MERCEDES CLA SHOOTING BRAKE phase 2
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113020427.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112313317.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113148373.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113195523.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113189199.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113210027.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102705814.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112535833.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113069942.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102720475.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102780604.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113134677.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112670269.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113126798.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113170615.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113189043.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113020427.html
# Nom du véhicule: RENAULT CLIO 5
# Nom du véhicule: FORD RANGER III phase 3
# Nom du véhicule: BMW X3 G01
# Nom du véhicule: CITROEN C3 AIRCROSS phase 2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112713513.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113009185.html
# An error occurred: Message:
#
# Nom du véhicule: MERCEDES SL IV AMG phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113089078.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113187504.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102756719.html
# Nom du véhicule: PEUGEOT 308 II phase 2
# Nom du véhicule: RENAULT CLIO V
# Nom du véhicule: CITROEN C3 III phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112313317.html
# Nom du véhicule: BMW SERIE 2 G42 COUPE
# Nom du véhicule: VOLKSWAGEN SHARAN II phase 2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113010551.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112890148.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112919979.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102799373.html
# Nom du véhicule: MINI III 5P phase 2
# An error occurred: Message:
#
# Nom du véhicule: AUDI TT III RS ROADSTER phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112957886.html
# Nom du véhicule: MERCEDES CLASSE C IV SW AMG
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113148373.html
# Nom du véhicule: AUDI A1 II SPORTBACK
# Nom du véhicule: CITROEN C5 AIRCROSS phase 2
# Nom du véhicule: ROLLS ROYCE SILVER SERAPH
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112765252.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102796880.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112341016.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112635330.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112715750.html
# Nom du véhicule: SKODA SCALA
# An error occurred: Message:
#
# Nom du véhicule: PORSCHE 911 TYPE 997 phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113195523.html
# Nom du véhicule: RENAULT KANGOO II EXPRESS phase 2
# Nom du véhicule: RENAULT CLIO V
# Nom du véhicule: PEUGEOT 208 II
# Nom du véhicule: AUDI A3 IV SPORTBACK
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# ...
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: FERRARI 488 GTB
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111722884.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113119661.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112938287.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: PEUGEOT 208 II
# Nom du véhicule: CITROEN C4 III
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT E-208 II
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112447138.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112729154.html
# Nom du véhicule: PEUGEOT 3008 II
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112732799.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: HYUNDAI KONA phase 2
# Nom du véhicule: AUDI A3 IV SPORTBACK
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113200967.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113093279.html
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113218062.html
# Nom du véhicule: CITROEN C3 AIRCROSS phase 2
# Nom du véhicule: MINI III CABRIOLET
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT 208 II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112254844.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: MERCEDES CLASSE B II phase 2
# An error occurred: Message:
#
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112398054.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112521995.html
# Nom du véhicule: BMW X4 G02 phase 2
# Nom du véhicule: RENAULT MEGANE 4 ESTATE
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113179973.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112917885.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112759200.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# An error occurred: Message:
#
# Nom du véhicule: MERCEDES CLASSE A IV
# Nom du véhicule: PEUGEOT 3008 II phase 2
# Nom du véhicule: FORD TOURNEO CONNECT II phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112577108.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Nom du véhicule: MERCEDES-AMG GT
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102819169.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112348597.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: VOLKSWAGEN T-ROC phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: AUDI A1 SPORTBACK phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112597395.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69110517725.html
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: LAND ROVER RANGE ROVER SPORT II phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102798977.html
# Nom du véhicule: ASTON MARTIN VANQUISH
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: PORSCHE 911 TYPE 992
# +1
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# ['https://www.lacentrale.fr/auto-occasion-annonce-87102799016.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112921443.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113175249.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113087012.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113022239.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113127580.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113217605.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112113676.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113162261.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112962314.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113156587.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113210821.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113220517.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113152842.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113142142.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112961471.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102799016.html
# An error occurred: Message:
#
# +1
# +1
# Nom du véhicule: PEUGEOT 208 II
# ['https://www.lacentrale.fr/auto-occasion-annonce-69112724191.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113006474.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102777197.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113131210.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112569060.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112969638.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113162248.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112698101.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102652839.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102770629.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112963813.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113186573.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113089177.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113215612.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113127599.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102817778.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112724191.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# ['https://www.lacentrale.fr/auto-occasion-annonce-87102819169.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112602524.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112895896.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102819671.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113175695.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112984174.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112999503.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113127591.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113187515.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112602333.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113099516.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111494283.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113184782.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113176116.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113183033.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113121955.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102819169.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: PORSCHE 911 TYPE 991 GT3 RS phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Nom du véhicule: AUDI A1 SPORTBACK phase 2
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# +1
# +1
# ['https://www.lacentrale.fr/auto-occasion-annonce-69110517725.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112519626.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113062029.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113132856.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111662650.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111878642.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113119557.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113158239.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113117008.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113054680.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113226734.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112569814.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113197665.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112726120.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112960114.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112114415.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69110517725.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113186037.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112687769.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102805144.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113199521.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113074516.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111907532.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112908111.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102797314.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113144384.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113233225.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112682544.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113142207.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112835500.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112867922.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102791406.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102692154.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113186037.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113115824.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113115747.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113220575.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113142121.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113142160.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112878611.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113009643.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112512091.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113045442.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113208662.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111846049.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112938571.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112145603.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112059407.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102652166.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112761602.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113115824.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: ASTON MARTIN VANQUISH
# Nom du véhicule: PEUGEOT 308 II SW phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: AUDI A4 V
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112921443.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113006474.html
# An error occurred: Message:
#
# Nom du véhicule: VOLKSWAGEN T-CROSS
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112602524.html
# Nom du véhicule: CITROEN C3 (3E GENERATION)
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: CITROEN C5 AIRCROSS phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
