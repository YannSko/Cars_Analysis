# %% [markdown]
# Lien du site :
# https://www.lacentrale.fr/auto-occasion-annonce-69113195868.html

# %% [markdown]
# # Scrappe la centrale

# %% [markdown]
# ### Import

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import pandas as pd
import urllib
import re
import requests
import csv
import time

from selenium.webdriver.common.service import Service
from selenium.webdriver.common.service import Service
from fake_useragent import UserAgent
from urllib3.exceptions import NewConnectionError
import logging
from datetime import datetime, timedelta
from selenium.common.exceptions import ElementClickInterceptedException

import pandas as pd 
import numpy as np 

import random
from selenium.webdriver.common.action_chains import ActionChains
from itertools import combinations

# %% [markdown]
# ### Scrappe

# %% [markdown]
# Fake Action

# %%
def action_aleatoire(driver):
    actions_possibles = ["scroll_full", "scroll_half", "move_to_element"]
    action_choisie = random.choice(actions_possibles)

    # Enregistrer la position actuelle de la page
    current_scroll_position = driver.execute_script("return window.pageYOffset;")

    if action_choisie == "scroll_full":
        # Action aléatoire : Faites défiler la page vers le bas
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    elif action_choisie == "scroll_half":
        # Action aléatoire : Faites défiler la moitié de la page vers le bas
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight / 2);")
    elif action_choisie == "move_to_element":
        # Action aléatoire : Bougez la souris vers un élément aléatoire (par exemple, div de class PriceInformation_classifiedPrice__b-Jae)
        wait = WebDriverWait(driver, 10)
        element_to_move = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'PriceInformation_classifiedPrice__b-Jae')))
        driver.execute_script("arguments[0].scrollIntoView();", element_to_move)

    # Revenir à la position enregistrée
    driver.execute_script(f"window.scrollTo(0, {current_scroll_position});")

# %%
def find_element_with_retry(driver, by, value, max_retries=3):
    retries = 0
    while retries < max_retries:
        try:
            element = driver.find_element(by, value)
            return element
        except NoSuchElementException:
            retries += 1
            time.sleep(2)  # Add a small delay before retrying
    raise NoSuchElementException(f"Element not found after {max_retries} retries")

# %% [markdown]
# Scrape

# %% [markdown]
# import time
# import random
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
# from fake_useragent import UserAgent
# from selenium.common.exceptions import WebDriverException
# # Configurations du navigateur
# ua = UserAgent()
# user_agent = ua.random
# options = webdriver.FirefoxOptions()
# options.add_argument('--headless')
# options.add_argument(f'user-agent={user_agent}')
#
# # Initialisation du navigateur
# driver = webdriver.Firefox(options=options)
# base_url = "https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page="
# xpath_expression = "//a[contains(@class, 'Vehiculecard_Vehiculecard_vehiculeCard Containers_Containers_containers Containers_Containers_borderRadius Containers_Containers_darkShadowWide')]"
# data_final = []
# # Numéro de la première page à visiter
# current_page = 0
#
# # Boucle pour parcourir les pages
# while True:
#     # Construire l'URL de la page actuelle
#
#
#     url = base_url + str(current_page)
#     time.sleep(random.uniform(2, 6))
#
#     # Charger la page web
#     try:
#         driver.set_page_load_timeout(120)
#         driver.get(url)
#     except TimeoutException:
#         print(f"TimeoutException: Unable to load {link}")
#     try:
#         # Insérer ici le code pour extraire les liens ou effectuer d'autres opérations sur la page
#         links = driver.find_elements(By.XPATH, xpath_expression)
#         all_links = []
#         # Ajouter les liens à la liste
#         all_links.extend(link.get_attribute("href") for link in links)
#         print(all_links)
#         # Parcourir chaque lien pour effectuer des opérations
#         for link in all_links:
#             try:
#                 # Afficher le lien trouvé
#                 print("Lien trouvé :", link)
#                 data = []
#                 # Accéder à la page du lien
#                 driver.get(link)
#                 time.sleep(random.uniform(2, 5))
#
#                 # Insérer ici le code pour effectuer des opérations sur la page du lien
#
#                 try:
#                     nom_xpath = "//div[contains(@class, 'Text_Text_text SummaryInformation_title__5CYhW Text_Text_headline3')]"
#
#                     nom = driver.find_element(By.XPATH, nom_xpath).text
#                     print("Nom du véhicule:", nom)
#
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     nom = " "
#                     print("aucun nom trouvé")
#                 data.append(nom)
#                 try:
#                     carac_xpath = "//div[contains(@class, 'Text_Text_text SummaryInformation_subtitle__M7MAb Text_Text_body2')]"
#                     carac = driver.find_element(By.XPATH, carac_xpath).text
#                     #print("Carac:", carac)
#
#                     # Diviser le texte en éléments
#                     elements = carac.split()
#                     action_aleatoire(driver)
#                     # Variables pour stocker les informations
#                     cylindree_moteur = ""
#                     type_moteur = ""
#                     puissance = ""
#                     finition = ""
#
#                     # Utiliser un indicateur pour savoir quel type d'information on traite actuellement
#                     current_type = None
#
#                     # Parcourir les éléments et attribuer aux variables appropriées
#                     for element in elements:
#                         # Vérifier s'il s'agit de la cylindrée du moteur (exprimée en centimètres cubes)
#                         if element.replace(".", "").isdigit() and not cylindree_moteur:
#                             cylindree_moteur = element
#                         # Vérifier s'il s'agit du type de moteur (contient des lettres)
#                         elif any(char.isalpha() for char in element) and not type_moteur:
#                             type_moteur = element
#                         # Vérifier s'il s'agit de la puissance (contient des chiffres)
#                         elif element.isdigit() and not puissance:
#                             puissance = element
#                         # Si ce n'est ni la cylindrée, ni le type, ni la puissance, c'est probablement la finition
#                         elif not finition:
#                             finition += element + " "
#
#                     cylindree_moteur = cylindree_moteur.strip()
#                     type_moteur = type_moteur.strip()
#                     puissance = puissance.strip()
#                     finition = finition.strip()
#                     # Afficher les résultats
#                     #print("Cylindrée du moteur:", cylindree_moteur.strip())
#                     #print("Type de moteur:", type_moteur.strip())
#                     #print("Puissance:", puissance.strip())
#                     #print("Finition:", finition.strip())
#                     data.append((cylindree_moteur,type_moteur,puissance,finition))
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     carac = " "
#                     print("Carac non trouvé")
#                 try:
#                     prix_xpath = "//span[contains(@class, 'PriceInformation_classifiedPrice__b-Jae')]"
#
#                     prix = driver.find_element(By.XPATH, prix_xpath).text
#                    # print("prix:", prix)
#                     time.sleep(random.uniform(2, 4))
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     prix = " "
#                     print("aucun nom trouvé")
#                 data.append(prix)
#                 try:
#                     duree_publi_xpath = "//div[contains(@class, 'Text_Text_text Text_Text_body2')]"
#
#                     duree_publi = driver.find_element(By.XPATH, duree_publi_xpath).text
#                    # print("publié depuis:",  duree_publi)
#                     time.sleep(random.uniform(2, 5))
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     durée_publi = " "
#                     print("no durée publi renseigné")
#                 data.append(duree_publi)
#                 try:
#                     volume_coffre_xpath = "//div[contains(@class, 'Gauge_Gauge_gaugeWrapper')]//button[contains(@class, 'Gauge_Gauge_value Button_Button_button Button_Button_shaded Button_Button_small Button_Button_square')]//span[contains(@class, 'Text_Text_text Text_Text_label2')]"
#                     volume_coffre_element = WebDriverWait(driver, 15).until(
#                             EC.presence_of_element_located((By.XPATH, volume_coffre_xpath))
#                     )
#
#                     volume_coffre = volume_coffre_element.get_attribute('textContent')
#                     # print("volume_coffre", volume_coffre)
#                     time.sleep(random.uniform(2, 3))
#                 except NoSuchElementException:
#                     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     volume_coffre = " "
#                     print("no volume_coffrerenseigné")
#                 except TimeoutException:
#                     # Gérer la TimeoutException ici
#                     print("Élément non trouvé après 15 secondes. Continuer avec le reste du code.")
#                     volume_coffre = " "
#                 data.append(volume_coffre)
#                 try:
#                     spans_xpath = "//span[contains(@class, 'Text_Text_text Icon-button_IconButton_label Text_Text_label2')]"
#                     action_aleatoire(driver)
#                     spans = driver.find_elements(By.XPATH, spans_xpath)
#                     time.sleep(random.uniform(2, 4))
#     # Nombre de spans
#                     num_spans = len(spans)
#                     point_forts_values = []
#     # Créer des variables dynamiquement
#                     for index, span in enumerate(spans, start=1):
#         # Utilisation de JavaScript pour extraire le texte
#                         span_text = driver.execute_script("return arguments[0].textContent;", span)
#                         variable_name = f"point_fort{index}"
#                         locals()[variable_name] = span_text.strip()
#                          #print(f"{variable_name}:", locals()[variable_name])
#                         point_forts_values.append(locals()[variable_name])
#
#
#                 except NoSuchElementException:
#     # Si la div n'est pas trouvée sur la page du lien, afficher un message
#                     for index in range(1, num_spans + 1):
#                         variable_name = f"point_fort{index}"
#                         locals()[variable_name] = " "
#                         print(f"{variable_name}: not found")
#                         point_forts_values.append(locals()[variable_name])
#
#                     # Ajouter le tuple de valeurs des points forts à la liste data
#                 data.append(tuple(point_forts_values))
#                 h3_values = []
#                 try:
#                     h3_xpath = "//h3[contains(@class, 'Text_Text_text Text_Text_subtitle1')]"
#
#                     h3_elements = driver.find_elements(By.XPATH, h3_xpath)
#                     time.sleep(random.uniform(2, 3))
#
#                     for h3_element in h3_elements:
#                         try:
#                             ul_element = h3_element.find_element(By.XPATH, "following-sibling::ul")
#
#                             li_elements = ul_element.find_elements(By.XPATH, "li")
#                             li_values = []
#                             for index, li_element in enumerate(li_elements, start=0):
#                                 time.sleep(random.uniform(2, 5))
#
#                                 try:
#                                     # Essayer de trouver le texte du span directement
#                                     first_span_xpath = ".//span[contains(@class, 'Text_Text_text Text_Text_subtitle2')]"
#                                     first_span_element = find_element_with_retry(li_element, By.XPATH, first_span_xpath)
#                                     variable_name = first_span_element.get_attribute('textContent')
#
#                                     span_xpath = ".//span[@class='Item_content__Xyd3d']"
#                                     span_element = find_element_with_retry(li_element, By.XPATH, span_xpath)
#                                     variable_value = span_element.get_attribute('textContent')
#
#                                 except NoSuchElementException:
#                                     # Si le premier essai échoue, essayer de trouver le texte du span à l'intérieur
#                                     span_xpath = ".//span[@class='Item_content__Xyd3d']//span"
#                                     span_element = find_element_with_retry(li_element, By.XPATH, span_xpath)
#                                     variable_value = span_element.get_attribute('textContent')
#                                 li_values.append((variable_name, variable_value))
#                                 # Maintenant, vous avez la valeur du texte du span, que ce soit directement ou à l'intérieur
#                                 #print(f"Nom de la variable : {variable_name}, Valeur de la variable : {variable_value}")
#                             h3_values.append(tuple(li_values))
#
#                         except NoSuchElementException:
#                             pass
#
#                 except NoSuchElementException:
#                     print("H3 non trouvé")
#                 data.append(tuple(h3_values))
#                 ########################EN COURS######################
#                 button_class_name = "Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline"
#
#                 try:
#                     # Find the button using its class name
#                     button = driver.find_element(By.CLASS_NAME, button_class_name)
#
#                     # Click the button
#                     button.click()
#
#                     print("Button clicked successfully")
#
#                 except NoSuchElementException:
#                     print(f"Button with class name '{button_class_name}' not found")
#                 except Exception as e:
#                     print(f"An error occurred: {e}")
#
#                 ####Scrappe equipement####
#                 xpath_button_options = "//div[contains(@class, 'EquipmentOptionsInformation_linkMoreEquipments__rd-QS')]//button[contains(@class, 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline')]"
#                 try:
#                     # Attendre que le bouton soit cliquable
#                     button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, xpath_button_options)))
#
#                     # Utiliser ActionChains pour survoler et cliquer sur le bouton
#                     action = ActionChains(driver)
#                     action.move_to_element(button).click().perform()
#
#                     print("Button clicked successfully")
#
#                 except NoSuchElementException:
#                     print(f"Button with XPath '{xpath_button_options}' not found")
#                 except Exception as e:
#                     print(f"An error occurred: {e}")
#
#                 ####Scrappe equipement####
#                 # Dictionnaire pour stocker les résultats
#                 results = {}
#
#
#
#                 # XPath pour sélectionner les uls
#                 ul_xpaths = "//ul[contains(@class, 'EquipmentOptionsInformation_column__rQp-a')]"
#
#                 # Parcourir les uls
#                 uls = driver.find_elements(By.XPATH, ul_xpaths)
#                 action_aleatoire(driver)
#                 # Parcourir chaque ul
#                 for ul_index, ul_element in enumerate(uls, start=1):
#                     try:
#                         # Trouver tous les li dans l'ul actuel
#                         li_elements = ul_element.find_elements(By.XPATH, "./li")
#
#                         # Parcourir chaque li
#                         time.sleep(random.uniform(2, 3))
#                         for li_index, li_element in enumerate(li_elements, start=1):
#                             # Obtenir tous les éléments h3 et div à l'intérieur du li
#                             h3_elements = li_element.find_elements(By.XPATH, "./h3")
#                             div_elements = li_element.find_elements(By.XPATH, "./div")
#
#                             # Concaténer les textcontents de tous les h3 et div
#                             li_textcontent = " ".join(element.get_attribute('textContent') for element in h3_elements + div_elements)
#
#                             # Ajouter le résultat au dictionnaire
#                             results[f"ul{ul_index}_li{li_index}"] = f",{li_textcontent}"
#
#                     except NoSuchElementException:
#                         print("UL non trouvé")
#
#                 # Afficher les résultats
#                 #for key, value in results.items():
#                     #print(f"{key}: {value}")
#                 data.append(tuple(results.values()))
#                 data_final.append(data)
#                 time.sleep(random.uniform(2, 3))
#                 #print(data_final)
#                 print("+1")
#                 csv_file_path = "data.csv"
#                 csv_columns = [
#                     "Nom du véhicule",
#                     "Caractéristiques",
#                     "Prix",
#                     "Durée de publication",
#                     "Volume du coffre",
#                     "Points forts",
#                     "Équipements"
#                 ]
#
#
#                 with open('data.csv', 'a', newline='', encoding='utf-8') as csvfile:
#                     csv_writer = csv.writer(csvfile)
#                     csv_writer.writerow(data)
#
#
#
#             except StaleElementReferenceException:
#                 # Si l'élément de lien est obsolète, afficher un message
#                 print("StaleElementReferenceException pour le lien :", link.get_attribute("href"))
#
#             except StaleElementReferenceException:
#                 # Si l'élément de lien est obsolète, afficher un message
#                 print("StaleElementReferenceException pour le lien :", link)
#                 pass
#             except TimeoutException as e:
#                 print(f"TimeoutException: {e}")
#                 pass
#                 # Handle the timeout exception
#             except WebDriverException as e:
#                 print(f"WebDriverException: {e}")
#                 pass
#
#     except NoSuchElementException:
#         # Si l'élément n'est pas trouvé, cela signifie probablement que la page n'existe pas
#         print("Fin de la boucle : La page", current_page, "n'existe pas.")
#         pass
#     # Passer à la page suivante
#
#     current_page += 1
#
# # Fermer le navigateur à la fin
# driver.quit()

# %% [markdown]
# ### TEST  POOL

# %%
import time
import random
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from fake_useragent import UserAgent
from selenium.common.exceptions import WebDriverException
from concurrent.futures import ThreadPoolExecutor
from selenium.common.exceptions import TimeoutException


def initialize_driver():
    ua = UserAgent()
    user_agent = ua.random
    options = webdriver.FirefoxOptions()
    options.add_argument('--headless')
    options.add_argument(f'user-agent={user_agent}')
    return webdriver.Firefox(options=options)
base_url = "https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page="
xpath_expression = "//a[contains(@class, 'Vehiculecard_Vehiculecard_vehiculeCard Containers_Containers_containers Containers_Containers_borderRadius Containers_Containers_darkShadowWide')]"
data_final = []
def scrape_page(base_url, start_page, step, driver, links):
    current_page = start_page
   
   
    
    # Boucle pour parcourir les pages
    while current_page < start_page + step:
        # Construire l'URL de la page actuelle


        url = base_url + str(current_page)
        time.sleep(random.uniform(2, 6))

        # Charger la page web
        try:
            driver.set_page_load_timeout(120)
            driver.get(url)
        except TimeoutException:
            print(f"TimeoutException: Unable to load {link}")
        try:
            # Insérer ici le code pour extraire les liens ou effectuer d'autres opérations sur la page
            all_links = driver.find_elements(By.XPATH, xpath_expression)
            links = []
            # Ajouter les liens à la liste
            links.extend(link.get_attribute("href") for link in all_links)
            print(links)
            # Parcourir chaque lien pour effectuer des opérations
            for link in links:
                try:
                    # Afficher le lien trouvé
                    print("Lien trouvé :", link)
                    data = []
                    # Accéder à la page du lien
                    driver.get(link)
                    time.sleep(random.uniform(2, 5))

                    # Insérer ici le code pour effectuer des opérations sur la page du lien

                    try:
                        time.sleep(random.uniform(2, 5))
                        nom_xpath = "//div[contains(@class, 'Text_Text_text SummaryInformation_title__5CYhW Text_Text_headline3')]"

                        nom = driver.find_element(By.XPATH, nom_xpath).text
                        print("Nom du véhicule:", nom)

                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        nom = " "
                        print("aucun nom trouvé")
                    data.append(nom)
                    try:
                        time.sleep(random.uniform(2, 5))
                        carac_xpath = "//div[contains(@class, 'Text_Text_text SummaryInformation_subtitle__M7MAb Text_Text_body2')]"
                        carac = driver.find_element(By.XPATH, carac_xpath).text
                        #print("Carac:", carac)

                        # Diviser le texte en éléments
                        elements = carac.split()
                        action_aleatoire(driver)
                        # Variables pour stocker les informations
                        cylindree_moteur = ""
                        type_moteur = ""
                        puissance = ""
                        finition = ""

                        # Utiliser un indicateur pour savoir quel type d'information on traite actuellement
                        current_type = None

                        # Parcourir les éléments et attribuer aux variables appropriées
                        for element in elements:
                            # Vérifier s'il s'agit de la cylindrée du moteur (exprimée en centimètres cubes)
                            if element.replace(".", "").isdigit() and not cylindree_moteur:
                                cylindree_moteur = element
                            # Vérifier s'il s'agit du type de moteur (contient des lettres)
                            elif any(char.isalpha() for char in element) and not type_moteur:
                                type_moteur = element
                            # Vérifier s'il s'agit de la puissance (contient des chiffres)
                            elif element.isdigit() and not puissance:
                                puissance = element
                            # Si ce n'est ni la cylindrée, ni le type, ni la puissance, c'est probablement la finition
                            elif not finition:
                                finition += element + " "

                        cylindree_moteur = cylindree_moteur.strip()
                        type_moteur = type_moteur.strip()
                        puissance = puissance.strip()
                        finition = finition.strip()
                        # Afficher les résultats
                        #print("Cylindrée du moteur:", cylindree_moteur.strip())
                        #print("Type de moteur:", type_moteur.strip())
                        #print("Puissance:", puissance.strip())
                        #print("Finition:", finition.strip())
                        data.append((cylindree_moteur,type_moteur,puissance,finition))
                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        carac = " "
                        print("Carac non trouvé")
                    try:
                        prix_xpath = "//span[contains(@class, 'PriceInformation_classifiedPrice__b-Jae')]"

                        prix = driver.find_element(By.XPATH, prix_xpath).text
                       # print("prix:", prix)
                        time.sleep(random.uniform(2, 4))
                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        prix = " "
                        print("aucun nom trouvé")
                    data.append(prix)
                    try:
                        duree_publi_xpath = "//div[contains(@class, 'Text_Text_text Text_Text_body2')]"

                        duree_publi = driver.find_element(By.XPATH, duree_publi_xpath).text
                       # print("publié depuis:",  duree_publi)
                        time.sleep(random.uniform(2, 5))
                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        durée_publi = " "
                        print("no durée publi renseigné")
                    data.append(duree_publi)
                    try:
                        volume_coffre_xpath = "//div[contains(@class, 'Gauge_Gauge_gaugeWrapper')]//button[contains(@class, 'Gauge_Gauge_value Button_Button_button Button_Button_shaded Button_Button_small Button_Button_square')]//span[contains(@class, 'Text_Text_text Text_Text_label2')]"
                        volume_coffre_element = WebDriverWait(driver, 15).until(
                                EC.presence_of_element_located((By.XPATH, volume_coffre_xpath))
                        )

                        volume_coffre = volume_coffre_element.get_attribute('textContent')
                        # print("volume_coffre", volume_coffre)
                        time.sleep(random.uniform(2, 3))
                    except NoSuchElementException:
                        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        volume_coffre = " "
                        print("no volume_coffrerenseigné")
                    except TimeoutException:
                        # Gérer la TimeoutException ici
                        print("Élément non trouvé après 15 secondes. Continuer avec le reste du code.")
                        volume_coffre = " "
                    data.append(volume_coffre)
                    try:
                        spans_xpath = "//span[contains(@class, 'Text_Text_text Icon-button_IconButton_label Text_Text_label2')]"
                        action_aleatoire(driver)
                        spans = driver.find_elements(By.XPATH, spans_xpath)
                        time.sleep(random.uniform(2, 4))
        # Nombre de spans
                        num_spans = len(spans)
                        point_forts_values = []
        # Créer des variables dynamiquement
                        for index, span in enumerate(spans, start=1):
            # Utilisation de JavaScript pour extraire le texte
                            span_text = driver.execute_script("return arguments[0].textContent;", span)
                            variable_name = f"point_fort{index}"
                            locals()[variable_name] = span_text.strip()
                             #print(f"{variable_name}:", locals()[variable_name])
                            point_forts_values.append(locals()[variable_name])


                    except NoSuchElementException:
        # Si la div n'est pas trouvée sur la page du lien, afficher un message
                        for index in range(1, num_spans + 1):
                            variable_name = f"point_fort{index}"
                            locals()[variable_name] = " "
                            print(f"{variable_name}: not found")
                            point_forts_values.append(locals()[variable_name])

                        # Ajouter le tuple de valeurs des points forts à la liste data
                    data.append(tuple(point_forts_values))
                    h3_values = []
                    try:
                        h3_xpath = "//h3[contains(@class, 'Text_Text_text Text_Text_subtitle1')]"

                        h3_elements = driver.find_elements(By.XPATH, h3_xpath)
                        time.sleep(random.uniform(2, 3))

                        for h3_element in h3_elements:
                            try:
                                ul_element = h3_element.find_element(By.XPATH, "following-sibling::ul")

                                li_elements = ul_element.find_elements(By.XPATH, "li")
                                li_values = []
                                time.sleep(random.uniform(2, 3))
                                for index, li_element in enumerate(li_elements, start=0):
                                    
                                    try:
                                        # Essayer de trouver le texte du span directement
                                        first_span_xpath = ".//span[contains(@class, 'Text_Text_text Text_Text_subtitle2')]"
                                        first_span_element = find_element_with_retry(li_element, By.XPATH, first_span_xpath)
                                        variable_name = first_span_element.get_attribute('textContent')

                                        span_xpath = ".//span[@class='Item_content__Xyd3d']"
                                        span_element = find_element_with_retry(li_element, By.XPATH, span_xpath)
                                        variable_value = span_element.get_attribute('textContent')

                                    except NoSuchElementException:
                                        # Si le premier essai échoue, essayer de trouver le texte du span à l'intérieur
                                        span_xpath = ".//span[@class='Item_content__Xyd3d']//span"
                                        span_element = find_element_with_retry(li_element, By.XPATH, span_xpath)
                                        variable_value = span_element.get_attribute('textContent')
                                    li_values.append((variable_name, variable_value))
                                    # Maintenant, vous avez la valeur du texte du span, que ce soit directement ou à l'intérieur
                                    #print(f"Nom de la variable : {variable_name}, Valeur de la variable : {variable_value}")
                                h3_values.append(tuple(li_values))

                            except NoSuchElementException:
                                pass

                    except NoSuchElementException:
                        print("H3 non trouvé")
                    data.append(tuple(h3_values))
                    ########################EN COURS######################  
                    button_class_name = "Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline"

                    try:
                        # Find the button using its class name
                        button = driver.find_element(By.CLASS_NAME, button_class_name)

                        # Click the button
                        button.click()

                        print("Button clicked successfully")

                    except NoSuchElementException:
                        print(f"Button with class name '{button_class_name}' not found")
                    except Exception as e:
                        print(f"An error occurred: {e}")

                    ####Scrappe equipement####
                    xpath_button_options = "//div[contains(@class, 'EquipmentOptionsInformation_linkMoreEquipments__rd-QS')]//button[contains(@class, 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline')]"
                    try:
                        # Attendre que le bouton soit cliquable
                        button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, xpath_button_options)))

                        # Utiliser ActionChains pour survoler et cliquer sur le bouton
                        action = ActionChains(driver)
                        action.move_to_element(button).click().perform()

                        print("Button clicked successfully")

                    except NoSuchElementException:
                        print(f"Button with XPath '{xpath_button_options}' not found")
                    except Exception as e:
                        print(f"An error occurred: {e}")

                    ####Scrappe equipement####
                    # Dictionnaire pour stocker les résultats
                    results = {}



                    # XPath pour sélectionner les uls
                    ul_xpaths = "//ul[contains(@class, 'EquipmentOptionsInformation_column__rQp-a')]"

                    # Parcourir les uls
                    uls = driver.find_elements(By.XPATH, ul_xpaths)
                    action_aleatoire(driver)
                    time.sleep(random.uniform(2, 5))
                    # Parcourir chaque ul
                    for ul_index, ul_element in enumerate(uls, start=1):
                        try:
                            # Trouver tous les li dans l'ul actuel
                            li_elements = ul_element.find_elements(By.XPATH, "./li")

                            # Parcourir chaque li
                            
                            for li_index, li_element in enumerate(li_elements, start=1):
                                # Obtenir tous les éléments h3 et div à l'intérieur du li
                                h3_elements = li_element.find_elements(By.XPATH, "./h3")
                                div_elements = li_element.find_elements(By.XPATH, "./div")

                                # Concaténer les textcontents de tous les h3 et div
                                li_textcontent = " ".join(element.get_attribute('textContent') for element in h3_elements + div_elements)

                                # Ajouter le résultat au dictionnaire
                                results[f"ul{ul_index}_li{li_index}"] = f",{li_textcontent}"

                        except NoSuchElementException:
                            print("UL non trouvé")

                    # Afficher les résultats
                    #for key, value in results.items():
                        #print(f"{key}: {value}")
                    data.append(tuple(results.values()))
                    data_final.append(data)
                    time.sleep(random.uniform(2, 3))
                    #print(data_final)
                    print("+1")
                    csv_file_path = "data.csv"
                    csv_columns = [
                        "Nom du véhicule",
                        "Caractéristiques",
                        "Prix",
                        "Durée de publication",
                        "Volume du coffre",
                        "Points forts",
                        "Équipements"
                    ]


                    with open('thread.csv', 'a', newline='', encoding='utf-8') as csvfile:
                        csv_writer = csv.writer(csvfile)
                        csv_writer.writerow(data)       



                except StaleElementReferenceException:
                    # Si l'élément de lien est obsolète, afficher un message
                    print("StaleElementReferenceException pour le lien :", link.get_attribute("href"))

                except StaleElementReferenceException:
                    # Si l'élément de lien est obsolète, afficher un message
                    print("StaleElementReferenceException pour le lien :", link)
                    pass
                except TimeoutException as e:
                    print(f"TimeoutException: {e}")
                    pass
                    # Handle the timeout exception
                except WebDriverException as e:
                    print(f"WebDriverException: {e}")
                    pass
        except StaleElementReferenceException:
            # If the element is stale, refind the links and continue
            print("StaleElementReferenceException. Refinding links.")
            links = driver.find_elements(By.XPATH, xpath_expression)
            continue
        except NoSuchElementException:
            # Si l'élément n'est pas trouvé, cela signifie probablement que la page n'existe pas
            print("Fin de la boucle : La page", current_page, "n'existe pas.")
            pass
        # Passer à la page suivante
        current_page += 1
        

    # Fermer le navigateur à la fin
    driver.quit()

# Number of threads
num_threads = 8

# Create a list to store WebDriver instances
drivers = [initialize_driver() for _ in range(num_threads)]

# Define the range of pages you want to scrape
start_page = 0
end_page = 500
# Calculate the step size to distribute pages evenly
step = (end_page - start_page) // num_threads
# Create a list to store thread links
thread_links = [[] for _ in range(num_threads)]
# Use ThreadPoolExecutor to run tasks concurrently
with ThreadPoolExecutor(max_workers=num_threads) as executor:
    # Submit tasks to the pool for the specified range of pages
    futures = [executor.submit(scrape_page, base_url, page, step, driver, thread_links[i]) for i, (page, driver) in enumerate(zip(range(start_page, end_page, step), drivers))]

    # Wait for all tasks to complete
    for future in futures:
        future.result()

# Close the WebDriver instances
for driver in drivers:
    driver.quit()
# Out:
# ['https://www.lacentrale.fr/auto-occasion-annonce-87102822375.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102714874.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112569060.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102638239.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113210160.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102620832.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113095433.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102789764.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113219675.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102815475.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112591371.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113195531.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112595210.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113177441.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113230162.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112753855.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102822375.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113187730.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112799065.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112768943.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113127128.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113227405.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113060154.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113242774.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113184518.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113243251.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112713199.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113236977.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113234084.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113246365.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113172406.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112715178.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112911752.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113187730.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69112842473.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113043708.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102780222.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113202650.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113199460.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112151798.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112851116.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113062483.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113202311.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102758115.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102805324.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112939154.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113233649.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112624620.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113162231.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102773919.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112842473.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113174922.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112367318.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112687744.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102702145.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113202090.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112626350.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102785673.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112970163.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112693517.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112908111.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102479917.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112985446.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113129558.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113230227.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113003040.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112944740.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113174922.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113127601.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113135547.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112964235.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102527655.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113051823.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113035951.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112715438.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113217091.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112477570.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112730540.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113192889.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102809606.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102818413.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112834665.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111445662.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113235454.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113127601.html
# StaleElementReferenceException. Refinding links.
# ['https://www.lacentrale.fr/auto-occasion-annonce-87102461814.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113087942.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102818891.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111815108.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102754741.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112657525.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113152842.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113226587.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112568919.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112982762.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112873056.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112891849.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111732642.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113007745.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112196739.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113217611.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102461814.html
# ['https://www.lacentrale.fr/auto-occasion-annonce-69113066367.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113199494.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102782224.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102808617.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102376675.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112980309.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112395854.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111846032.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113175761.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102821897.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112878611.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113108686.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113055851.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112904948.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113095912.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113070614.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113066367.html
# StaleElementReferenceException. Refinding links.
# Nom du véhicule: PEUGEOT 308 II phase 2
# Nom du véhicule: PORSCHE 911 TYPE 991 CABRIOLET TURBO phase 2
# Nom du véhicule: RENAULT GRAND SCENIC IV
# Nom du véhicule: VOLKSWAGEN T-ROC CABRIOLET
# Nom du véhicule: MERCEDES CLASSE C III SW AMG
# ['https://www.lacentrale.fr/auto-occasion-annonce-69111475181.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113056038.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112863805.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112678345.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113153356.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112424246.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112938276.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69111846082.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113062507.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69112844890.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102752795.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113224366.html', 'https://www.lacentrale.fr/auto-occasion-annonce-87102725363.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113230727.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113112847.html', 'https://www.lacentrale.fr/auto-occasion-annonce-69113087197.html']
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111475181.html
# Nom du véhicule: AUDI Q3 II
# Nom du véhicule: OPEL CROSSLAND phase 2
# Nom du véhicule: PEUGEOT 5008 II phase 2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112367318.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102714874.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112799065.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113043708.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113199494.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113135547.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113087942.html
# An error occurred: Message:
#
# Nom du véhicule: RENAULT KADJAR phase 2
# Nom du véhicule: NISSAN QASHQAI II phase 2
# Nom du véhicule: MASERATI LEVANTE
# Nom du véhicule: PEUGEOT 308 (3E GENERATION)
# Nom du véhicule: CITROEN JUMPY III FOURGON
# Nom du véhicule: FORD B-MAX
# Nom du véhicule: PEUGEOT 2008 II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113056038.html
# Nom du véhicule: NISSAN X-TRAIL III
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112687744.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112768943.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112569060.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102780222.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112964235.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102782224.html
# Nom du véhicule: BENTLEY BENTAYGA phase 2
# Nom du véhicule: FIAT TALENTO PANORAMA
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102818891.html
# An error occurred: Message:
#
# Nom du véhicule: MERCEDES CLA phase 2
# Nom du véhicule: BMW SERIE 1 F20 5 PORTES phase 2
# Nom du véhicule: FORD PUMA II
# Nom du véhicule: BMW X1 F48
# Nom du véhicule: PEUGEOT 208
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112863805.html
# Nom du véhicule: BMW X1 F48 phase 2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113127128.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102527655.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102702145.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113202650.html
# Nom du véhicule: FIAT 500 X phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102808617.html
# Nom du véhicule: TESLA MODEL Y
# Nom du véhicule: MINI III 3P
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111815108.html
# Nom du véhicule: PEUGEOT 3008 II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102638239.html
# An error occurred: Message:
#
# Nom du véhicule: TOYOTA AURIS II
# Nom du véhicule: MINI III 5P
# Nom du véhicule: PEUGEOT 208 II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112678345.html
# Nom du véhicule: VOLKSWAGEN T-CROSS
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113227405.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113202090.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113199460.html
# Nom du véhicule: AUDI A1 II SPORTBACK
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102754741.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113051823.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113210160.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102376675.html
# Nom du véhicule: AUDI S6 AVANT V
# Nom du véhicule: PEUGEOT 2008 phase 2
# An error occurred: Message:
#
# Nom du véhicule: VOLKSWAGEN GOLF VIII GTI
# Nom du véhicule: SEAT TARRACO
# Nom du véhicule: JAGUAR XE
# Nom du véhicule: BMW SERIE 2 F46 GRAN TOURER phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113153356.html
# Nom du véhicule: LAND ROVER RANGE ROVER EVOQUE phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112626350.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113060154.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112657525.html
# Nom du véhicule: FIAT 500 X phase 2
# Nom du véhicule: SKODA KAMIQ
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112151798.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113035951.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102620832.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112980309.html
# Nom du véhicule: PEUGEOT 508 II
# An error occurred: Message:
#
# Nom du véhicule: CITROEN C5 AIRCROSS
# Nom du véhicule: JAGUAR E-PACE phase 2
# Nom du véhicule: HYUNDAI IONIQ
# Nom du véhicule: PEUGEOT 3008 II phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112424246.html
# Nom du véhicule: VOLKSWAGEN T-ROC phase 2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102785673.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113152842.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113242774.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Nom du véhicule: ALFA ROMEO GIULIETTA III phase 2
# Nom du véhicule: LEXUS UX
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: AUDI A1 phase 2
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113095433.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112851116.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112715438.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112395854.html
# An error occurred: Message:
#
# Nom du véhicule: NISSAN QASHQAI III
# Nom du véhicule: VOLVO XC90 II
# Nom du véhicule: PEUGEOT E-208 II
# Nom du véhicule: MERCEDES GLE
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112938276.html
# Nom du véhicule: PEUGEOT 308 III
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112970163.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113184518.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113226587.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: PEUGEOT 308 (2E GENERATION) SW
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT 508
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113217091.html
# Nom du véhicule: CITROEN C3 AIRCROSS
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102789764.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113062483.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111846032.html
# An error occurred: Message:
#
# Nom du véhicule: VOLKSWAGEN POLO VI
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111846082.html
# Nom du véhicule: SEAT ATECA
# Nom du véhicule: PEUGEOT 208 phase 2
# Nom du véhicule: PEUGEOT 5008 II phase 2
# Nom du véhicule: VOLKSWAGEN TIGUAN 2 ALLSPACE
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112693517.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113243251.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: RENAULT CAPTUR II
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112568919.html
# Nom du véhicule: MERCEDES GLA II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112477570.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Nom du véhicule: NISSAN QASHQAI 3
# Nom du véhicule: VOLKSWAGEN T-ROC phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113175761.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113062507.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113219675.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113202311.html
# Nom du véhicule: AUDI Q3 II SPORTBACK
# Nom du véhicule: CITROEN C1 II
# Nom du véhicule: KIA SPORTAGE III
# Nom du véhicule: CITROEN BERLINGO II MULTISPACE phase 3
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112908111.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112713199.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: FORD TOURNEO CUSTOM II FOURGON II phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112730540.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Nom du véhicule: JEEP WRANGLER IV phase 2
# An error occurred: Message:
#
# Nom du véhicule: AUDI Q5 (2E GENERATION)
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102821897.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112844890.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102758115.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102815475.html
# Nom du véhicule: PEUGEOT 5008 II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112982762.html
# Nom du véhicule: OPEL MOKKA II
# Nom du véhicule: HONDA JAZZ II
# Nom du véhicule: BMW SERIE 3 G80 M3
# Nom du véhicule: NISSAN QASHQAI III
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102479917.html
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: OPEL CROSSLAND phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113192889.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113236977.html
# An error occurred: Message:
#
# Nom du véhicule: PORSCHE TAYCAN
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112878611.html
# Nom du véhicule: RENAULT CLIO IV phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102752795.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112591371.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112873056.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102805324.html
# Nom du véhicule: CITROEN JUMPY III FOURGON
# Nom du véhicule: VOLKSWAGEN GOLF VII SW phase 2
# Nom du véhicule: MINI III 5P
# Nom du véhicule: JEEP GRAND CHEROKEE IV phase 2
# Nom du véhicule: PEUGEOT 208 (2E GENERATION)
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112985446.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Nom du véhicule: AUDI A3 IV SPORTBACK
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113234084.html
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102809606.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# Nom du véhicule: MERCEDES GLC 2
# An error occurred: Message:
#
# Nom du véhicule: TOYOTA C-HR phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113108686.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113224366.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113195531.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112939154.html
# Nom du véhicule: PORSCHE PANAMERA II SPORT TURISMO
# Nom du véhicule: PEUGEOT 2008 phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112891849.html
# Nom du véhicule: AUDI A5 SPORTBACK II phase 2
# Nom du véhicule: DACIA SANDERO II phase 2
# Nom du véhicule: RENAULT MASTER III phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113129558.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: FORD MUSTANG VI COUPE phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113246365.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102818413.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Nom du véhicule: FORD PUMA II
# Nom du véhicule: FORD ECOSPORT phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102725363.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112595210.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113055851.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113233649.html
# Nom du véhicule: PORSCHE PANAMERA
# Nom du véhicule: VOLKSWAGEN GOLF VII R phase 2
# Nom du véhicule: VOLKSWAGEN T-ROC
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111732642.html
# Nom du véhicule: PEUGEOT 208 II
# Nom du véhicule: PEUGEOT 3008 II
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113230227.html
# Nom du véhicule: AUDI A6 V AVANT
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112834665.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113172406.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT E-208 II
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Nom du véhicule: BMW X4 G02
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112624620.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113230727.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112904948.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113177441.html
# Nom du véhicule: VOLKSWAGEN TAIGO
# Nom du véhicule: PEUGEOT 3008 II
# An error occurred: Message:
#
# Nom du véhicule: SKODA OCTAVIA III COMBI phase 2
# Nom du véhicule: PEUGEOT 208 II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113007745.html
# Nom du véhicule: PEUGEOT 208 II
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113003040.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: VOLKSWAGEN GOLF 8
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112715178.html
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111445662.html
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113112847.html
# Nom du véhicule: TOYOTA COROLLA XII phase 2
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113162231.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113230162.html
# Nom du véhicule: PEUGEOT 2008 phase 2
# Nom du véhicule: PORSCHE MACAN
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113095912.html
# An error occurred: Message:
#
# Nom du véhicule: VOLKSWAGEN PASSAT VIII SW phase 2
# Nom du véhicule: RENAULT CLIO V
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112196739.html
# Nom du véhicule: AUDI A3 III SPORTBACK phase 2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Nom du véhicule: BMW X2 F39
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112944740.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT 3008 II phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113087197.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113235454.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112911752.html
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112753855.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102773919.html
# Nom du véhicule: PEUGEOT 2008 II phase 2
# Nom du véhicule: AUDI A5 CABRIOLET
# An error occurred: Message:
#
# Nom du véhicule: PEUGEOT 208 II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113070614.html
# Nom du véhicule: MERCEDES CLASSE E V COUPE
# Nom du véhicule: MINI MINI 3 3P
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113217611.html
# Nom du véhicule: AUDI RS Q8
# Nom du véhicule: RENAULT ESPACE V phase 2
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# ...
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102736961.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102807349.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112551831.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113102209.html
# An error occurred: Message:
#
# Nom du véhicule: FORD PUMA II
# Nom du véhicule: PORSCHE 911 TYPE 992
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112071360.html
# Nom du véhicule: BMW Z3
# Nom du véhicule: FORD FIESTA VI ACTIVE
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: AUDI A3 IV SPORTBACK
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111846028.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111846009.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102760202.html
# Nom du véhicule: VOLKSWAGEN TIGUAN 2
# Nom du véhicule: VOLKSWAGEN TIGUAN 2
# Nom du véhicule: BMW SERIE 1 F21 3 PORTES phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112282792.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113206884.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113028480.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113216706.html
# An error occurred: Message:
#
# Nom du véhicule: VOLKSWAGEN GOLF 7 SW
# Nom du véhicule: OPEL CORSA V
# Nom du véhicule: CITROEN C5 AIRCROSS phase 2
# Nom du véhicule: PORSCHE 911 TYPE 993
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113187336.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: CITROEN C1 II
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113192544.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102813881.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102630323.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Nom du véhicule: AUDI A3 III SPORTBACK phase 2
# Nom du véhicule: PEUGEOT 307 CC phase 2
# Nom du véhicule: RENAULT KADJAR
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113162480.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112851802.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113132063.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113241274.html
# An error occurred: Message:
#
# Nom du véhicule: CITROEN C3 AIRCROSS
# Nom du véhicule: JEEP AVENGER
# Nom du véhicule: PEUGEOT 208 II
# Nom du véhicule: AUDI Q5 II SPORTBACK phase 2
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113131862.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: RENAULT CLIO V
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113156609.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113177951.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113192633.html
# Nom du véhicule: AUDI Q5 II phase 2
# Nom du véhicule: PEUGEOT 2008 II
# Nom du véhicule: DACIA DUSTER II phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111870210.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112980081.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113175752.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112961457.html
# An error occurred: Message:
#
# Nom du véhicule: VOLKSWAGEN GOLF SPORTSVAN
# Nom du véhicule: VOLKSWAGEN ARTEON
# Nom du véhicule: FORD FIESTA V phase 2
# Nom du véhicule: FIAT TIPO II COMMERCIALE
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102797314.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: SUZUKI SWIFT II
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113218048.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69111846073.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112138327.html
# Nom du véhicule: PEUGEOT 208 phase 2
# Nom du véhicule: AUDI Q3
# Nom du véhicule: MERCEDES CLASSE C IV
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113142206.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102513077.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113220179.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113092162.html
# An error occurred: Message:
#
# Nom du véhicule: CITROEN C3 (3E GENERATION)
# Nom du véhicule: FORD PUMA II
# Nom du véhicule: FORD TRANSIT IV
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112746322.html
# Nom du véhicule: FIAT 500 II phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: AUDI A1 SPORTBACK
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113195953.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102663277.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113218060.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Nom du véhicule: MINI III CLUBMAN phase 2
# Nom du véhicule: SEAT ATECA
# Nom du véhicule: LAND ROVER DISCOVERY SPORT
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112956378.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113193436.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-87102791280.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112987746.html
# An error occurred: Message:
#
# Nom du véhicule: AUDI Q3 II SPORTBACK
# Nom du véhicule: AUDI Q3 II
# Nom du véhicule: PEUGEOT 308 II phase 2
# Nom du véhicule: RENAULT KANGOO II EXPRESS phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113175249.html
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: PEUGEOT 3008 II
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113246809.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113115592.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113107012.html
# Élément non trouvé après 15 secondes. Continuer avec le reste du code.
# Nom du véhicule: SEAT IBIZA V phase 2
# Nom du véhicule: RENAULT CAPTUR phase 2
# Nom du véhicule: PEUGEOT 3008 II
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:507:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:132:16
#
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112114247.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112982977.html
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69112933661.html
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113157062.html
# Nom du véhicule: AUDI Q3 II
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113020431.html
# Nom du véhicule: JEEP AVENGER
# Nom du véhicule: AUDI Q2 phase 2
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: BMW X5 G05
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Button with class name 'Hyperlink_Hyperlink_hyperlink Hyperlink_Hyperlink_primary Hyperlink_Hyperlink_underline' not found
# Nom du véhicule: PEUGEOT 308 III
# An error occurred: Message:
#
# An error occurred: Message:
#
# An error occurred: Message:
#
# +1
# Lien trouvé : https://www.lacentrale.fr/auto-occasion-annonce-69113108957.html
