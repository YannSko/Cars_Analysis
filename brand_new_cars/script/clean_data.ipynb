# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
from urllib.request import Request,urlopen 
import csv
import os
import time

 # Parser la page
#Product = page.findAll("div","flex flex-1 flex-col p-3") 
# Permet d'avoir tout les produits ( comics )

for compteur in range(1,56,1) :
    site = 'https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page='+str(compteur)+'&yearMax=1980'
    req = Request(site,headers={'User-agent':'Mozilla/5.0'})
    webpage = urlopen(req)
    page = bs(webpage,"html.parser")
    print(site)
    time.sleep(2)

    for CompteurVoiture in range(1,16,1):
        voiture = page.findAll("a",class_="Vehiculecard_Vehiculecard_vehiculeCard Containers_Containers_containers Containers_Containers_borderRadius Containers_Containers_darkShadowWide")
        nom = voiture[CompteurVoiture].findAll("h2",class_="Text_Text_text Vehiculecard_Vehiculecard_title Text_Text_subtitle2")
        prix = voiture[CompteurVoiture].findAll("span",class_="Text_Text_text Vehiculecard_Vehiculecard_price Text_Text_subtitle2")
        AKBC = voiture[CompteurVoiture].findAll("div",class_="Vehiculecard_Vehiculecard_characteristics")
        ModelPrecis = voiture[CompteurVoiture].findAll("div",class_="Text_Text_text Vehiculecard_Vehiculecard_subTitle Text_Text_body2")


        print('\n')
        print(nom[0].text)
        print(ModelPrecis[0].text)
        print(AKBC[0].text+'')
        print(prix[0].text)
# Out:
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=1&yearMax=1980
#
#
# FORD MUSTANG COUPE
# COUPE GT 289CI V8
# 1966124 000 kmManuelleEssence
# 52 700 €
#
#
# TRIUMPH TR 4
# 2.2 100
# 196890 000 kmManuelleEssence
# 32 280 €
#
#
# CHEVROLET C10
# V8 CUSTOM 350CI 5.7L
# 197155 000 kmAutomatiqueEssence
# 29 150 €
#
#
# JAGUAR MK IV
# I 1/2
# 1947156 738 kmManuelleEssence
# 40 570 €
#
#
# FORD MUSTANG COUPE
# FASTBACK 351 MACH 1
# 197058 000 kmAutomatiqueEssence
# 78 760 €
#
#
# FORD MUSTANG COUPE
# COUPE 289CI V8 BURGUNDY
# 196782 500 kmAutomatiqueEssence
# 39 490 €
#
#
# VOLKSWAGEN COMBI
# T2
# 1974117 809 kmManuelleEssence
# 43 400 €
#
#
# FORD MUSTANG CABRIOLET
# CABRIOLET GRIS BANDES NOIRES V8
# 196872 000 kmAutomatiqueEssence
# 71 980 €
#
#
# PORSCHE 914
# 1.7 80
# 197280 040 kmManuelleEssence
# 52 180 €
#
#
# LANCIA FLAVIA
# 1.8 110 ZAGATO
# 196760 248 kmManuelleEssence
# 121 980 €
#
#
# ALFA ROMEO GIULIA GT
# 1.6 103 GT
# 19663 060 kmManuelleEssence
# 74 410 €
#
#
# FORD MUSTANG
# FASTBACK BULLITT V8
# 196893 600 kmManuelleEssence
# 97 110 €
#
#
# FORD MUSTANG
# FASTBACK 302CI BULLITT
# 196888 956 kmManuelleEssence
# 105 270 €
#
#
# FORD MUSTANG COUPE
# COUPE TOIT VINYLE CORAIL 289CI V8
# 1969153 942 kmAutomatiqueEssence
# 41 890 €
#
#
# FORD MUSTANG COUPE
# FASTBACK 289 CI V8 BULLITT
# 196878 671 kmAutomatiqueEssence
# 83 460 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=2&yearMax=1980
#
#
# FORD MUSTANG CABRIOLET
# CABRIOLET CODE A TRIPPLE BLACK
# 196884 000 kmAutomatiqueEssence
# 56 680 €
#
#
# CHEVROLET CORVETTE C2 CABRIOLET
# 5.4 V8 365
# 196412 966 kmManuelleEssence
# 75 400 €
#
#
# FORD MUSTANG
# 3.3 CI 101
# 196621 640 kmAutomatiqueEssence
# 40 280 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 1966100 860 kmAutomatiqueEssence
# 61 480 €
#
#
# FORD MUSTANG COUPE
# COUPE GOLD 289CI V8
# 196995 200 kmAutomatiqueEssence
# 45 810 €
#
#
# MG A COUPE
# 1.5 72
# 196047 875 kmManuelleEssence
# 39 370 €
#
#
# SAAB 96
# E
# 1973260 573 kmManuelleEssence
# 9 520 €
#
#
# CHEVROLET CAMARO COUPE
# V8 210
# 1968179 685 kmManuelleEssence
# 64 120 €
#
#
# TRIUMPH TR 3
# 2.0 100
# 196114 790 kmManuelleEssence
# 32 450 €
#
#
# FORD MUSTANG CABRIOLET
# CABRIOLET CODE A V8
# 196884 000 kmAutomatiqueEssence
# 54 490 €
#
#
# FORD MUSTANG COUPE
# 4.7 CI 271 FASTBACK
# 196866 600 kmAutomatiqueEssence
# 94 350 €
#
#
# BMW M1
# 3.5 M
# 198069 215 kmManuelleEssence
# 653 980 €
#
#
# FORD MUSTANG COUPE
# COUPE V8
# 196779 500 kmAutomatiqueEssence
# 39 750 €
#
#
# VOLKSWAGEN COMBI
# T1
# 197641 967 kmManuelleEssence
# 40 230 €
#
#
# VOLKSWAGEN COCCINELLE
# 1200
# 197616 971 kmManuelleEssence
# 18 530 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=3&yearMax=1980
#
#
# FORD GT
# V8 AC COBRA FF SMALL BLOCK
# 196438 280 kmManuelleEssence
# 110 190 €
#
#
# MERCEDES 230
# 120
# 19774 411 kmManuelleEssence
# 21 780 €
#
#
# FORD F250
# PICK-UP
# 196751 299 kmManuelleEssence
# 22 680 €
#
#
# LAND ROVER LAND SERIE 2
# 88
# 196635 547 kmManuelleDiesel
# 67 850 €
#
#
# JAGUAR TYPE E COUPE
# 4.2 265
# 197016 302 kmManuelleEssence
# 81 480 €
#
#
# CHEVROLET CORVETTE C3
# C3 5.7 350 CI V8 COOPER
# 1973100 800 kmAutomatiqueEssence
# 47 600 €
#
#
# FORD MUSTANG COUPE
# COUPE VERTE 289CI V8 BOITE MECA
# 19675 900 kmManuelleEssence
# 44 250 €
#
#
# MG B
# V8 COLLECTION 3.5 CARTE GRISE
# 198010 618 kmManuelleEssence
# 42 220 €
#
#
# ALFA ROMEO 2600 SPRINT
# 2.6 145
# 196438 850 kmManuelleEssence
# 52 480 €
#
#
# FORD MUSTANG COUPE
# COUPE CODE A GT
# 196687 200 kmManuelleEssence
# 49 590 €
#
#
# FIAT 500
# 0.6 18
# 1973103 797 kmManuelleEssence
# 26 770 €
#
#
# FORD MUSTANG CABRIOLET
# CABRIOLET 302 CI V18 69
# 197095 400 kmAutomatiqueEssence
# 46 110 €
#
#
# FIAT 500
# 0.6 18
# 197030 067 kmManuelleEssence
# 17 100 €
#
#
# FIAT 500
# 0.6 18
# 197456 kmManuelleEssence
# 16 780 €
#
#
# FIAT 500
# 2P
# 1964575 kmManuelleEssence
# 26 430 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=4&yearMax=1980
#
#
# TRIUMPH SPITFIRE
# FH
# 1979138 714 kmManuelleEssence
# 21 830 €
#
#
# FIAT 500
# 0.6 18
# 197025 828 kmManuelleEssence
# 14 280 €
#
#
# CITROEN MEHARI
# 0.6 29
# 197933 759 kmManuelleEssence
# 26 490 €
#
#
# AUSTIN HEALEY 3000 ROADSTER
# 2.9 124
# 196225 810 kmManuelleEssence
# 62 580 €
#
#
# PEUGEOT 403
# E
# 196167 336 kmManuelleEssence
# 86 250 €
#
#
# FIAT 500
# L 110F
# 19747 062 kmManuelleEssence
# 15 800 €
#
#
# VOLKSWAGEN KARMAN GHIA
# 1.6 50
# 197488 800 kmManuelleEssence
# 33 070 €
#
#
# FORD MUSTANG COUPE
# FASTBACK CODE J 302 CI V8 GRISE
# 196964 200 kmManuelleEssence
# 77 040 €
#
#
# FIAT 500
# 0.6 18
# 197312 kmManuelleEssence
# 19 180 €
#
#
# JAGUAR XK ROADSTER
# ROADSTER 120
# 195594 266 kmManuelleEssence
# 128 520 €
#
#
# FIAT 500
# 0.6 18
# 19726 924 kmManuelleEssence
# 17 420 €
#
#
# FIAT 500
# 2P
# 196622 kmManuelleEssence
# 19 420 €
#
#
# MERCEDES SL
# 450 V8 218 218CH + SL HARD TOP +
# 1979100 601 kmAutomatiqueEssence
# 31 300 €
#
#
# FORD MUSTANG COUPE
# V8 RESTOMOD
# 19666 858 kmAutomatiqueEssence
# 64 900 €
#
#
# MERCEDES 230
# 120
# 196594 075 kmManuelleEssence
# 102 350 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=5&yearMax=1980
#
#
# MASERATI BORA
# V8 310
# 197349 280 kmManuelleEssence
# 200 480 €
#
#
# PORSCHE 911 TYPE 901
# L
# 197294 095 kmManuelleEssence
# 122 870 €
#
#
# JAGUAR TYPE E COUPE
# V12 272
# 197337 720 kmAutomatiqueEssence
# 76 930 €
#
#
# CHEVROLET CORVETTE C1 CABRIOLET
# 3.9 150
# 195758 000 kmAutomatiqueEssence
# 111 340 €
#
#
# PORSCHE 356 SPEEDSTER
# SPEEDSTER
# 19603 404 kmManuelleEssence
# 298 530 €
#
#
# PEUGEOT 203
# 42
# 1953110 086 kmManuelleEssence
# 22 300 €
#
#
# JAGUAR TYPE E COUPE
# 3.8 265
# 196434 598 kmManuelleEssence
# 133 750 €
#
#
# FORD MUSTANG CABRIOLET
# CI 228
# 197423 798 kmAutomatiqueEssence
# 44 620 €
#
#
# MASERATI INDY
# 5.0 V8 320
# 197729 430 kmManuelleEssence
# 92 650 €
#
#
# TRIUMPH TR 4
# 2.2 100
# 19653 245 kmManuelleEssence
# 49 580 €
#
#
# RENAULT 4CV
# 0.7 17
# 195778 299 kmManuelleEssence
# 25 440 €
#
#
# PEUGEOT 404
# E
# 196642 689 kmManuelleEssence
# 9 920 €
#
#
# JAGUAR TYPE E COUPE
# V12 272
# 1972118 320 kmAutomatiqueEssence
# 69 480 €
#
#
# PORSCHE 911 TYPE 901
# 2.4 E
# 1974212 100 kmManuelleEssence
# 126 380 €
#
#
# PEUGEOT 304 COUPE
# COUPE
# 1973166 675 kmManuelleEssence
# 19 210 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=6&yearMax=1980
#
#
# PEUGEOT 504 COUPE
# 2.7 V6 136
# 1978218 790 kmManuelleEssence
# 29 600 €
#
#
# FIAT 500
# 1971CH L ATTACHANTE PETITE AUTO
# 1973105 000 kmManuelleEssence
# 14 870 €
#
#
# BMW 2002
# 2.0 170
# 1974152 211 kmManuelleEssence
# 41 010 €
#
#
# LANCIA FLAMINIA COUPE
# GT 2.5 3C SUPERLEGGERA SUBLIME
# 196374 104 kmManuelleEssence
# 135 700 €
#
#
# ALFA ROMEO GIULIA
# 1.6 92 TI
# 196444 840 kmManuelleEssence
# 96 760 €
#
#
# JAGUAR TYPE E CABRIOLET
# CABRIOLET
# 19639 519 kmManuelleEssence
# 191 400 €
#
#
# FIAT 500
# 2P
# 197478 750 kmManuelleEssence
# 16 780 €
#
#
# PORSCHE 356
# 1.6 75 S
# 19643 510 kmManuelleEssence
# 98 860 €
#
#
# JEEP CJ5
# LAREDO
# 19761 830 kmManuelleEssence
# 35 360 €
#
#
# PORSCHE 928
# 4.5 240
# 1979126 707 kmManuelleEssence
# 36 510 €
#
#
# MG A
# 1.5 72
# 19593 532 kmManuelleEssence
# 43 380 €
#
#
# MERCEDES SL
# 2.8 280 170 PAGODE
# 197845 375 kmAutomatiqueEssence
# 54 450 €
#
#
# FERRARI 208
# 2.0 V8 170 GT4
# 197649 020 kmManuelleEssence
# 62 580 €
#
#
# ROLLS ROYCE SILVER CLOUD
# 4.9
# 195761 761 kmAutomatiqueEssence
# 71 280 €
#
#
# PORSCHE 912 TARGA
# 1.6 90 TARGA
# 1969141 668 kmManuelleEssence
# 89 770 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=7&yearMax=1980
#
#
# BENTLEY S1
# 4.9 160
# 196073 800 kmAutomatiqueEssence
# 59 040 €
#
#
# ABARTH SCORPION
# E
# 197111 kmManuelleEssence
# 23 640 €
#
#
# JAGUAR XK
# 140
# 196059 670 kmManuelleEssence
# 99 330 €
#
#
# HONDA S800
# 0.8 78
# 196896 380 kmManuelleEssence
# 39 650 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 306 GT SHELBY
# 19702 530 kmManuelleEssence
# 206 690 €
#
#
# CHEVROLET CORVETTE C2
# 5.4 V8 360 STINGRAY
# 197021 345 kmAutomatiqueEssence
# 63 020 €
#
#
# JAGUAR XJ6
# 4.2 205
# 197489 434 kmAutomatiqueEssence
# 26 980 €
#
#
# FORD MUSTANG COUPE
# 4.7 CI 271 FASTBACK
# 196953 198 kmAutomatiqueEssence
# 73 070 €
#
#
# CITROEN ACADIANE
# E
# 198038 870 kmManuelleEssence
# 14 370 €
#
#
# VOLKSWAGEN GOLF GTI
# 1.6 110 GTI
# 1981241 792 kmManuelleEssence
# 25 180 €
#
#
# FIAT 500
# 2P
# 1964121 kmManuelleEssence
# 27 810 €
#
#
# FORD COBRA
# 427CH BACKDRAFT RT3
# 19665 831 kmManuelleEssence
# 165 410 €
#
#
# FORD F1
# PICK UP FORD
# 195233 060 kmManuelleEssence
# 35 340 €
#
#
# ROLLS ROYCE SILVER SHADOW
# 6.8 V8
# 1977125 190 kmAutomatiqueEssence
# 32 170 €
#
#
# AMC PACER phase 2
# 3.8 V8 130
# 1979128 960 kmManuelleEssence
# 32 240 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=8&yearMax=1980
#
#
# PORSCHE 912
# 1.6 90
# 197067 650 kmManuelleEssence
# 67 650 €
#
#
# PORSCHE 356 SPEEDSTER
# SPEEDSTER
# 197677 188 kmManuelleEssence
# 80 380 €
#
#
# FIAT 500
# 0.6 18
# 19707 736 kmManuelleEssence
# 15 940 €
#
#
# BMW 3.0
# 3.2 206 CSL
# 197698 338 kmManuelleEssence
# 434 000 €
#
#
# JAGUAR XJ
# 4.2 170CH XJC XJC4.2L
# 198074 580 kmAutomatiqueEssence
# 38 640 €
#
#
# JAGUAR TYPE E COUPE
# COUPE 3.8 SERIE 1
# 196464 735 kmManuelleEssence
# 143 380 €
#
#
# JAGUAR XK CABRIOLET
# CABRIOLET
# 1960105 840 kmManuelleEssence
# 147 960 €
#
#
# CITROEN 2CV
# AZAM
# 196594 490 kmManuelleEssence
# 14 000 €
#
#
# FIAT 500
# 0.6 18
# 19734 191 kmManuelleEssence
# 15 520 €
#
#
# MG C
# 2.9 147
# 196915 400 kmManuelleEssence
# 37 950 €
#
#
# ALFA ROMEO GIULIETTA SPRINT SPECIALE
# 1.3 90 SS
# 196652 030 kmManuelleEssence
# 60 480 €
#
#
# MERCEDES 280
# V8 SE BENZ 3.5
# 1973115 640 kmAutomatiqueEssence
# 30 660 €
#
#
# JAGUAR TYPE E COUPE
# 4.2 265
# 1969144 534 kmManuelleEssence
# 130 690 €
#
#
# TRIUMPH TR 6
# 104
# 197466 550 kmManuelleEssence
# 45 960 €
#
#
# FIAT 850 SPIDER
# SPIDER
# 197766 045 kmManuelleEssence
# 15 520 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=9&yearMax=1980
#
#
# CHEVROLET CORVETTE C3 CABRIOLET
# CABRIOLET C3 5.7 V8 350 CI BVA
# 197688 708 kmAutomatiqueEssence
# 30 770 €
#
#
# MERCEDES 190 SL
# 105
# 1963146 kmManuelleEssence
# 117 000 €
#
#
# FIAT 500
# 2P
# 197030 268 kmManuelleEssence
# 17 260 €
#
#
# PORSCHE 911 TYPE 901 CABRIOLET
# 2.0
# 196922 369 kmManuelleEssence
# 121 790 €
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI 228
# 198188 535 kmAutomatiqueEssence
# 36 590 €
#
#
# ALPINE A110
# 1.6 138 S2
# 197483 080 kmManuelleEssence
# 145 060 €
#
#
# ALFA ROMEO 1600
# E
# 196669 125 kmManuelleEssence
# 150 000 €
#
#
# MINI MINI 2 CLUBMAN
# ESTATE 1000 3P
# 197821 330 kmManuelleEssence
# 26 040 €
#
#
# ALFA ROMEO GT phase 3
# 2.0 130 VELOCE
# 1974103 662 kmManuelleEssence
# 69 620 €
#
#
# FIAT 500
# 0.6 18
# 19714 164 kmManuelleEssence
# 19 700 €
#
#
# CITROEN MEHARI
# 0.6
# 19702 856 kmManuelleEssence
# 29 750 €
#
#
# PORSCHE 911 TYPE 901
# 2.4 E TARGA 165 BT5
# 1975103 973 kmManuelleEssence
# 123 030 €
#
#
# FORD ESCORT
# 4P
# 197629 835 kmManuelleEssence
# 9 940 €
#
#
# JAGUAR TYPE E COUPE
# V12 272
# 19737 006 kmAutomatiqueEssence
# 77 400 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 E
# 197273 677 kmManuelleEssence
# 122 980 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=10&yearMax=1980
#
#
# PEUGEOT 504 CABRIOLET
# 2.0 104
# 198033 942 kmManuelleEssence
# 66 690 €
#
#
# MERCEDES 190 SL
# 105
# 1957118 580 kmManuelleEssence
# 121 000 €
#
#
# FORD MUSTANG COUPE
# 3.3 V8 122
# 1966115 900 kmAutomatiqueEssence
# 64 530 €
#
#
# MERCEDES 280
# 2.7 185 SE
# 197730 504 kmAutomatiqueEssence
# 18 600 €
#
#
# PEUGEOT 203 PICK-UP
# 42
# 1961141 700 kmManuelleEssence
# 2 720 €
#
#
# JAGUAR TYPE E CABRIOLET
# CABRIOLET
# 19651 928 kmManuelleEssence
# 169 580 €
#
#
# FERRARI DINO
# 246 GT GT
# 197436 750 kmManuelleEssence
# 414 750 €
#
#
# AUSTIN HEALEY 3000 ROADSTER
# 2.9 148
# 196763 765 kmManuelleEssence
# 74 660 €
#
#
# AC COBRA
# SHELBY AC COBRA AMERICAN
# 196659 375 kmManuelleEssence
# 118 750 €
#
#
# CITROEN DS
# IE PALLAS
# 1975101 520 kmManuelleEssence
# 34 560 €
#
#
# FIAT 500
# 0.6 18
# 197483 139 kmManuelleEssence
# 9 520 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 S
# 197188 655 kmManuelleEssence
# 208 250 €
#
#
# PORSCHE 356
# 1.6 75
# 196611 600 kmManuelleEssence
# 126 920 €
#
#
# FIBERFAB BONITO FT
# GT 40
# 196675 692 kmManuelleEssence
# 19 260 €
#
#
# BUICK RIVIERA
# 8
# 195464 320 kmManuelleEssence
# 16 950 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=11&yearMax=1980
#
#
# MG B
# 1.8 97
# 1975856 kmManuelleEssence
# 19 390 €
#
#
# AUSTIN MINI
# 1000
# 197621 400 kmManuelleEssence
# 21 180 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 E
# 197190 000 kmManuelleEssence
# 127 500 €
#
#
# RENAULT JUVAQUATRE
# 1.0 24
# 194052 217 kmManuelleEssence
# 12 180 €
#
#
# MERCEDES 280
# 2.7 185 SE
# 197126 540 kmManuelleEssence
# 47 100 €
#
#
# HOTCHKISS AM 80
# CABOURG
# 193638 645 kmManuelleEssence
# 26 640 €
#
#
# FORD MUSTANG CABRIOLET
# CABRIOLET 289 CI
# 1968183 920 kmAutomatiqueEssence
# 54 430 €
#
#
# FERRARI 365
# 4.4 320
# 197182 655 kmManuelleEssence
# 294 980 €
#
#
# CHEVROLET CORVETTE C2
# C2 7.0 V8 425 STINGRAY
# 196784 468 kmAutomatiqueEssence
# 101 770 €
#
#
# ALFA ROMEO GIULIA GT
# 1.3 89 JUNIOR
# 197059 774 kmManuelleEssence
# 50 570 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 196668 615 kmAutomatiqueEssence
# 55 660 €
#
#
# PORSCHE 911 TYPE 901 CABRIOLET
# 2.0
# 197095 940 kmManuelleEssence
# 181 350 €
#
#
# AC COBRA
# 6.4 V8 475
# 196610 201 kmAutomatiqueEssence
# 172 480 €
#
#
# LAND ROVER LAND SERIE 3
# 2.5 67
# 1979101 787 kmManuelleDiesel
# 30 980 €
#
#
# PORSCHE 914
# 2.0 110
# 197110 413 kmManuelleEssence
# 122 730 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=12&yearMax=1980
#
#
# ROLLS ROYCE SILVER SHADOW
# 6.8 V8
# 1976171 750 kmAutomatiqueEssence
# 44 870 €
#
#
# FERRARI 308
# 2.9 255 GT4
# 197657 040 kmManuelleEssence
# 64 210 €
#
#
# ALFA ROMEO GIULIA
# 1.6 92 TI
# 196936 900 kmManuelleEssence
# 22 010 €
#
#
# PORSCHE 914
# 85
# 197592 053 kmManuelleEssence
# 40 250 €
#
#
# FORD MUSTANG COUPE
# 4.7 CI 271 FASTBACK
# 196835 637 kmAutomatiqueEssence
# 73 180 €
#
#
# VOLKSWAGEN 1200
# 1.2 34
# 197378 272 kmManuelleEssence
# 21 530 €
#
#
# PORSCHE 912 TARGA
# 1.6 90 TARGA
# 196924 769 kmManuelleEssence
# 105 910 €
#
#
# FERRARI 365
# 4.4 320
# 197156 874 kmManuelleEssence
# 314 890 €
#
#
# MERCEDES 280 SL
# 170 SL
# 1970126 348 kmManuelleEssence
# 142 800 €
#
#
# TRIUMPH TR 3
# B
# 196498 078 kmManuelleEssence
# 48 470 €
#
#
# PORSCHE 911 TYPE 901
# 2.7 210 CARRERA
# 197470 620 kmManuelleEssence
# 203 300 €
#
#
# MERCEDES SL
# 450
# 1977139 230 kmAutomatiqueEssence
# 29 630 €
#
#
# CITROEN DS
# 21 PALLAS PALLAS
# 197075 244 kmManuelleEssence
# 53 430 €
#
#
# MG TD
# 1.3
# 195324 936 kmManuelleEssence
# 60 370 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 T
# 1972189 736 kmManuelleEssence
# 107 910 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=13&yearMax=1980
#
#
# RENAULT R8
# 1.3 103 GORDINI
# 197033 674 kmManuelleEssence
# 90 390 €
#
#
# FORD MERCURY
# V8 MONTEREY
# 1965104 644 kmAutomatiqueEssence
# 44 000 €
#
#
# JAGUAR XK
# 140
# 19569 799 kmManuelleEssence
# 112 370 €
#
#
# ALPINE A310
# 2.7 V6 150
# 1979109 016 kmManuelleEssence
# 42 370 €
#
#
# CHEVROLET C10
# V8 UP
# 196932 534 kmAutomatiqueEssence
# 44 030 €
#
#
# AUSTIN HEALEY 3000 ROADSTER
# 2.9 134
# 19641 210 kmManuelleEssence
# 77 970 €
#
#
# CHEVROLET CORVETTE C1
# 5.4 360
# 1963102 840 kmManuelleEssence
# 82 730 €
#
#
# PORSCHE 911 TYPE 911
# 200 CARRERA
# 1978162 500 kmManuelleEssence
# 106 980 €
#
#
# MERCEDES 190 SL
# 105
# 19581 438 kmManuelleEssence
# 207 370 €
#
#
# MERCEDES SL
# 2.8 280 170 PAGODE
# 19724 060 kmAutomatiqueEssence
# 140 300 €
#
#
# LINCOLN CONTINENTAL COUPE
# COUPE
# 198014 000 kmAutomatiqueEssence
# 44 670 €
#
#
# JAGUAR XK
# OTS
# 19574 028 kmManuelleEssence
# 147 040 €
#
#
# MG A
# 1.6 72
# 196391 760 kmManuelleEssence
# 43 270 €
#
#
# LANCIA FULVIA
# 1.3 90 S
# 197720 651 kmManuelleEssence
# 23 210 €
#
#
# FORD MUSTANG
# 289CH SHELBY GT CLONE 350
# 196940 950 kmManuelleEssence
# 73 480 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=14&yearMax=1980
#
#
# JENSEN INTERCEPTOR MK III
# 6.3 V8 330
# 197566 236 kmAutomatiqueEssence
# 52 080 €
#
#
# PORSCHE 911 TYPE 901
# 2.4 S
# 197337 100 kmManuelleEssence
# 112 360 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 E
# 1972100 795 kmManuelleEssence
# 106 980 €
#
#
# CITROEN D
# BERLINE
# 1964130 836 kmManuelleEssence
# 42 030 €
#
#
# PORSCHE 912 TARGA
# 1.6 90 TARGA
# 1968104 026 kmManuelleEssence
# 103 380 €
#
#
# TRIUMPH TR 3
# TR3A 2.0 100 OVERDRIVE + CHAUFFAGE
# 1962137 760 kmManuelleEssence
# 34 720 €
#
#
# JAGUAR 3.8
# S 3.8
# 196693 600 kmAutomatiqueEssence
# 32 750 €
#
#
# PEUGEOT 203
# 42
# 195797 112 kmManuelleEssence
# 15 180 €
#
#
# ALFA ROMEO SPIDER
# 1.6
# 196723 211 kmManuelleEssence
# 122 870 €
#
#
# FORD B CABRIOLET
# TYPE 40
# 193533 790 kmAutomatiqueEssence
# 73 460 €
#
#
# AUSTIN MINI BREAK
# BREAK
# 197898 813 kmManuelleEssence
# 20 110 €
#
#
# BMW SERIE 5 E28
# 2.8 528I 184
# 1981128 400 kmManuelleEssence
# 23 980 €
#
#
# BMW 2002
# 2.0 120 TI
# 197436 727 kmManuelleEssence
# 26 480 €
#
#
# FERRARI 308
# 2.9 255 GTB
# 197947 745 kmManuelleEssence
# 148 080 €
#
#
# PORSCHE 356
# B 1600 T6
# 19657 232 kmManuelleEssence
# 89 260 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=15&yearMax=1980
#
#
# RENAULT R12
# 1.3 60 TS
# 197865 720 kmManuelleEssence
# 7 680 €
#
#
# RENAULT DAUPHINE
# 0.8 49
# 196552 892 kmManuelleEssence
# 59 290 €
#
#
# VOLKSWAGEN 1600
# E
# 197354 280 kmManuelleEssence
# 31 840 €
#
#
# CHEVROLET CORVETTE C1 CABRIOLET
# 3.9 150
# 196119 981 kmAutomatiqueEssence
# 106 000 €
#
#
# CITROEN SM
# V6
# 197355 589 kmManuelleEssence
# 59 950 €
#
#
# JAGUAR TYPE E CABRIOLET
# CABRIOLET
# 197096 984 kmManuelleEssence
# 91 690 €
#
#
# JAGUAR MK II
# 3.8 220
# 196334 160 kmManuelleEssence
# 60 630 €
#
#
# BMW SERIE 5 E28
# E12 528I
# 1981120 482 kmManuelleEssence
# 26 640 €
#
#
# ASTON MARTIN DB2
# 3.0 140
# 195893 240 kmManuelleEssence
# 309 690 €
#
#
# MASERATI MEXICO
# V8
# 196998 630 kmManuelleEssence
# 144 670 €
#
#
# ALFA ROMEO GIULIA GT
# 1.6 106 VELOCE
# 1967141 015 kmManuelleEssence
# 54 400 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 E
# 197230 821 kmManuelleEssence
# 146 780 €
#
#
# RENAULT R8
# 1.1 46 MAJOR
# 197374 359 kmManuelleEssence
# 11 280 €
#
#
# ALFA ROMEO SPIDER
# 1.6 JUNIOR CODA LONGA
# 197091 014 kmManuelleEssence
# 43 090 €
#
#
# JAGUAR XK ROADSTER
# ROADSTER 150
# 196067 540 kmManuelleEssence
# 158 600 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=16&yearMax=1980
#
#
# JAGUAR TYPE E CABRIOLET
# CABRIOLET
# 1964110 740 kmManuelleEssence
# 191 980 €
#
#
# CITROEN DS
# IE PALLAS
# 197515 104 kmManuelleEssence
# 58 880 €
#
#
# AUSTIN MINI-MOKE
# 0.8
# 196794 746 kmManuelleEssence
# 39 540 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 S TARGA
# 197247 970 kmManuelleEssence
# 146 370 €
#
#
# FIAT 500
# R
# 197450 325 kmManuelleEssence
# 15 840 €
#
#
# MERCEDES 280 SL
# 170 SL
# 1971130 390 kmManuelleEssence
# 117 980 €
#
#
# FIAT 500
# 0.6 18
# 197218 600 kmManuelleEssence
# 20 950 €
#
#
# FIAT 500
# 0.6 18
# 197360 024 kmManuelleEssence
# 20 130 €
#
#
# CHEVROLET APACHE
# PICK UP
# 195688 500 kmAutomatiqueEssence
# 70 680 €
#
#
# FIAT 600
# 1000 ABARTH
# 196545 154 kmManuelleEssence
# 52 960 €
#
#
# PORSCHE 911 TYPE 901
# L
# 196727 830 kmManuelleEssence
# 169 270 €
#
#
# MERCEDES 230
# E
# 1977193 638 kmManuelleEssence
# 12 180 €
#
#
# PORSCHE 911 TYPE 901
# 2.7 210 CARRERA
# 197710 440 kmManuelleEssence
# 139 080 €
#
#
# FIAT 500
# 0.6 18
# 197176 254 kmManuelleEssence
# 15 710 €
#
#
# MG A
# 1.5 72
# 19596 090 kmManuelleEssence
# 49 350 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=17&yearMax=1980
#
#
# TOYOTA LAND CRUISER SERIE 40
# (BJ40) 3.0 D 80
# 1980144 078 kmManuelleDiesel
# 21 070 €
#
#
# PORSCHE 356 SPEEDSTER
# SPEEDSTER
# 19697 437 kmManuelleEssence
# 72 130 €
#
#
# NASH METROPOLITAN
# CABRIOLET
# 1961173 491 kmManuelleEssence
# 30 120 €
#
#
# JAGUAR TYPE E CABRIOLET
# V12 272
# 19741 066 kmManuelleEssence
# 138 750 €
#
#
# CHEVROLET BEL AIR COUPE
# HANDYMAN
# 19565 083 kmAutomatiqueEssence
# 42 690 €
#
#
# MERCEDES 250 CABRIOLET
# 250 SE
# 19679 161 kmManuelleEssence
# 172 380 €
#
#
# FORD TORINO
# 4.9 V8 CI 302CH GT
# 19691 943 kmAutomatiqueEssence
# 20 980 €
#
#
# LANCIA AURELIA CABRIOLET
# CABRIOLET
# 195612 388 kmManuelleEssence
# 1 308 000 €
#
#
# INNOCENTI MINI
# 1.3 COOPER
# 19765 371 kmManuelleEssence
# 34 380 €
#
#
# ROLLS ROYCE CORNICHE
# 6.8 V8
# 197325 103 kmAutomatiqueEssence
# 95 340 €
#
#
# JAGUAR XK CABRIOLET
# CABRIOLET
# 1961100 000 kmManuelleEssence
# 212 370 €
#
#
# FORD THUNDERBIRD CABRIOLET
# V8 245
# 19601 819 kmAutomatiqueEssence
# 74 750 €
#
#
# MERCEDES SL
# 2.8 280 170 PAGODE
# 1971158 568 kmManuelleEssence
# 107 100 €
#
#
# CITROEN SM
# 2.7 V6 170
# 1972105 846 kmManuelleEssence
# 58 760 €
#
#
# PORSCHE 356 SPEEDSTER
# SPEEDSTER
# 19663 042 kmManuelleEssence
# 285 070 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=18&yearMax=1980
#
#
# ALFA ROMEO ALFETTA GTV
# 2.0
# 197996 396 kmManuelleEssence
# 26 910 €
#
#
# PORSCHE 911 TYPE 901
# 2.4
# 197481 900 kmManuelleEssence
# 116 880 €
#
#
# CITROEN SM
# V6
# 197440 824 kmManuelleEssence
# 64 690 €
#
#
# JAGUAR XK ROADSTER
# 120 ROADSTER
# 1951102 082 kmManuelleEssence
# 111 860 €
#
#
# VOLKSWAGEN COMBI
# T2B BUS 9PL
# 1978156 250 kmManuelleEssence
# 61 120 €
#
#
# JAGUAR 3.8
# BERLINE
# 1966107 360 kmManuelleEssence
# 85 400 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 196763 638 kmAutomatiqueEssence
# 36 580 €
#
#
# MG B
# 1.8 97
# 1974111 180 kmManuelleEssence
# 24 850 €
#
#
# JAGUAR TYPE E CABRIOLET
# CABRIOLET
# 1966525 kmManuelleEssence
# 162 750 €
#
#
# MERCEDES SL
# 450
# 1977135 420 kmAutomatiqueEssence
# 30 370 €
#
#
# AUSTIN HEALEY 3000 ROADSTER
# 2.9 134
# 19615 550 kmManuelleEssence
# 109 890 €
#
#
# CHEVROLET 3100
# 3.1
# 1955152 100 kmAutomatiqueEssence
# 46 780 €
#
#
# PORSCHE 928
# 4.5 240
# 197986 986 kmManuelleEssence
# 28 040 €
#
#
# VOLKSWAGEN 1600 CABRIOLET
# CABRIOLET
# 1980132 083 kmManuelleEssence
# 28 510 €
#
#
# MERCEDES SL
# 230 PAGODE
# 196752 118 kmAutomatiqueEssence
# 94 280 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=19&yearMax=1980
#
#
# MERCEDES 190 SL
# 105
# 1961163 097 kmManuelleEssence
# 141 750 €
#
#
# CADILLAC SERIE 62
# BERLINE
# 195696 380 kmAutomatiqueEssence
# 34 140 €
#
#
# FIAT 500 BREAK
# BREAK
# 1962116 636 kmManuelleEssence
# 30 000 €
#
#
# FIAT 500
# 0.6 18
# 197265 550 kmManuelleEssence
# 26 440 €
#
#
# ROLLS ROYCE CORNICHE
# 6.8 V8 SALOON
# 197785 250 kmAutomatiqueEssence
# 115 500 €
#
#
# FARDIER LOHR ECLAT
# 500
# 19792 646 kmManuelleEssence
# 23 560 €
#
#
# ALFA ROMEO SPIDER phase 2
# 1.6 VELOCE CODA TRONCA
# 197760 900 kmManuelleEssence
# 25 720 €
#
#
# CHEVROLET CORVAIR CABRIOLET
# CABRIOLET 2.7 FLAT 6 110
# 196687 326 kmManuelleEssence
# 34 980 €
#
#
# LINCOLN CONTINENTAL
# MK V TONW CAR V8 179 6PL
# 198049 165 kmAutomatiqueEssence
# 21 830 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 1966179 010 kmAutomatiqueEssence
# 42 000 €
#
#
# TRIUMPH TR 4
# 2.1 104 IRS
# 196763 250 kmManuelleEssence
# 40 250 €
#
#
# MERCEDES SL
# 280 PAGODE BVA
# 197127 000 kmAutomatiqueEssence
# 178 200 €
#
#
# TRIUMPH TR 6
# 104
# 1975114 240 kmManuelleEssence
# 23 560 €
#
#
# PONTIAC CHIEFTAIN
# 4.7 V8 860 TWO 27 SERIES DOOR
# 19569 614 kmAutomatiqueEssence
# 22 040 €
#
#
# FORD MUSTANG COUPE
# 4.7 CI 271 FASTBACK
# 1966101 411 kmAutomatiqueEssence
# 68 200 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=20&yearMax=1980
#
#
# CITROEN SM
# V6
# 197438 080 kmManuelleEssence
# 101 150 €
#
#
# FORD MUSTANG CABRIOLET
# CI 228
# 1967130 968 kmManuelleEssence
# 53 480 €
#
#
# CITROEN 2CV
# 6
# 197642 600 kmManuelleEssence
# 14 380 €
#
#
# FORD BRONCO
# RANGER XLT
# 197998 649 kmAutomatiqueEssence
# 31 520 €
#
#
# PONTIAC GTO CABRIOLET
# CABRIOLET
# 197344 940 kmAutomatiqueEssence
# 69 550 €
#
#
# CITROEN 2CV (2E GENERATION)
# 0.6 29 SPECIAL
# 198199 680 kmManuelleEssence
# 41 420 €
#
#
# FERRARI 308
# 2.9 255 GTS
# 1980110 439 kmManuelleEssence
# 102 480 €
#
#
# FORD A
# COUPE SPORT 3.3  40
# 19308 540 kmManuelleEssence
# 34 100 €
#
#
# FIAT 500
# FERVES RANGER
# 197052 974 kmManuelleEssence
# 32 590 €
#
#
# VOLKSWAGEN COMBI
# T1 SAMBA BUS
# 195883 310 kmManuelleEssence
# 99 770 €
#
#
# VOLKSWAGEN GOLF GTI
# 1.6 110 GTI
# 1981175 201 kmManuelleEssence
# 14 620 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 306 GT
# 196719 140 kmAutomatiqueEssence
# 44 080 €
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI
# 197371 974 kmAutomatiqueEssence
# 40 280 €
#
#
# PORSCHE 356
# 1.6 75
# 196333 852 kmManuelleEssence
# 136 270 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 196937 760 kmAutomatiqueEssence
# 53 100 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=21&yearMax=1980
#
#
# CHRYSLER NEW YORKER
# BROUGHAM CUIR SERIES MODEL CS43
# 197586 272 kmManuelleEssence
# 17 740 €
#
#
# MG A COUPE
# 1.5 72
# 19623 285 kmManuelleEssence
# 34 700 €
#
#
# LANCIA FULVIA
# 1.3 90 MONTE CARLO
# 197485 680 kmManuelleEssence
# 35 580 €
#
#
# BUICK RIVIERA
# V8 455 CI
# 197367 155 kmAutomatiqueEssence
# 33 180 €
#
#
# FIAT 500
# 0.6 18
# 19705 863 kmManuelleEssence
# 19 470 €
#
#
# MG TC
# 1.3
# 1949664 kmManuelleEssence
# 41 400 €
#
#
# BMW SERIE 5 E12
# 1.8
# 1978178 159 kmManuelleEssence
# 17 480 €
#
#
# PLYMOUTH ROAD RUNNER
# E
# 197159 400 kmManuelleEssence
# 57 130 €
#
#
# CHEVROLET MONTE CARLO
# BERLINE
# 1976145 373 kmAutomatiqueEssence
# 27 820 €
#
#
# PACKARD SUPER EIGHT
# E
# 1937106 kmAutomatiqueEssence
# 79 500 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 E
# 1971543 kmManuelleEssence
# 120 640 €
#
#
# HONDA CIVIC II
# II ESS
# 197899 019 kmAutomatiqueEssence
# 12 470 €
#
#
# VOLKSWAGEN 1200
# 1.2 34
# 19624 715 kmManuelleEssence
# 32 770 €
#
#
# DODGE CHALLENGER
# COUPE
# 197515 246 kmAutomatiqueEssence
# 36 170 €
#
#
# FIAT 500 GAMINE
# 0.6 18 GAMINE
# 1966100 332 kmManuelleEssence
# 19 330 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=22&yearMax=1980
#
#
# MASERATI MISTRAL CABRIOLET
# CABRIOLET
# 196627 342 kmManuelleEssence
# 627 000 €
#
#
# PORSCHE 911 TYPE 901
# 2.4 S
# 1973131 250 kmManuelleEssence
# 135 450 €
#
#
# MERCURY MONTEREY CABRIOLET
# CABRIOLET 6.4 V8 300 MARAUDER
# 1965153 372 kmManuelleEssence
# 29 730 €
#
#
# BMW 2800
# E
# 197143 557 kmManuelleEssence
# 30 150 €
#
#
# OPEL MANTA
# 1.6 84
# 197251 146 kmManuelleEssence
# 28 780 €
#
#
# VOLKSWAGEN 1500
# COMBI
# 197339 915 kmManuelleEssence
# 20 900 €
#
#
# FERRARI 330
# 4.0 V12 300 GTC
# 1968119 kmManuelleEssence
# 844 900 €
#
#
# PORSCHE 911 TYPE 901
# 2.4 S
# 1973156 838 kmManuelleEssence
# 106 680 €
#
#
# FORD MUSTANG CABRIOLET
# CI 228
# 196835 854 kmAutomatiqueEssence
# 44 830 €
#
#
# VOLKSWAGEN COMBI
# T1
# 196739 628 kmManuelleEssence
# 80 710 €
#
#
# BUICK RIVIERA
# 7.5 V8 455 CID
# 197287 710 kmAutomatiqueEssence
# 32 080 €
#
#
# CITROEN DS
# 2.0 103 PALLAS
# 1970123 284 kmAutomatiqueEssence
# 35 680 €
#
#
# MORRIS MINI
# MK1
# 196935 520 kmManuelleEssence
# 50 940 €
#
#
# VOLKSWAGEN COMBI
# T2A
# 197211 258 kmManuelleEssence
# 35 500 €
#
#
# FERRARI 308
# 2.9 255 GTB
# 197845 399 kmManuelleEssence
# 152 490 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=23&yearMax=1980
#
#
# FIAT 500
# R
# 197527 869 kmManuelleEssence
# 14 960 €
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI
# 197293 814 kmAutomatiqueEssence
# 57 990 €
#
#
# PORSCHE 914
# 2.0 110
# 197140 950 kmManuelleEssence
# 96 990 €
#
#
# BMW 327
# CABRIOLET 55
# 19411 820 kmManuelleEssence
# 275 500 €
#
#
# FORD F100
# V8 400
# 197130 475 kmAutomatiqueEssence
# 31 620 €
#
#
# ALFA ROMEO GIULIETTA SPIDER
# 1.3 80
# 196374 992 kmManuelleEssence
# 88 130 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 306 CLEVELAND
# 19665 625 kmAutomatiqueEssence
# 55 000 €
#
#
# CHEVROLET BEL AIR COUPE
# COUPE
# 195412 499 kmAutomatiqueEssence
# 53 750 €
#
#
# LAND ROVER RANGE ROVER
# 2.3
# 1974109 739 kmManuelleEssence
# 73 070 €
#
#
# CHEVROLET IMPALA
# BERINE
# 197853 580 kmAutomatiqueEssence
# 33 060 €
#
#
# TRIUMPH TR 6
# 104
# 197871 920 kmManuelleEssence
# 31 200 €
#
#
# MG B GT
# 1.8 97 COUPE
# 1971108 000 kmManuelleEssence
# 16 680 €
#
#
# CITROEN 2CV
# 0.4 9
# 195479 500 kmManuelleEssence
# 16 940 €
#
#
# MG TD
# 1.3
# 195430 670 kmManuelleEssence
# 44 750 €
#
#
# CHEVROLET CORVETTE C2 CABRIOLET
# 5.4 V8 365
# 1966172 500 kmManuelleEssence
# 82 500 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=24&yearMax=1980
#
#
# EXCALIBUR SSK
# CABRIOLET
# 19663 071 kmAutomatiqueEssence
# 89 250 €
#
#
# FORD T
# COUPE DOCTEUR 2.8 20
# 192817 095 kmManuelleEssence
# 33 860 €
#
#
# OLDSMOBILE CUTLASS CABRIOLET
# CABRIOLET F85 BVA
# 196534 008 kmAutomatiqueEssence
# 20 710 €
#
#
# MERCEDES 250
# 250 SE
# 196967 200 kmManuelleEssence
# 5 400 €
#
#
# DODGE ROYAL CUSTOM
# COUPE
# 19571 kmManuelleEssence
# 31 920 €
#
#
# CADILLAC SERIE 62 CABRIOLET
# CABRIOLET
# 196055 782 kmAutomatiqueEssence
# 186 300 €
#
#
# CITROEN TYPE H
# HY
# 197798 440 kmManuelleEssence
# 42 780 €
#
#
# CITROEN H
# 1.9 52 8V AV
# 195890 618 kmManuelleEssence
# 18 170 €
#
#
# BMW SERIE 3 E21
# 315
# 1979181 662 kmManuelleEssence
# 18 130 €
#
#
# GMC C20
# 5.7 V8 255 PICK UP
# 1969150 107 kmAutomatiqueEssence
# 21 400 €
#
#
# MG B
# 1.8 97
# 197058 850 kmManuelleEssence
# 21 290 €
#
#
# CHEVROLET CORVETTE C1 CABRIOLET
# 3.9 150
# 1960151 848 kmAutomatiqueEssence
# 86 670 €
#
#
# MERCEDES 280
# SE
# 196967 860 kmManuelleEssence
# 5 260 €
#
#
# FORD FAIRLANE 500
# BERLINE
# 196371 001 kmAutomatiqueEssence
# 24 720 €
#
#
# VOLKSWAGEN KARMAN GHIA CABRIOLET
# 1.6 50
# 197240 600 kmManuelleEssence
# 46 280 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=25&yearMax=1980
#
#
# CITROEN CX
# 2.0 102
# 197617 868 kmManuelleEssence
# 17 830 €
#
#
# CHEVROLET MONTE CARLO
# COUPE 2P
# 197469 540 kmAutomatiqueEssence
# 30 370 €
#
#
# MERCEDES SL
# 3.5 350 200
# 197376 700 kmManuelleEssence
# 43 540 €
#
#
# PORSCHE 356
# 1.6 60
# 1964107 577 kmManuelleEssence
# 90 090 €
#
#
# AUTOBIANCHI BIANCHINA CABRIOLET
# CABRIOLET EDEN ROC
# 197013 455 kmManuelleEssence
# 33 930 €
#
#
# MERCEDES 280
# 2.7 185 SE
# 1979275 686 kmManuelleEssence
# 21 290 €
#
#
# PORSCHE 911 TYPE 901
# 2.4 S
# 197371 583 kmManuelleEssence
# 212 930 €
#
#
# MERCEDES CLASSE S II
# II 350 SE
# 1975229 900 kmAutomatiqueEssence
# 27 830 €
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI 205
# 197843 852 kmAutomatiqueEssence
# 29 380 €
#
#
# CITROEN TYPE C 5HP
# 5HP TORPEDO
# 192717 656 kmManuelleEssence
# 30 500 €
#
#
# FORD GT 40
# 7.0
# 196811 121 kmManuelleEssence
# 367 500 €
#
#
# AUSTIN HEALEY 3000 ROADSTER
# 2.9 148
# 196583 824 kmManuelleEssence
# 117 800 €
#
#
# CHEVROLET CORVETTE C1
# 4.7 250
# 196226 938 kmManuelleEssence
# 136 850 €
#
#
# CHRYSLER WINDSOR COUPE
# COUPE 6.4 V8 383 CID
# 1967136 577 kmManuelleEssence
# 29 140 €
#
#
# CITROEN TRACTION 11
# 1.9 46
# 195678 120 kmManuelleEssence
# 26 020 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=26&yearMax=1980
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI
# 1971143 190 kmAutomatiqueEssence
# 56 610 €
#
#
# PORSCHE 911 TYPE 901
# 2.7 210 CARRERA
# 197633 600 kmManuelleEssence
# 140 000 €
#
#
# RENAULT R10
# E
# 1971104 060 kmManuelleEssence
# 8 470 €
#
#
# CHEVROLET CORVETTE C1
# 4.6 283CI 230
# 19591 947 kmManuelleEssence
# 189 970 €
#
#
# CHEVROLET CORVETTE C2
# C2 250 STINGRAY
# 19661 725 kmAutomatiqueEssence
# 91 770 €
#
#
# SIMCA 6
# E
# 1951178 750 kmManuelleEssence
# 12 250 €
#
#
# PORSCHE 356
# PRE A 1500
# 195653 167 kmManuelleEssence
# 343 910 €
#
#
# AUSTIN MINI BREAK
# BREAK
# 196811 374 kmManuelleEssence
# 41 640 €
#
#
# CITROEN DS
# 21
# 1964134 842 kmManuelleEssence
# 21 450 €
#
#
# MG B
# 1.8 97
# 196849 860 kmManuelleEssence
# 32 380 €
#
#
# BMW SERIE 3 E21
# 2.3 122
# 1978226 695 kmManuelleEssence
# 11 780 €
#
#
# LANCIA FLAVIA
# COUPE
# 1970102 125 kmManuelleEssence
# 34 380 €
#
#
# BMW 3.0
# 3.0 180 CS
# 197681 320 kmManuelleEssence
# 69 530 €
#
#
# DODGE CHALLENGER
# COUPE
# 1971103 700 kmAutomatiqueEssence
# 120 760 €
#
#
# MG B
# 1.8 97
# 196932 377 kmManuelleEssence
# 29 150 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=27&yearMax=1980
#
#
# TRIUMPH STAG
# V8
# 1974110 734 kmManuelleEssence
# 32 220 €
#
#
# FORD MUSTANG COUPE
# 4.7 CI 271
# 196636 662 kmAutomatiqueEssence
# 36 460 €
#
#
# PORSCHE 356
# 1.6 90 SUPER
# 196532 842 kmManuelleEssence
# 96 300 €
#
#
# FIAT DINO COUPE
# COUPE
# 197049 268 kmManuelleEssence
# 58 750 €
#
#
# PORSCHE 911 TYPE 901
# 2.4
# 1974133 300 kmManuelleEssence
# 105 400 €
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI
# 1973108 350 kmAutomatiqueEssence
# 38 390 €
#
#
# PORSCHE 911 TYPE 901
# 2.4 S TRAPPE A HUILE
# 197398 064 kmManuelleEssence
# 151 100 €
#
#
# ROLLS ROYCE SILVER SHADOW
# 6.8 V8
# 1972136 800 kmAutomatiqueEssence
# 47 870 €
#
#
# JAGUAR TYPE E COUPE
# COUPE 4.2 2+2 SERIE 2
# 196916 082 kmManuelleEssence
# 91 280 €
#
#
# MERCEDES 190 SL
# 105
# 195611 160 kmManuelleEssence
# 214 800 €
#
#
# CITROEN 2CV
# 0.4 18
# 196978 266 kmManuelleEssence
# 17 500 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 E
# 197228 912 kmManuelleEssence
# 123 920 €
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI
# 1977109 411 kmAutomatiqueEssence
# 27 280 €
#
#
# JAGUAR TYPE E CABRIOLET
# CABRIOLET
# 196677 280 kmManuelleEssence
# 204 750 €
#
#
# MERCEDES SL
# 250 150 PAGODE
# 196927 250 kmManuelleEssence
# 125 240 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=28&yearMax=1980
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI
# 197339 550 kmAutomatiqueEssence
# 45 080 €
#
#
# FIAT 500
# 0.6 32 595
# 19701 140 kmManuelleEssence
# 39 780 €
#
#
# ALFA ROMEO 2600 SPIDER
# 145
# 196530 475 kmManuelleEssence
# 149 380 €
#
#
# MERCEDES 220
# SE
# 197216 161 kmManuelleEssence
# 8 990 €
#
#
# FORD 32 ROADSTER
# REPLICA V8 18
# 193332 525 kmManuelleEssence
# 118 580 €
#
#
# AUSTIN 1000
# E
# 197680 315 kmManuelleEssence
# 19 930 €
#
#
# CHEVROLET CORVETTE C3
# 350 CI STINGRAY
# 197457 477 kmAutomatiqueEssence
# 44 010 €
#
#
# OPEL KADETT
# 200 S
# 197664 698 kmManuelleEssence
# 8 460 €
#
#
# MG B
# 1.8 97
# 1980112 230 kmManuelleEssence
# 19 710 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 1966102 608 kmAutomatiqueEssence
# 42 350 €
#
#
# FIAT 500
# R
# 197413 960 kmManuelleEssence
# 17 380 €
#
#
# FIAT DINO SPIDER
# SPIDER
# 19709 240 kmManuelleEssence
# 146 890 €
#
#
# VOLKSWAGEN COMBI
# T2A TYPE 23 CAMPMOBILE WESTFALIA 6PL
# 1972102 000 kmManuelleEssence
# 107 860 €
#
#
# CADILLAC ELDORADO CABRIOLET
# V8 CABRIOLET
# 197428 305 kmAutomatiqueEssence
# 33 180 €
#
#
# PORSCHE 911 TYPE 901 CABRIOLET
# 2.0
# 1968575 kmManuelleEssence
# 186 900 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=29&yearMax=1980
#
#
# RENAULT R16
# 1.5 55
# 1968106 272 kmManuelleEssence
# 15 370 €
#
#
# CHEVROLET IMPALA
# 5.7 V8 COUPE 2 PORTES
# 196374 401 kmAutomatiqueEssence
# 56 250 €
#
#
# ROLLS ROYCE SILVER SHADOW II
# 6.8 V8
# 1978164 220 kmAutomatiqueEssence
# 49 980 €
#
#
# FORD BRONCO
# 200
# 197885 600 kmAutomatiqueEssence
# 64 200 €
#
#
# ALFA ROMEO 2000
# 150 VELOCE
# 19745 529 kmManuelleEssence
# 51 290 €
#
#
# AUSTIN MINI
# COOPER S
# 197016 662 kmManuelleEssence
# 43 540 €
#
#
# PORSCHE 911 TYPE 901
# 2.7 210 CARRERA
# 1974271 425 kmManuelleEssence
# 577 500 €
#
#
# CITROEN 2CV
# 0.4 24 SPOT
# 1977117 kmManuelleEssence
# 23 400 €
#
#
# MG A
# 1.6 72
# 196296 800 kmManuelleEssence
# 46 580 €
#
#
# PORSCHE 911 TYPE 901
# 2.7 210 CARRERA
# 197697 684 kmManuelleEssence
# 146 290 €
#
#
# CITROEN TRACTION 11
# 1.9 46
# 194046 617 kmManuelleEssence
# 116 720 €
#
#
# DODGE CHARGER
# 6.3 V8 D200
# 196820 460 kmAutomatiqueEssence
# 37 180 €
#
#
# CHEVROLET BEL AIR
# 170
# 195718 419 kmAutomatiqueEssence
# 39 430 €
#
#
# MERCEDES 280 CABRIOLET
# E
# 1976155 375 kmManuelleEssence
# 18 060 €
#
#
# LANCIA FULVIA
# 1.3 90 S
# 197596 240 kmManuelleEssence
# 24 600 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=30&yearMax=1980
#
#
# CHEVROLET MASTER DELUXE
# COUPE 3.4
# 193989 942 kmManuelleEssence
# 55 880 €
#
#
# CHEVROLET CORVETTE C2 CABRIOLET
# CABRIOLET C2 5.4 L 365 CV
# 196683 636 kmManuelleEssence
# 178 250 €
#
#
# PORSCHE 911 TYPE 901
# 2.0
# 196637 kmManuelleEssence
# 1 340 700 €
#
#
# FORD MUSTANG COUPE
# 3.3 V8 122
# 1969160 460 kmAutomatiqueEssence
# 90 280 €
#
#
# PORSCHE 911 TYPE 901
# 2.7
# 1978104 500 kmManuelleEssence
# 109 900 €
#
#
# FORD MUSTANG COUPE
# BULLIT
# 196920 554 kmManuelleEssence
# 70 780 €
#
#
# DODGE CHARGER
# 7.2 CI 375
# 197035 700 kmAutomatiqueEssence
# 104 890 €
#
#
# FORD B CABRIOLET
# 5.0
# 19332 573 kmAutomatiqueEssence
# 83 890 €
#
#
# FIAT DINO COUPE
# COUPE
# 197458 560 kmManuelleEssence
# 55 990 €
#
#
# MG B
# 1.8 97
# 197762 872 kmManuelleEssence
# 26 860 €
#
#
# RENAULT FLORIDE
# E
# 1963112 203 kmManuelleEssence
# 58 380 €
#
#
# ALFA ROMEO SPIDER phase 2
# 1.6 VELOCE CODA TRONCA
# 198071 690 kmManuelleEssence
# 26 530 €
#
#
# FORD THUNDERBIRD CABRIOLET
# MATCHING HARD TOP & CAPOTE NEUVE
# 195866 378 kmManuelleEssence
# 59 870 €
#
#
# ALFA ROMEO 1750
# GT VELOCE BERTONE
# 197251 802 kmManuelleEssence
# 64 780 €
#
#
# PORSCHE 911 TYPE 901
# 2.4
# 1974141 600 kmManuelleEssence
# 103 720 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=31&yearMax=1980
#
#
# PORSCHE 356
# 1.6 95
# 196558 157 kmManuelleEssence
# 127 580 €
#
#
# FIAT 500
# 2P
# 197079 520 kmManuelleEssence
# 9 520 €
#
#
# VOLKSWAGEN 1600
# E
# 197897 638 kmManuelleEssence
# 40 920 €
#
#
# CHEVROLET CORVETTE C1
# 5.4 360
# 196415 872 kmManuelleEssence
# 210 670 €
#
#
# VOLKSWAGEN 1303
# 1.3 44
# 1979201 720 kmManuelleEssence
# 31 980 €
#
#
# TRIUMPH TR 4
# 2.1 104 IRS
# 196834 168 kmManuelleEssence
# 50 580 €
#
#
# FIAT 600
# 2P
# 196513 885 kmManuelleEssence
# 13 540 €
#
#
# MERCEDES SL
# 450
# 1979176 400 kmAutomatiqueEssence
# 33 020 €
#
#
# LANCIA FULVIA
# 1.6 114 HF
# 197324 160 kmManuelleEssence
# 67 080 €
#
#
# JAGUAR XJ 2 C
# 4.2
# 1978117 993 kmAutomatiqueEssence
# 20 740 €
#
#
# VOLKSWAGEN COMBI
# T2 WESTFALIA
# 1976138 240 kmManuelleEssence
# 29 140 €
#
#
# AUSTIN MINI-MOKE
# 1.3 34
# 196963 kmManuelleEssence
# 49 950 €
#
#
# OLDSMOBILE CUTLASS CABRIOLET
# CABRIOLET
# 196744 833 kmManuelleEssence
# 21 400 €
#
#
# ALPINE A106
# 0.8 45 MILLE MILES
# 195973 125 kmManuelleEssence
# 55 110 €
#
#
# MASERATI GHIBLI
# 5.0 V8 335 SS
# 197121 090 kmManuelleEssence
# 336 300 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=32&yearMax=1980
#
#
# CHEVROLET CORVETTE C2 CABRIOLET
# CABRIOLET 427 V8 390
# 197062 160 kmManuelleEssence
# 99 900 €
#
#
# FORD THUNDERBIRD CABRIOLET
# V8 245
# 1956117 800 kmAutomatiqueEssence
# 43 380 €
#
#
# LANCIA FULVIA
# SPORT ZAGATO ZAGATO
# 197031 777 kmManuelleEssence
# 47 080 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 T
# 197278 632 kmManuelleEssence
# 134 430 €
#
#
# VOLKSWAGEN KARMAN GHIA
# COUPE
# 197025 607 kmManuelleEssence
# 30 780 €
#
#
# FORD MUSTANG COUPE
# 289 CI FASTBACK
# 196636 519 kmAutomatiqueEssence
# 58 710 €
#
#
# VOLKSWAGEN COMBI
# T1 SAMBA
# 196627 875 kmManuelleEssence
# 56 250 €
#
#
# FIAT 130
# BERLINE
# 197495 971 kmManuelleEssence
# 13 200 €
#
#
# MERCEDES SL
# 2.8 280 170 PAGODE
# 19722 780 kmAutomatiqueEssence
# 97 990 €
#
#
# EXCALIBUR PHAETON
# CABRIOLET
# 198059 622 kmAutomatiqueEssence
# 56 880 €
#
#
# CHEVROLET CORVETTE C1
# 5.4 360
# 1965402 kmManuelleEssence
# 97 740 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 196640 938 kmAutomatiqueEssence
# 77 100 €
#
#
# VOLKSWAGEN 1303
# 1.3 44
# 197886 832 kmManuelleEssence
# 26 040 €
#
#
# TRIUMPH TR 6
# 104
# 19753 720 kmManuelleEssence
# 27 520 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 S
# 197129 760 kmManuelleEssence
# 190 830 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=33&yearMax=1980
#
#
# MG C COUPE
# 2.9 147
# 196983 227 kmManuelleEssence
# 33 180 €
#
#
# PLYMOUTH GTX
# 440 SUPER COMMANDO
# 196964 480 kmAutomatiqueEssence
# 111 600 €
#
#
# PEUGEOT 404
# E
# 196699 612 kmManuelleEssence
# 10 500 €
#
#
# RENAULT 4CV
# 0.8 17
# 19545 762 kmManuelleEssence
# 13 540 €
#
#
# CADILLAC SERIE 62 CABRIOLET
# CABRIOLET
# 196432 568 kmAutomatiqueEssence
# 43 070 €
#
#
# TRIUMPH TR 3
# 2.0 100
# 196071 332 kmManuelleEssence
# 44 160 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 1969185 238 kmAutomatiqueEssence
# 55 220 €
#
#
# PEUGEOT 504 BREAK
# 95
# 1979275 414 kmManuelleEssence
# 13 800 €
#
#
# FERRARI 308 CABRIOLET
# GTS CABRIOLET GTS
# 198061 000 kmManuelleEssence
# 121 980 €
#
#
# MERCEDES SL
# 2.8 280 170 PAGODE
# 1971111 150 kmAutomatiqueEssence
# 76 030 €
#
#
# JAGUAR TYPE E COUPE
# COUPE 4.2 SERIE 2
# 1972150 257 kmManuelleEssence
# 87 720 €
#
#
# VOLKSWAGEN 1600
# E
# 197847 845 kmManuelleEssence
# 42 330 €
#
#
# PORSCHE 356
# 1.6 75
# 196573 125 kmManuelleEssence
# 102 960 €
#
#
# FORD THUNDERBIRD VI
# V8
# 197897 440 kmAutomatiqueEssence
# 11 480 €
#
#
# CITROEN 2CV FOURGONNETTE
# 0.4 12
# 197595 920 kmManuelleEssence
# 16 350 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=34&yearMax=1980
#
#
# LANCIA APPIA
# COUPE GTE ZAGATO
# 196227 404 kmManuelleEssence
# 166 480 €
#
#
# CHEVROLET CORVETTE C1
# C1
# 195976 880 kmAutomatiqueEssence
# 126 480 €
#
#
# FORD MUSTANG COUPE
# COUPE 4.7 V8 289CI
# 196779 462 kmAutomatiqueEssence
# 28 440 €
#
#
# BMW 2002
# 2.0 TII 130 TII
# 1974114 724 kmManuelleEssence
# 40 480 €
#
#
# VOLKSWAGEN COMBI
# T1 SAMBA
# 19782 925 kmManuelleEssence
# 44 460 €
#
#
# PORSCHE 911 TYPE 901
# 2.4 S
# 197414 519 kmManuelleEssence
# 165 190 €
#
#
# PORSCHE 911 TYPE 901
# 2.4
# 1972109 003 kmManuelleEssence
# 91 080 €
#
#
# SUNBEAM ALPINE
# CAB
# 196196 807 kmManuelleEssence
# 26 290 €
#
#
# PORSCHE 911 TYPE 901
# 2.7 210 CARRERA
# 1974249 900 kmManuelleEssence
# 577 500 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 E
# 197111 346 kmManuelleEssence
# 168 190 €
#
#
# PEUGEOT 104
# SE SE
# 197652 038 kmManuelleEssence
# 10 690 €
#
#
# FORD MUSTANG CABRIOLET
# CI 228
# 196853 911 kmAutomatiqueEssence
# 45 580 €
#
#
# FORD THUNDERBIRD III
# V8
# 196333 040 kmAutomatiqueEssence
# 43 540 €
#
#
# RENAULT R12
# 1.3 54 TL
# 197785 389 kmManuelleEssence
# 8 410 €
#
#
# MG B
# 1.8 97
# 1977105 000 kmManuelleEssence
# 16 060 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=35&yearMax=1980
#
#
# FIAT 500
# 2P
# 196666 729 kmManuelleEssence
# 20 650 €
#
#
# PORSCHE 912
# 1.6 90
# 1967123 715 kmManuelleEssence
# 87 090 €
#
#
# FORD MUSTANG CABRIOLET
# CI 228
# 1967116 040 kmAutomatiqueEssence
# 56 280 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 S
# 197175 980 kmManuelleEssence
# 214 480 €
#
#
# MG B GT
# 1.8 97
# 197286 526 kmManuelleEssence
# 22 680 €
#
#
# JAGUAR XK CABRIOLET
# CABRIOLET
# 19611 026 kmManuelleEssence
# 159 600 €
#
#
# PORSCHE 911 TYPE 901
# 2.4
# 19741 688 kmManuelleEssence
# 81 250 €
#
#
# BMW 2002
# 2.0 TII 130 TII
# 197310 285 kmManuelleEssence
# 42 790 €
#
#
# JAGUAR TYPE E COUPE
# V12 272
# 1974102 120 kmAutomatiqueEssence
# 124 320 €
#
#
# MG B
# 1.8 97
# 19791 690 kmManuelleEssence
# 23 680 €
#
#
# FORD THUNDERBIRD 3
# 6.4 V8 COUPE HARD TOP
# 1963144 506 kmAutomatiqueEssence
# 31 000 €
#
#
# TRIUMPH TR 6
# 104
# 197239 063 kmManuelleEssence
# 23 120 €
#
#
# FIAT DINO COUPE
# COUPE
# 19733 651 kmManuelleEssence
# 79 300 €
#
#
# ALFA ROMEO MONTREAL
# 2.6 V8 200
# 197439 711 kmManuelleEssence
# 84 360 €
#
#
# TRIUMPH TR 6
# 2.5 6 CYLINDRES 105 CH HARD TOP
# 1975147 000 kmManuelleEssence
# 33 060 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=36&yearMax=1980
#
#
# OLDSMOBILE F-85
# STATION WAGON
# 1962110 625 kmManuelleEssence
# 30 000 €
#
#
# PORSCHE 911 TYPE 911
# 200 CARRERA
# 1977109 470 kmManuelleEssence
# 121 770 €
#
#
# PORSCHE 911 TYPE 901
# E
# 197086 031 kmManuelleEssence
# 155 400 €
#
#
# MERCEDES 190 SL
# 105
# 1961110 658 kmManuelleEssence
# 160 630 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 306 GT
# 196689 680 kmAutomatiqueEssence
# 54 160 €
#
#
# PORSCHE 912
# 1.6 90
# 196954 740 kmManuelleEssence
# 95 080 €
#
#
# AC COBRA
# ERA 400 SUPERFORMANCE
# 19682 394 kmManuelleEssence
# 115 640 €
#
#
# MERCEDES 190 SL
# SL
# 196397 733 kmManuelleEssence
# 173 750 €
#
#
# ALFA ROMEO 2000 SPIDER
# 2.0
# 19634 130 kmManuelleEssence
# 114 440 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 S
# 19723 318 kmManuelleEssence
# 190 400 €
#
#
# FORD MUSTANG CABRIOLET
# CABRIOLET 289 CI MACH 1
# 1973113 608 kmAutomatiqueEssence
# 30 470 €
#
#
# MG B
# 1.8 97
# 1969104 218 kmManuelleEssence
# 29 140 €
#
#
# FORD MUSTANG COUPE
# 390 GTA FASTBACK
# 196862 730 kmAutomatiqueEssence
# 129 150 €
#
#
# CHEVROLET CAMARO II
# V8
# 197993 750 kmAutomatiqueEssence
# 24 980 €
#
#
# MERCEDES 300
# 3.0 109
# 1981209 720 kmManuelleDiesel
# 9 090 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=37&yearMax=1980
#
#
# CHEVROLET CORVETTE C2
# 5.4 360 STINGRAY
# 196710 900 kmAutomatiqueEssence
# 108 890 €
#
#
# OLDSMOBILE F85
# COUPE V8
# 1964104 792 kmAutomatiqueEssence
# 13 200 €
#
#
# CHEVROLET IMPALA
# COUPE 454CI
# 196698 820 kmAutomatiqueEssence
# 47 150 €
#
#
# PORSCHE 912
# 1.6 90
# 1967124 000 kmManuelleEssence
# 105 290 €
#
#
# BUICK RIVIERA
# 455 CI 455
# 1972166 420 kmAutomatiqueEssence
# 28 600 €
#
#
# PORSCHE 911 TYPE 901
# 2.2 S
# 19711 764 kmManuelleEssence
# 189 200 €
#
#
# BMW SERIE 5 E12
# (E12) 520i
# 1976169 400 kmManuelleEssence
# 15 710 €
#
#
# FORD MUSTANG COUPE
# 4.7 CI 271 FASTBACK
# 1968103 500 kmAutomatiqueEssence
# 171 350 €
#
#
# PORSCHE 911 TYPE 901
# 2.7 TARGA
# 197570 928 kmManuelleEssence
# 86 770 €
#
#
# JAGUAR 420
# BERLINE
# 19694 537 kmManuelleEssence
# 22 210 €
#
#
# JAGUAR 3.4
# BERLINE
# 196744 950 kmManuelleEssence
# 35 890 €
#
#
# CHEVROLET IMPALA
# COUPE
# 196161 476 kmAutomatiqueEssence
# 80 660 €
#
#
# FORD F100
# V8 400
# 1953103 500 kmAutomatiqueEssence
# 51 740 €
#
#
# RENAULT R5
# L L
# 197976 654 kmManuelleEssence
# 8 950 €
#
#
# MORRIS MINI
# 1.0 55 COOPER
# 196963 233 kmManuelleEssence
# 30 090 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=38&yearMax=1980
#
#
# MERCEDES SL
# 450
# 1977219 989 kmAutomatiqueEssence
# 19 780 €
#
#
# FERRARI 250
# GT GT
# 1964103 685 kmManuelleEssence
# 349 650 €
#
#
# TRIUMPH TR 3
# 2.0 100
# 196067 200 kmManuelleEssence
# 38 640 €
#
#
# PEUGEOT 504 COUPE
# 2.0 104
# 1979225 630 kmManuelleEssence
# 16 330 €
#
#
# FIAT 600
# 2P
# 196690 629 kmManuelleEssence
# 20 560 €
#
#
# AUSTIN MINI
# 1000
# 1979954 kmManuelleEssence
# 11 660 €
#
#
# PORSCHE 911 TYPE 901 CABRIOLET
# 2.0
# 1969145 770 kmManuelleEssence
# 124 180 €
#
#
# VOLKSWAGEN COCCINELLE
# 1303
# 197957 500 kmManuelleEssence
# 29 880 €
#
#
# FIAT 500
# 0.6 18
# 197310 126 kmManuelleEssence
# 12 070 €
#
#
# BENTLEY MARK
# 6
# 195085 400 kmManuelleEssence
# 40 260 €
#
#
# LAND ROVER RANGE ROVER
# 3.5
# 198187 462 kmManuelleEssence
# 34 460 €
#
#
# SHELBY COBRA DAYTONA
# 4.7 470 CSX
# 19678 493 kmManuelleEssence
# 192 650 €
#
#
# BMW SERIE 3 E21
# 2.3 323I 150
# 19817 500 kmManuelleEssence
# 37 370 €
#
#
# TRIUMPH SPITFIRE
# FH
# 197872 150 kmManuelleEssence
# 15 420 €
#
#
# TRIUMPH SPITFIRE
# FH
# 198179 867 kmManuelleEssence
# 14 020 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=39&yearMax=1980
#
#
# CITROEN TRACTION 11
# 1.9 46
# 195677 054 kmManuelleEssence
# 23 600 €
#
#
# GMC SIERRA
# CLASSIC 5.7 SHORT BED
# 19783 653 kmAutomatiqueEssence
# 46 870 €
#
#
# MORGAN PLUS 8
# 3.5 V8 160
# 1975124 300 kmManuelleEssence
# 55 930 €
#
#
# CITROEN 2CV
# 0.4 18
# 196548 600 kmManuelleEssence
# 19 330 €
#
#
# FIAT 500 JOLLY
# 0.6 18 GHIA
# 197116 350 kmManuelleEssence
# 37 060 €
#
#
# FIAT 500
# R
# 197540 530 kmManuelleEssence
# 12 070 €
#
#
# MG B GT
# 3.5 V8 137 GT
# 1973113 460 kmManuelleEssence
# 11 950 €
#
#
# CITROEN 2CV
# 0.4 18
# 196628 000 kmManuelleEssence
# 11 200 €
#
#
# MG A
# 1.6 72
# 196162 016 kmManuelleEssence
# 39 330 €
#
#
# AC COBRA
# 520 CSX
# 196622 487 kmManuelleEssence
# 124 290 €
#
#
# CITROEN MEHARI
# 0.6
# 197145 980 kmManuelleEssence
# 25 410 €
#
#
# MERCEDES CLASSE S II
# 3.5 350 195 SE
# 1975198 690 kmAutomatiqueEssence
# 15 520 €
#
#
# BMW 2000 BREAK
# BREAK
# 197069 891 kmManuelleEssence
# 10 580 €
#
#
# FORD MUSTANG COUPE
# 3.3 V8 122
# 196933 898 kmAutomatiqueEssence
# 42 000 €
#
#
# CITROEN MEHARI
# 0.6
# 1975100 960 kmManuelleEssence
# 16 050 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=40&yearMax=1980
#
#
# TRIUMPH TR 3
# 2.0 100
# 195970 800 kmManuelleEssence
# 41 180 €
#
#
# VOLKSWAGEN 1303
# 1.3 44
# 197460 420 kmManuelleEssence
# 25 640 €
#
#
# CHEVROLET C10
# V8 FLEETSIDE
# 19722 645 kmAutomatiqueEssence
# 25 620 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 1966151 200 kmAutomatiqueEssence
# 30 780 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 196860 720 kmAutomatiqueEssence
# 44 000 €
#
#
# PEUGEOT 504 CABRIOLET
# 2.0 104
# 198082 482 kmManuelleEssence
# 49 560 €
#
#
# TRIUMPH SPITFIRE
# 1.3 63
# 197559 780 kmManuelleEssence
# 19 390 €
#
#
# VOLKSWAGEN 1200
# 1.2 34
# 1975102 340 kmManuelleEssence
# 18 440 €
#
#
# TRIUMPH TR 6
# 104
# 197578 750 kmManuelleEssence
# 12 490 €
#
#
# RENAULT R8
# 1.1 53 S
# 19706 kmManuelleEssence
# 26 010 €
#
#
# FORD MUSTANG COUPE
# 289 CI COUPE
# 196631 900 kmAutomatiqueEssence
# 27 500 €
#
#
# SKODA POPULAR
# DECOUVRABLE
# 193642 800 kmManuelleEssence
# 37 450 €
#
#
# JAGUAR XK ROADSTER
# ROADSTER
# 19574 119 kmManuelleEssence
# 440 300 €
#
#
# FORD MUSTANG CABRIOLET
# CI 228
# 196775 768 kmAutomatiqueEssence
# 30 750 €
#
#
# CITROEN 2CV
# 6
# 197673 332 kmManuelleEssence
# 6 090 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=41&yearMax=1980
#
#
# HOTCHKISS JEEP
# M201
# 196411 186 kmManuelleEssence
# 26 160 €
#
#
# JAGUAR TYPE E COUPE
# V12 272
# 1974102 947 kmAutomatiqueEssence
# 77 700 €
#
#
# JAGUAR 3.8
# BERLINE
# 196962 700 kmManuelleEssence
# 31 900 €
#
#
# CITROEN 2CV
# 0.4 18
# 196677 350 kmManuelleEssence
# 10 710 €
#
#
# RENAULT RODEO
# 0.8 34
# 198135 840 kmManuelleEssence
# 20 160 €
#
#
# CITROEN 2CV
# 6
# 197512 051 kmManuelleEssence
# 10 530 €
#
#
# PEUGEOT 504 COUPE
# 2.7 V6 136
# 1978281 600 kmManuelleEssence
# 29 700 €
#
#
# LAND ROVER LAND SERIE 3
# 2.3
# 197592 800 kmManuelleEssence
# 17 400 €
#
#
# RENAULT 4CV
# 0.8 17
# 1958236 kmManuelleEssence
# 23 600 €
#
#
# CITROEN TRACTION 11
# 1.9 46
# 195694 843 kmManuelleEssence
# 6 420 €
#
#
# FIAT 500 JOLLY
# 0.6 18 GHIA
# 196768 908 kmManuelleEssence
# 14 440 €
#
#
# RENAULT R8
# 1.1 46 MAJOR
# 197187 344 kmManuelleEssence
# 10 070 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 196623 100 kmAutomatiqueEssence
# 46 200 €
#
#
# MG B GT
# 1.8 97 GT
# 197439 960 kmAutomatiqueEssence
# 29 970 €
#
#
# CITROEN 2CV (2E GENERATION)
# 0.6 29 SPECIAL
# 1981137 160 kmManuelleEssence
# 10 260 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=42&yearMax=1980
#
#
# TRIUMPH TR 3
# 2.0 100
# 196175 480 kmManuelleEssence
# 31 080 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 306 GT
# 196783 930 kmAutomatiqueEssence
# 53 410 €
#
#
# MERCEDES 280 COUPE
# 2.7 177
# 1981156 800 kmAutomatiqueEssence
# 17 360 €
#
#
# CITROEN 2CV
# 0.4 18
# 196799 510 kmManuelleEssence
# 9 630 €
#
#
# AUSTIN HEALEY 3000 ROADSTER
# 2.9 124
# 196266 000 kmManuelleEssence
# 93 600 €
#
#
# FIAT 124 SPIDER
# SPIDER
# 197163 801 kmManuelleEssence
# 24 360 €
#
#
# AUSTIN HEALEY 3000 ROADSTER
# 2.9 124
# 196243 448 kmManuelleEssence
# 64 290 €
#
#
# MG B GT
# 1.8 97 GT
# 196854 282 kmAutomatiqueEssence
# 24 580 €
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI
# 1971111 870 kmAutomatiqueEssence
# 50 840 €
#
#
# VOLVO 144
# 1.8 75
# 197536 300 kmManuelleEssence
# 9 680 €
#
#
# BMW SERIE 3 E21
# 2.3 150
# 1980222 000 kmManuelleEssence
# 15 420 €
#
#
# CITROEN 2CV FOURGONNETTE
# 0.4 12
# 197784 750 kmManuelleEssence
# 8 920 €
#
#
# TOYOTA LAND CRUISER SERIE 40
# 4.0 125
# 198033 601 kmManuelleEssence
# 28 990 €
#
#
# FORD COBRA
# 7.0 V8 450
# 19668 282 kmAutomatiqueEssence
# 166 500 €
#
#
# FIAT 500 JOLLY
# 0.6 18 GHIA
# 1971575 kmManuelleEssence
# 40 250 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=43&yearMax=1980
#
#
# MG B
# 1.8 97
# 1964136 800 kmManuelleEssence
# 26 210 €
#
#
# VOLKSWAGEN 1302
# 1.3 44
# 197313 447 kmManuelleEssence
# 14 280 €
#
#
# PORSCHE 356
# 1.6 75
# 1965115 200 kmManuelleEssence
# 110 240 €
#
#
# PEUGEOT 204
# E
# 197323 370 kmManuelleEssence
# 10 080 €
#
#
# MERCURY MONTEREY
# E
# 196068 440 kmManuelleEssence
# 41 300 €
#
#
# MERCEDES SL
# 450
# 1980106 820 kmAutomatiqueEssence
# 32 700 €
#
#
# MG B
# 1.8 97
# 1965109 469 kmManuelleEssence
# 30 150 €
#
#
# AUSTIN HEALEY SPRITE ROADSTER
# MK III ROADSTER
# 196652 320 kmManuelleEssence
# 17 330 €
#
#
# CITROEN MEHARI
# 0.6
# 197310 590 kmManuelleEssence
# 21 870 €
#
#
# RENAULT ESTAFETTE
# LUXE LUXE
# 1981124 000 kmManuelleEssence
# 7 440 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 196780 101 kmAutomatiqueEssence
# 56 870 €
#
#
# FORD MUSTANG COUPE
# 4.7 CI 271 FASTBACK
# 1966220 220 kmAutomatiqueEssence
# 75 020 €
#
#
# PEUGEOT 203 PICK-UP
# 42
# 195916 385 kmManuelleEssence
# 14 120 €
#
#
# MG B
# 1.8 97
# 1979148 800 kmManuelleEssence
# 17 360 €
#
#
# CITROEN MEHARI
# 0.6
# 197160 270 kmManuelleEssence
# 21 520 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=44&yearMax=1980
#
#
# VOLVO PV544
# 1.6 67 SPORT
# 196229 580 kmManuelleEssence
# 21 460 €
#
#
# AUSTIN HEALEY 3000 ROADSTER
# 2.9 148
# 196546 421 kmManuelleEssence
# 103 700 €
#
#
# CHEVROLET CAMARO COUPE
# V8 210
# 196922 524 kmManuelleEssence
# 60 870 €
#
#
# MERCEDES SL
# 3.5 350 200
# 1980167 140 kmManuelleEssence
# 32 810 €
#
#
# MERCEDES 280 COUPE
# 2.7 177
# 1979300 840 kmManuelleEssence
# 9 700 €
#
#
# LINCOLN CONTINENTAL COUPE
# COUPE
# 198076 380 kmAutomatiqueEssence
# 28 490 €
#
#
# MG B
# 1.8 97
# 1968122 647 kmManuelleEssence
# 25 620 €
#
#
# ALPINE A310
# 1.6 127 VE
# 197643 126 kmManuelleEssence
# 55 360 €
#
#
# CHEVROLET CAMARO COUPE
# V8
# 1970530 kmAutomatiqueEssence
# 52 470 €
#
#
# MG B GT
# 1.8 97 GT
# 1975104 720 kmAutomatiqueEssence
# 26 180 €
#
#
# CHEVROLET APACHE
# PICK UP
# 195810 800 kmAutomatiqueEssence
# 32 290 €
#
#
# BMW 3.0
# 3.0 200 CSI
# 1974104 048 kmManuelleEssence
# 74 920 €
#
#
# CITROEN DS
# 2.0 103 PALLAS
# 1969116 820 kmAutomatiqueEssence
# 42 480 €
#
#
# GLAS 1700
# COUPE
# 196968 900 kmManuelleEssence
# 63 600 €
#
#
# AC COBRA
# CSX 427 FIBRE 570CH
# 19676 588 kmManuelleEssence
# 303 030 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=45&yearMax=1980
#
#
# TRIUMPH SPITFIRE
# 1.3 75
# 1969121 000 kmManuelleEssence
# 18 390 €
#
#
# MERCEDES SL
# 450
# 197676 300 kmAutomatiqueEssence
# 20 710 €
#
#
# MG C COUPE
# 2.9 147
# 197059 800 kmManuelleEssence
# 33 920 €
#
#
# PORSCHE 914
# 1.7 80
# 1973108 706 kmManuelleEssence
# 146 780 €
#
#
# MG B
# 1.8 97
# 197455 350 kmManuelleEssence
# 23 240 €
#
#
# RENAULT R4
# 0.8 27
# 197834 200 kmManuelleEssence
# 9 100 €
#
#
# CHEVROLET CORVETTE
# C3
# 197092 167 kmManuelleEssence
# 65 380 €
#
#
# MG A
# 1.5 72
# 1958101 818 kmManuelleEssence
# 40 920 €
#
#
# MERCEDES 190 SL
# 105
# 195711 700 kmManuelleEssence
# 127 520 €
#
#
# RENAULT ESTAFETTE
# LUXE LUXE
# 197544 963 kmManuelleEssence
# 15 150 €
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI
# 197328 945 kmAutomatiqueEssence
# 43 950 €
#
#
# CHEVROLET BEL AIR COUPE
# COUPE
# 195963 637 kmAutomatiqueEssence
# 43 400 €
#
#
# CITROEN 2CV
# 0.6 29 CLUB
# 198116 650 kmManuelleEssence
# 14 980 €
#
#
# PORSCHE 924
# 2.0 125
# 1977198 000 kmManuelleEssence
# 11 000 €
#
#
# AUSTIN HEALEY 3000 ROADSTER
# 2.9 134
# 196369 825 kmManuelleEssence
# 79 800 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=46&yearMax=1980
#
#
# PEUGEOT 404 CABRIOLET
# CABRIOLET
# 196584 000 kmManuelleEssence
# 39 900 €
#
#
# PORSCHE 911 TYPE 901
# 2.4
# 1973108 480 kmManuelleEssence
# 118 640 €
#
#
# CITROEN 2CV
# 0.4 18
# 196549 279 kmManuelleEssence
# 12 700 €
#
#
# CITROEN AC4
# 1.6
# 193348 689 kmManuelleEssence
# 10 710 €
#
#
# CHEVROLET CAMARO COUPE
# V8 5.4
# 1970122 000 kmAutomatiqueEssence
# 44 530 €
#
#
# VOLKSWAGEN 1200
# 1.2 34
# 196365 648 kmManuelleEssence
# 13 200 €
#
#
# CATERHAM SUPER SEVEN
# 1.4 84 GT
# 197958 000 kmManuelleEssence
# 24 360 €
#
#
# TOYOTA LAND CRUISER SERIE 40
# 3.0 80
# 197953 975 kmManuelleDiesel
# 16 820 €
#
#
# TRIUMPH GT6
# 2.0 104
# 1968151 515 kmManuelleEssence
# 41 970 €
#
#
# RENAULT R8
# 1.3 103 GORDINI
# 196964 350 kmManuelleEssence
# 45 630 €
#
#
# VOLKSWAGEN POLO
# 0.9
# 197949 500 kmManuelleEssence
# 11 000 €
#
#
# MORRIS 1100
# E
# 19707 881 kmManuelleEssence
# 24 370 €
#
#
# FERRARI 308
# 2.9 255 GTB
# 19819 740 kmManuelleEssence
# 95 400 €
#
#
# ROLLS ROYCE SILVER SHADOW
# 6.8 V8
# 198084 800 kmAutomatiqueEssence
# 26 500 €
#
#
# FERRARI 308
# 2.9 255 GTB
# 1980138 329 kmManuelleEssence
# 110 330 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=47&yearMax=1980
#
#
# MERCEDES 280 SL
# 170 SL
# 1979172 500 kmManuelleEssence
# 31 250 €
#
#
# CITROEN 2CV
# 0.4 9
# 195563 397 kmManuelleEssence
# 22 610 €
#
#
# CITROEN 2CV (2E GENERATION)
# 0.6 29 SPECIAL
# 198192 796 kmManuelleEssence
# 10 260 €
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI
# 197591 300 kmAutomatiqueEssence
# 41 800 €
#
#
# ALFA ROMEO GIULIA GT
# 1.6 103 GT
# 196457 720 kmManuelleEssence
# 76 050 €
#
#
# MERCEDES SL
# 450
# 1981181 350 kmAutomatiqueEssence
# 26 790 €
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI
# 197045 000 kmAutomatiqueEssence
# 61 250 €
#
#
# CITROEN 2CV
# 0.4 18
# 1968119 175 kmManuelleEssence
# 12 600 €
#
#
# VOLKSWAGEN COMBI
# T2B BUS 9PL
# 1979169 500 kmManuelleEssence
# 44 060 €
#
#
# CITROEN 2CV FOURGONNETTE phase 2
# 0.6 35
# 197216 200 kmManuelleEssence
# 13 500 €
#
#
# CHEVROLET CORVETTE
# V8 355 STINGRAY C3 5.7
# 1976195 200 kmManuelleEssence
# 31 710 €
#
#
# ALFA ROMEO 1750
# GT VELOCE VELOCE
# 1972110 048 kmManuelleEssence
# 46 000 €
#
#
# FIAT 500
# 0.6 18
# 197168 480 kmManuelleEssence
# 10 700 €
#
#
# CITROEN MEHARI
# 0.6
# 197842 705 kmManuelleEssence
# 23 980 €
#
#
# CITROEN MEHARI
# 0.6
# 19712 326 kmManuelleEssence
# 21 640 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=48&yearMax=1980
#
#
# CHEVROLET CORVETTE C3
# 5.7 350 CI
# 197922 728 kmAutomatiqueEssence
# 22 480 €
#
#
# AC COBRA
# KIRKHAM ALU 611
# 196622 890 kmManuelleEssence
# 323 750 €
#
#
# VESPA 400
# E
# 1971174 kmManuelleEssence
# 9 620 €
#
#
# CITROEN 2CV
# 0.4 18
# 1967130 255 kmManuelleEssence
# 8 170 €
#
#
# RENAULT 4CV
# 0.8 17
# 1954119 197 kmManuelleEssence
# 14 750 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 196792 800 kmAutomatiqueEssence
# 30 150 €
#
#
# AUSTIN HEALEY SPRITE ROADSTER
# 0.9
# 19633 210 kmManuelleEssence
# 31 560 €
#
#
# RENAULT R8
# 1.1 95 GORDINI
# 19693 918 kmManuelleEssence
# 105 020 €
#
#
# CITROEN MEHARI
# 0.6 29
# 198064 900 kmManuelleEssence
# 34 440 €
#
#
# VOLKSWAGEN 1500
# 44
# 197258 500 kmManuelleEssence
# 24 570 €
#
#
# OPEL MANTA II
# 1.9 105 GTE
# 1980139 020 kmManuelleEssence
# 6 300 €
#
#
# JAGUAR MK II
# 3.4 210
# 196493 054 kmManuelleEssence
# 71 550 €
#
#
# RENAULT R5
# 1.4 93
# 1979148 500 kmManuelleEssence
# 23 760 €
#
#
# BMW 1500
# E
# 1981171 719 kmManuelleEssence
# 30 770 €
#
#
# RENAULT JUVAQUATRE
# 1.0 24
# 193973 683 kmManuelleEssence
# 12 370 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=49&yearMax=1980
#
#
# CITROEN 2CV FOURGONNETTE phase 2
# 0.6 22
# 196564 335 kmManuelleEssence
# 11 770 €
#
#
# RENAULT R4
# 0.8 34 SUPER
# 1970111 240 kmManuelleEssence
# 16 200 €
#
#
# SIMCA ARONDE BREAK
# 1.3
# 195889 770 kmManuelleEssence
# 14 880 €
#
#
# TRIUMPH TR 4
# 2.1 104 IRS
# 196828 500 kmManuelleEssence
# 45 590 €
#
#
# FORD MUSTANG COUPE
# 4.7 CI 271
# 1967109 800 kmAutomatiqueEssence
# 36 600 €
#
#
# CITROEN MEHARI
# 0.6 29
# 197952 320 kmManuelleEssence
# 31 810 €
#
#
# SIMCA ARONDE
# BERLINE
# 195774 370 kmManuelleEssence
# 5 310 €
#
#
# CITROEN DS
# 2.0 103 PALLAS
# 1975107 085 kmAutomatiqueEssence
# 19 470 €
#
#
# MG A
# 1.5 72
# 195979 433 kmManuelleEssence
# 54 730 €
#
#
# JAGUAR XJ 2 C
# 4.2
# 197851 360 kmAutomatiqueEssence
# 16 050 €
#
#
# MG B GT
# 1.8 97
# 1976131 346 kmManuelleEssence
# 17 710 €
#
#
# FIAT 500 GAMINE
# 0.6 18 GAMINE
# 1972109 000 kmManuelleEssence
# 7 080 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 196953 631 kmAutomatiqueEssence
# 44 840 €
#
#
# RENAULT 4CV
# 0.8 17
# 1961107 527 kmManuelleEssence
# 11 360 €
#
#
# PEUGEOT 403
# E
# 1963128 520 kmManuelleEssence
# 8 330 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=50&yearMax=1980
#
#
# JAGUAR 3.8
# BERLINE
# 196293 112 kmManuelleEssence
# 56 490 €
#
#
# ALFA ROMEO 2600 SPRINT
# 2.6 145
# 196514 954 kmManuelleEssence
# 72 950 €
#
#
# MERCEDES SL
# 350
# 197498 040 kmManuelleEssence
# 19 260 €
#
#
# FIAT 500
# 0.6 18
# 197235 400 kmManuelleEssence
# 15 930 €
#
#
# FORD MUSTANG CABRIOLET
# CI 228
# 197166 957 kmAutomatiqueEssence
# 60 480 €
#
#
# CADILLAC COUPE DEVILLE
# V8 429
# 1968108 580 kmAutomatiqueEssence
# 34 160 €
#
#
# CITROEN 2CV
# 6
# 198032 256 kmManuelleEssence
# 14 380 €
#
#
# CITROEN TYPE H
# HY
# 1969101 200 kmManuelleEssence
# 44 000 €
#
#
# MG B GT
# 1.8 97 GT
# 1975131 230 kmAutomatiqueEssence
# 17 200 €
#
#
# FORD MUSTANG COUPE
# 4.7 CI 271
# 196713 443 kmAutomatiqueEssence
# 38 160 €
#
#
# PEUGEOT 204 CABRIOLET
# CABRIOLET
# 1969104 981 kmManuelleEssence
# 24 470 €
#
#
# BMW 2000 COUPE TOURING
# COUPE TOURING
# 197254 060 kmManuelleEssence
# 27 340 €
#
#
# RENAULT FLORIDE
# E
# 196459 940 kmManuelleEssence
# 19 640 €
#
#
# TRIUMPH SPITFIRE
# 80
# 197735 700 kmManuelleEssence
# 16 540 €
#
#
# JEEP WILLYS
# 50
# 195759 920 kmManuelleEssence
# 17 650 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=51&yearMax=1980
#
#
# ALFA ROMEO SPIDER phase 2
# 2.0 VELOCE CODA TRONCA
# 197363 280 kmManuelleEssence
# 33 780 €
#
#
# CITROEN 2CV
# 6
# 197844 640 kmManuelleEssence
# 9 300 €
#
#
# VOLKSWAGEN 1600 CABRIOLET
# CABRIOLET
# 1970119 560 kmManuelleEssence
# 42 680 €
#
#
# MERCEDES SL
# 2.8 280 170 PAGODE
# 1978256 250 kmManuelleEssence
# 37 370 €
#
#
# CITROEN AC4
# TORPEDO
# 193287 674 kmManuelleEssence
# 22 320 €
#
#
# MG B GT
# 1.8 97
# 197016 054 kmManuelleEssence
# 23 160 €
#
#
# CITROEN 2CV
# 6
# 197482 080 kmManuelleEssence
# 13 100 €
#
#
# CITROEN 2CV
# 6
# 197417 011 kmManuelleEssence
# 11 070 €
#
#
# CITROEN 2CV
# 6
# 198021 357 kmManuelleEssence
# 11 290 €
#
#
# MG B GT
# 1.8 97
# 197171 370 kmManuelleEssence
# 30 300 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 1968106 000 kmAutomatiqueEssence
# 68 900 €
#
#
# WOLSELEY HORNET
# E
# 196965 720 kmManuelleEssence
# 19 840 €
#
#
# VOLKSWAGEN 1600
# E
# 198011 kmManuelleEssence
# 25 610 €
#
#
# CITROEN DYANE 6
# 0.6 35
# 197035 424 kmManuelleEssence
# 7 990 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 19681 932 kmAutomatiqueEssence
# 56 450 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=52&yearMax=1980
#
#
# CITROEN 2CV FOURGONNETTE phase 2
# 0.6 35
# 1975118 800 kmManuelleEssence
# 16 200 €
#
#
# FORD MUSTANG COUPE
# 4.7 V8 200
# 19693 824 kmAutomatiqueEssence
# 44 400 €
#
#
# PORSCHE 911 TYPE 901
# 2.7
# 1977252 960 kmManuelleEssence
# 73 160 €
#
#
# CITROEN 2CV (2E GENERATION)
# 0.6 29 SPECIAL
# 197926 950 kmManuelleEssence
# 12 100 €
#
#
# TRIUMPH SPITFIRE
# FH
# 19786 150 kmManuelleEssence
# 18 450 €
#
#
# INNOCENTI MINI
# 1.0
# 197561 950 kmManuelleEssence
# 14 590 €
#
#
# PEUGEOT 203
# 42
# 195762 313 kmManuelleEssence
# 90 930 €
#
#
# TRIUMPH TR 6
# 104
# 197177 000 kmManuelleEssence
# 23 980 €
#
#
# CITROEN SM
# V6
# 1975103 821 kmManuelleEssence
# 61 250 €
#
#
# FIAT 500
# 0.6 18
# 197426 160 kmManuelleEssence
# 11 880 €
#
#
# FORD MUSTANG COUPE
# 5.8 290 MACH 1
# 197226 750 kmAutomatiqueEssence
# 62 060 €
#
#
# VOLKSWAGEN COMBI
# T1
# 197657 500 kmManuelleEssence
# 34 150 €
#
#
# MERCURY COUGAR
# COUPE XR7 V8 351CI
# 197488 281 kmAutomatiqueEssence
# 26 060 €
#
#
# FORD MUSTANG COUPE
# 3.3 CI 122
# 1966149 330 kmAutomatiqueEssence
# 24 520 €
#
#
# LANCIA FULVIA
# SPORT ZAGATO ZAGATO
# 197391 200 kmManuelleEssence
# 35 880 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=53&yearMax=1980
#
#
# BENTLEY T
# 6.2 V8 36
# 196947 040 kmManuelleEssence
# 25 640 €
#
#
# MG B
# 1.8 97
# 197383 960 kmManuelleEssence
# 27 750 €
#
#
# RENAULT R5
# L L
# 1980131 673 kmManuelleEssence
# 24 520 €
#
#
# CITROEN 2CV
# 6
# 198078 815 kmManuelleEssence
# 9 840 €
#
#
# MG A
# 1.5 72
# 19594 620 kmManuelleEssence
# 40 800 €
#
#
# CADILLAC SERIE 62
# BERLINE
# 195478 082 kmAutomatiqueEssence
# 15 330 €
#
#
# DODGE RAMCHARGER
# 5.2 V8
# 1980142 090 kmAutomatiqueEssence
# 17 200 €
#
#
# VOLKSWAGEN 1303
# 1.3 44
# 197440 330 kmManuelleEssence
# 16 070 €
#
#
# CITROEN 2CV FOURGONNETTE phase 2
# 0.6 35
# 197881 466 kmManuelleEssence
# 9 340 €
#
#
# CHEVROLET IMPALA
# COUPE
# 196089 600 kmManuelleEssence
# 59 360 €
#
#
# MERCEDES 280 SL
# 170 CALIFORNIA
# 197016 950 kmManuelleEssence
# 107 340 €
#
#
# PORSCHE 911 TYPE 901
# 2.4
# 197117 555 kmManuelleEssence
# 119 860 €
#
#
# RENAULT 4CV
# 0.8 17
# 1958117 120 kmManuelleEssence
# 20 740 €
#
#
# CITROEN 2CV
# 0.4 18
# 1967108 304 kmManuelleEssence
# 14 560 €
#
#
# ROVER P5
# E
# 1974129 600 kmManuelleEssence
# 42 000 €
# https://www.lacentrale.fr/listing?makesModelsCommercialNames=&options=&page=54&yearMax=1980
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Cars_Analysis\brand_new_cars\script\clean_data.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/d%3A/Cars_Analysis/brand_new_cars/script/clean_data.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a> page = bs(webpage,"html.parser")
#      <a href='vscode-notebook-cell:/d%3A/Cars_Analysis/brand_new_cars/script/clean_data.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a> print(site)
# ---> <a href='vscode-notebook-cell:/d%3A/Cars_Analysis/brand_new_cars/script/clean_data.ipynb#W0sZmlsZQ%3D%3D?line=17'>18</a> time.sleep(2)
#      <a href='vscode-notebook-cell:/d%3A/Cars_Analysis/brand_new_cars/script/clean_data.ipynb#W0sZmlsZQ%3D%3D?line=19'>20</a> for CompteurVoiture in range(1,16,1):
#      <a href='vscode-notebook-cell:/d%3A/Cars_Analysis/brand_new_cars/script/clean_data.ipynb#W0sZmlsZQ%3D%3D?line=20'>21</a>     voiture = page.findAll("a",class_="Vehiculecard_Vehiculecard_vehiculeCard Containers_Containers_containers Containers_Containers_borderRadius Containers_Containers_darkShadowWide")
#
# KeyboardInterrupt:
